# %%
from qualibrate import QualibrationNode, NodeParameters
from pathlib import Path
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2026-02-18 14:54:49,682 - qm - INFO     - Starting session: 1eda2364-d23c-4e36-ac96-aa36eadf8b57

# %%
node  = QualibrationNode(name="QPT_vs_ellipsoid")
QPT_ellipsoid_data_path = Path("/Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/data/QPT_vs_ellipsoid")
# Out:
# 2026-02-18 14:54:50,843 - qualibrate - INFO - Creating node QPT_vs_ellipsoid

# %% [markdown]
# # QPT

# %%
from QPT_vs_ellipsoid_marcos import xyz_data_to_gate_fidelity, random_sampling
QPT_sampling_data = []
gate_fidelity = []
#QPT_data_id = np.arange(1824,1915,3)
QPT_data_id = np.arange(1926,2017,3)
# QPT_data_id = np.arange(1926,1940,3)


trials = 10
for i in QPT_data_id:
    QPT = node.load_from_id(i, base_path=QPT_ellipsoid_data_path)
    ds = QPT.results['ds']
    machine =  QPT.machine
    qubit = machine.qubits['q0']
    confusion_matrix = qubit.resonator.confusion_matrix
    n_runs = 10000  #maximum is 10000
    ds_samples = random_sampling(ds, n_samples=trials, sample_size= n_runs)
    for j in range(trials):
        results = xyz_data_to_gate_fidelity(
        ds_samples.sel(sample=j), 
        confusion_matrix,
        qubit,
        n_runs,
        apply_mitigation=True,
        operation_name='id'
        )
        QPT_sampling_data .append(results['q0']['quantum_information']['mitigated']['Quantum Memory Robustness'])
        gate_fidelity.append(results['q0']['quantum_information']['mitigated']['fidelity'])
QPT_sampling_data, gate_fidelity = np.array(QPT_sampling_data), np.array(gate_fidelity)
QPT_sampling_data = QPT_sampling_data.reshape(len(QPT_data_id),trials)
gate_fidelity = gate_fidelity.reshape(len(QPT_data_id),trials)
# Out:
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/atoms/affine/reshape.py:68: FutureWarning:
#     You didn't specify the order of the reshape expression. The default order
#     used in CVXPY is Fortran ('F') order. This default will change to match NumPy's
#     default order ('C') in a future version of CVXPY.
#     To suppress this warning, please specify the order explicitly.
#
#   warnings.warn(reshape_order_warning, FutureWarning)
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.

# %%
import numpy as np
from numpy.polynomial import Polynomial

# Extract mean data for fitting
x_data = gate_fidelity.mean(axis=1)
QPT_y_data = QPT_sampling_data.mean(axis=1)
QPT_y_err = QPT_sampling_data.std(axis=1)

# Fit with polynomial (1st order = linear fit)
p = Polynomial.fit(x_data, QPT_y_data, 1)
QPT_x_fit = np.linspace(x_data.min(), x_data.max()+0.1, 100)
QPT_y_fit = p(QPT_x_fit)

# Plot data points with green color and error bars
plt.errorbar(x_data, QPT_y_data, QPT_y_err,
                    linestyle='none', fmt='o', markersize=4, markerfacecolor='green', 
                    markeredgecolor='green', ecolor='green', elinewidth=2, capsize=4, capthick=1.2)

# Plot fitting line as dashed line
plt.plot(QPT_x_fit, QPT_y_fit, 'g--', linewidth=2, label='Linear Fit')
# plt.xlim(0.85,1.0)
# plt.ylim(0.7,1)
plt.xlabel('Gate Fidelity(%)')
plt.ylabel('Robustness')
plt.show()

# %% [markdown]
# # ellipsoid

# %%
from QPT_vs_ellipsoid_marcos import random_sampling_without_replacement, compute_robustness

# %%
from QPT_vs_ellipsoid_marcos import random_sampling_without_replacement, compute_robustness, filter_robustness_outliers

ellipsoid_data_id = np.arange(1927,2018,3)
#ellipsoid_data_id = np.arange(1927,1933,3)
number_of_ellipsoid =300
data_points_per_ellipsoid = 180
robustness_results_all = []  # Save all original robustness values
robustness_results_filtered = []  # Save filtered robustness values
filter_stats = []  # Save filtering statistics for each ID
ellipsoid_statistics = {}  # Dictionary to store mean and std for each ID

for i in range(len(ellipsoid_data_id)):
    QPT = node.load_from_id(ellipsoid_data_id[i], base_path=QPT_ellipsoid_data_path)
    ds = QPT.results['ds']
    machine =  QPT.machine
    qubit = machine.qubits['q0']
    confusion_matrix = qubit.resonator.confusion_matrix
    ds_samples = random_sampling_without_replacement(ds, n_samples=number_of_ellipsoid, sample_size=data_points_per_ellipsoid)
    
    # Compute robustness for all samples
    robustness_per_id = []
    for j in range(number_of_ellipsoid):
        robustness, results = compute_robustness(ds_samples[j], np.array(confusion_matrix).T, apply_mitigation=True)
        robustness_per_id.append(robustness)
        robustness_results_all.append(robustness)
    
    # Filter outliers using IQR method for this ID
    robustness_array = np.array(robustness_per_id)
    filtered_array, mask, stats = filter_robustness_outliers(
        robustness_array, 
        method='iqr', 
        threshold=1.5,
        verbose=False
    )
    
    robustness_results_filtered.extend(filtered_array)
    stats['ellipsoid_id'] = ellipsoid_data_id[i]
    filter_stats.append(stats)
    
    # Store statistics for this ID
    mean_robustness = np.mean(filtered_array)
    std_robustness = np.std(filtered_array)
    ellipsoid_statistics[int(ellipsoid_data_id[i])] = {
        'mean': mean_robustness,
        'std': std_robustness,
        'count': len(filtered_array),
        'outliers_removed': stats['removed_count']
    }
    
    print(f"ID {ellipsoid_data_id[i]}: Retained {stats['filtered_count']}/{stats['original_count']} data "
          f"(removed {stats['removed_count']}, {stats['removed_percentage']:.1f}%) | "
          f"Mean: {mean_robustness:.6f} ± {std_robustness:.6f}")

robustness_results_all = np.array(robustness_results_all)
robustness_results_filtered = np.array(robustness_results_filtered)
robustness_results = robustness_results_filtered  # Use filtered results

print(f"\nOverall Statistics:")
print(f"  Original data: {len(robustness_results_all)} points")
print(f"  Filtered data: {len(robustness_results_filtered)} points")
print(f"  Removed: {len(robustness_results_all) - len(robustness_results_filtered)} points ({100*(1-len(robustness_results_filtered)/len(robustness_results_all)):.1f}%)")

print(f"\nEllipsoid Statistics Dictionary:")
print(ellipsoid_statistics)
# Out:
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.05   0.944]
# After 10 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 15 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.055  0.939]
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.007  0.043  0.951]
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.021  0.973]
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.102  0.892]
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.054  0.94 ]
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.052  0.942]
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 16 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 14 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.018  0.976]
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.007  0.1    0.894]
# After 36 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 12 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 12 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 34 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.007  0.987]
# Choi state is invalid:
# ❌ Trace of the Choi state is not 1. Got trace = (1.000000017375831+0j)
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 18 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.011  0.982]
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 29 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.024  0.97 ]
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 82 iterations, the Choi state is valid.
# After 21 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 15 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# ID 1927: Retained 242/300 data (removed 58, 19.3%) | Mean: 0.962852 ± 0.027058
# After 9 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.015  0.051  0.935]
# After 9 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.005  0.021  0.973]
# After 2 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 27 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.021  0.973]
# After 9 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 25 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 16 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 20 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.004  0.021  0.975]
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 11 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 11 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.004  0.021  0.974]
# After 9 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.024  0.97 ]
# After 8 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 16 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 15 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.013  0.066  0.921]
# After 7 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.014  0.055  0.931]
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 54 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 14 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 20 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.005  0.021  0.974]
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.004  0.02   0.976]
# After 7 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.005  0.021  0.974]
# After 10 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 13 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 11 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.023  0.972]
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 12 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.004  0.02   0.976]
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 18 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 91 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.004  0.021  0.975]
# After 7 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.022  0.972]
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 18 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# ID 1930: Retained 255/300 data (removed 45, 15.0%) | Mean: 0.935449 ± 0.011129
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 11 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# ID 1933: Retained 285/300 data (removed 15, 5.0%) | Mean: 0.936888 ± 0.037363
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.007  0.017  0.976]
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.007  0.018  0.975]
# After 7 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 57 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.007  0.017  0.977]
# After 3 iterations, the Choi state is valid.
# After 13 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 11 iterations, the Choi state is valid.
# After 41 iterations, the Choi state is valid.
# After 11 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 28 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 55 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 49 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.014  0.98 ]
# After 7 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.006  0.017  0.977]
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 32 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 38 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 87 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 32 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 13 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 76 iterations, the Choi state is valid.
# After 61 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 20 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 59 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# ...
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.007  0.011  0.982]
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 12 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.004  0.007  0.989]
# After 6 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 17 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# ID 2017: Retained 293/300 data (removed 7, 2.3%) | Mean: 0.966022 ± 0.006715
#
# Overall Statistics:
#   Original data: 9300 points
#   Filtered data: 8658 points
#   Removed: 642 points (6.9%)
#
# Ellipsoid Statistics Dictionary:
# {1927: {'mean': 0.9628516217668466, 'std': 0.02705758486567207, 'count': 242, 'outliers_removed': 58}, 1930: {'mean': 0.9354490645888937, 'std': 0.011128621926570912, 'count': 255, 'outliers_removed': 45}, 1933: {'mean': 0.9368883146688073, 'std': 0.03736326130107567, 'count': 285, 'outliers_removed': 15}, 1936: {'mean': 0.7769625476857114, 'std': 0.16690316221088472, 'count': 300, 'outliers_removed': 0}, 1939: {'mean': 0.884204496293467, 'std': 0.051798271949189366, 'count': 294, 'outliers_removed': 6}, 1942: {'mean': 0.9358919090421931, 'std': 0.013503347354315274, 'count': 280, 'outliers_removed': 20}, 1945: {'mean': 0.9227506912010905, 'std': 0.004528300022284554, 'count': 299, 'outliers_removed': 1}, 1948: {'mean': 0.8122248524814942, 'std': 0.020650059533483606, 'count': 285, 'outliers_removed': 15}, 1951: {'mean': 0.9314986888893468, 'std': 0.008593192133901556, 'count': 291, 'outliers_removed': 9}, 1954: {'mean': 0.938856293551688, 'std': 0.010495984233868971, 'count': 284, 'outliers_removed': 16}, 1957: {'mean': 0.9401149506616112, 'std': 0.01516516534828248, 'count': 246, 'outliers_removed': 54}, 1960: {'mean': 0.9476099549900583, 'std': 0.010661303522646041, 'count': 288, 'outliers_removed': 12}, 1963: {'mean': 0.7746780300157448, 'std': 0.24539569953076668, 'count': 300, 'outliers_removed': 0}, 1966: {'mean': 0.9388970520115699, 'std': 0.012385259104776532, 'count': 227, 'outliers_removed': 73}, 1969: {'mean': 0.9468652728662186, 'std': 0.005743961250993913, 'count': 299, 'outliers_removed': 1}, 1972: {'mean': 0.9221583419929575, 'std': 0.026579857948507264, 'count': 253, 'outliers_removed': 47}, 1975: {'mean': 0.8850979889286861, 'std': 0.030204639619596758, 'count': 295, 'outliers_removed': 5}, 1978: {'mean': 0.95175037907001, 'std': 0.012669125488779806, 'count': 247, 'outliers_removed': 53}, 1981: {'mean': 0.6017257904337577, 'std': 0.18796819763668554, 'count': 300, 'outliers_removed': 0}, 1984: {'mean': 0.9489996526915718, 'std': 0.007763503044850648, 'count': 293, 'outliers_removed': 7}, 1987: {'mean': 0.5638266694527997, 'std': 0.3568934197513538, 'count': 300, 'outliers_removed': 0}, 1990: {'mean': 0.9468886209694438, 'std': 0.008180879318244218, 'count': 238, 'outliers_removed': 62}, 1993: {'mean': 0.8963790704023133, 'std': 0.026332800392972883, 'count': 294, 'outliers_removed': 6}, 1996: {'mean': 0.96160556844962, 'std': 0.0015979699910228322, 'count': 285, 'outliers_removed': 15}, 1999: {'mean': 0.6371070403170852, 'std': 0.18268831354287002, 'count': 300, 'outliers_removed': 0}, 2002: {'mean': 0.9231582919991893, 'std': 0.0063942522421630435, 'count': 262, 'outliers_removed': 38}, 2005: {'mean': 0.902629890310167, 'std': 0.01104925900678765, 'count': 282, 'outliers_removed': 18}, 2008: {'mean': 0.9554389152021222, 'std': 0.009868318136353057, 'count': 280, 'outliers_removed': 20}, 2011: {'mean': 0.954579524379493, 'std': 0.011689952638058864, 'count': 262, 'outliers_removed': 38}, 2014: {'mean': 0.8921761006576353, 'std': 0.10189211757518568, 'count': 299, 'outliers_removed': 1}, 2017: {'mean': 0.96602179216484, 'std': 0.0067153352826573405, 'count': 293, 'outliers_removed': 7}}

# %%
ellipsoid_statistics
# Out:
# {1927: {'mean': 0.9628516217668466,
#   'std': 0.02705758486567207,
#   'count': 242,
#   'outliers_removed': 58},
#  1930: {'mean': 0.9354490645888937,
#   'std': 0.011128621926570912,
#   'count': 255,
#   'outliers_removed': 45},
#  1933: {'mean': 0.9368883146688073,
#   'std': 0.03736326130107567,
#   'count': 285,
#   'outliers_removed': 15},
#  1936: {'mean': 0.7769625476857114,
#   'std': 0.16690316221088472,
#   'count': 300,
#   'outliers_removed': 0},
#  1939: {'mean': 0.884204496293467,
#   'std': 0.051798271949189366,
#   'count': 294,
#   'outliers_removed': 6},
#  1942: {'mean': 0.9358919090421931,
#   'std': 0.013503347354315274,
#   'count': 280,
#   'outliers_removed': 20},
#  1945: {'mean': 0.9227506912010905,
#   'std': 0.004528300022284554,
#   'count': 299,
#   'outliers_removed': 1},
#  1948: {'mean': 0.8122248524814942,
#   'std': 0.020650059533483606,
#   'count': 285,
#   'outliers_removed': 15},
#  1951: {'mean': 0.9314986888893468,
#   'std': 0.008593192133901556,
#   'count': 291,
#   'outliers_removed': 9},
#  1954: {'mean': 0.938856293551688,
#   'std': 0.010495984233868971,
#   'count': 284,
#   'outliers_removed': 16},
#  1957: {'mean': 0.9401149506616112,
#   'std': 0.01516516534828248,
#   'count': 246,
#   'outliers_removed': 54},
#  1960: {'mean': 0.9476099549900583,
#   'std': 0.010661303522646041,
#   'count': 288,
#   'outliers_removed': 12},
#  1963: {'mean': 0.7746780300157448,
#   'std': 0.24539569953076668,
#   'count': 300,
#   'outliers_removed': 0},
#  1966: {'mean': 0.9388970520115699,
#   'std': 0.012385259104776532,
#   'count': 227,
#   'outliers_removed': 73},
#  1969: {'mean': 0.9468652728662186,
#   'std': 0.005743961250993913,
#   'count': 299,
#   'outliers_removed': 1},
#  1972: {'mean': 0.9221583419929575,
#   'std': 0.026579857948507264,
#   'count': 253,
#   'outliers_removed': 47},
#  1975: {'mean': 0.8850979889286861,
#   'std': 0.030204639619596758,
#   'count': 295,
#   'outliers_removed': 5},
#  1978: {'mean': 0.95175037907001,
#   'std': 0.012669125488779806,
#   'count': 247,
#   'outliers_removed': 53},
#  1981: {'mean': 0.6017257904337577,
#   'std': 0.18796819763668554,
#   'count': 300,
#   'outliers_removed': 0},
#  1984: {'mean': 0.9489996526915718,
#   'std': 0.007763503044850648,
#   'count': 293,
#   'outliers_removed': 7},
#  1987: {'mean': 0.5638266694527997,
#   'std': 0.3568934197513538,
#   'count': 300,
#   'outliers_removed': 0},
#  1990: {'mean': 0.9468886209694438,
#   'std': 0.008180879318244218,
#   'count': 238,
#   'outliers_removed': 62},
#  1993: {'mean': 0.8963790704023133,
#   'std': 0.026332800392972883,
#   'count': 294,
#   'outliers_removed': 6},
#  1996: {'mean': 0.96160556844962,
#   'std': 0.0015979699910228322,
#   'count': 285,
#   'outliers_removed': 15},
#  1999: {'mean': 0.6371070403170852,
#   'std': 0.18268831354287002,
#   'count': 300,
#   'outliers_removed': 0},
#  2002: {'mean': 0.9231582919991893,
#   'std': 0.0063942522421630435,
#   'count': 262,
#   'outliers_removed': 38},
#  2005: {'mean': 0.902629890310167,
#   'std': 0.01104925900678765,
#   'count': 282,
#   'outliers_removed': 18},
#  2008: {'mean': 0.9554389152021222,
#   'std': 0.009868318136353057,
#   'count': 280,
#   'outliers_removed': 20},
#  2011: {'mean': 0.954579524379493,
#   'std': 0.011689952638058864,
#   'count': 262,
#   'outliers_removed': 38},
#  2014: {'mean': 0.8921761006576353,
#   'std': 0.10189211757518568,
#   'count': 299,
#   'outliers_removed': 1},
#  2017: {'mean': 0.96602179216484,
#   'std': 0.0067153352826573405,
#   'count': 293,
#   'outliers_removed': 7}}

# %%
ellipsoid_mean = []
ellipsoid_std = []
for i in ellipsoid_data_id:
    ellipsoid_mean.append(ellipsoid_statistics[i]['mean'])
    ellipsoid_std.append(ellipsoid_statistics[i]['std'])

# %%
# Extract mean data for fitting
x_data = gate_fidelity.mean(axis=1)
ellipsoid_y_data = ellipsoid_mean
ellipsoid_y_err = ellipsoid_std

# Fit with polynomial (1st order = linear fit)
p = Polynomial.fit(x_data, ellipsoid_y_data, 1)
ellipsoid_x_fit = np.linspace(x_data.min(), x_data.max()+0.1, 100)
ellipsoid_y_fit = p(ellipsoid_x_fit)

# Plot data points with green color and error bars
plt.errorbar(x_data, ellipsoid_y_data, ellipsoid_y_err,
                    linestyle='none', fmt='o', markersize=4, markerfacecolor='blue', 
                    markeredgecolor='blue', ecolor='blue', elinewidth=2, capsize=4, capthick=1.2)

# Plot fitting line as dashed line
plt.plot(ellipsoid_x_fit, ellipsoid_y_fit, 'b--', linewidth=2, label='Linear Fit')
plt.xlim(0.85,1.0)
plt.ylim(0.7,1)
plt.xlabel('Gate Fidelity(%)')
plt.ylabel('Robustness')
plt.show()

# %%
# Plot data points with green color and error bars
plt.errorbar(x_data, QPT_y_data, QPT_y_err,
                    linestyle='none', fmt='o', markersize=4, markerfacecolor='green', 
                    markeredgecolor='green', ecolor='green', elinewidth=2, capsize=4, capthick=1.2)

# Plot fitting line as dashed line
plt.plot(QPT_x_fit, QPT_y_fit, 'g--', linewidth=2, label='Linear Fit')

# Plot data points with green color and error bars
plt.errorbar(x_data, ellipsoid_y_data, ellipsoid_y_err,
                    linestyle='none', fmt='o', markersize=4, markerfacecolor='blue', 
                    markeredgecolor='blue', ecolor='blue', elinewidth=2, capsize=4, capthick=1.2)

# Plot fitting line as dashed line
plt.plot(ellipsoid_x_fit, ellipsoid_y_fit, 'b--', linewidth=2, label='Linear Fit')

plt.xlim(0.85,1.0)
plt.ylim(0.7,1)
plt.xlabel('Gate Fidelity(%)')
plt.ylabel('Robustness')
plt.show()

# %%
# Filter both QPT and ellipsoid data based on ellipsoid error bars
ellipsoid_y_err_array = np.array(ellipsoid_y_err)
x_data_array = np.array(x_data)
ellipsoid_y_data_array = np.array(ellipsoid_y_data)
QPT_y_data_array = np.array(QPT_y_data)
QPT_y_err_array = np.array(QPT_y_err)

# Define threshold for error bar - keep points with std below the median + 0.45 std dev
err_threshold = np.median(ellipsoid_y_err_array) + 0.45*np.std(ellipsoid_y_err_array)
print(f"Error bar threshold (based on ellipsoid): {err_threshold:.6f}")
print(f"Median error: {np.median(ellipsoid_y_err_array):.6f}")
print(f"Std of errors: {np.std(ellipsoid_y_err_array):.6f}")

# Filter mask based on ellipsoid error bars
mask = ellipsoid_y_err_array <= err_threshold

# Apply same mask to both datasets
filtered_x = x_data_array[mask]
filtered_ellipsoid_y = ellipsoid_y_data_array[mask]
filtered_ellipsoid_err = ellipsoid_y_err_array[mask]
filtered_QPT_y = QPT_y_data_array[mask]
filtered_QPT_err = QPT_y_err_array[mask]

print(f"\nFiltering results:")
print(f"  Original data points: {len(x_data_array)}")
print(f"  Filtered data points: {len(filtered_x)}")
print(f"  Removed: {len(x_data_array) - len(filtered_x)} ({100*(1-len(filtered_x)/len(x_data_array)):.1f}%)")

# Fit both datasets with the filtered data
p_QPT_filtered = Polynomial.fit(filtered_x, filtered_QPT_y, 1)
p_ellipsoid_filtered = Polynomial.fit(filtered_x, filtered_ellipsoid_y, 1)
x_fit_filtered = np.linspace(x_data_array.min(), x_data_array.max()+0.1, 100)
QPT_y_fit_filtered = p_QPT_filtered(x_fit_filtered)
ellipsoid_y_fit_filtered = p_ellipsoid_filtered(x_fit_filtered)

print(f"\nFit comparison (Original vs Filtered):")
print(f"  QPT:")
print(f"    Original:  y = {p.coef[1]:.4f}*x + {p.coef[0]:.4f}")
print(f"    Filtered:  y = {p_QPT_filtered.coef[1]:.4f}*x + {p_QPT_filtered.coef[0]:.4f}")
print(f"  Ellipsoid:")
print(f"    Original:  y = {p.coef[1]:.4f}*x + {p.coef[0]:.4f}")
print(f"    Filtered:  y = {p_ellipsoid_filtered.coef[1]:.4f}*x + {p_ellipsoid_filtered.coef[0]:.4f}")

# Plot comparison
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Original data
ax1.errorbar(x_data, QPT_y_data, QPT_y_err,
                    linestyle='none', fmt='o', markersize=4, markerfacecolor='green', 
                    markeredgecolor='green', ecolor='green', elinewidth=2, capsize=4, capthick=1.2,
                    label='QPT Data')
ax1.plot(QPT_x_fit, QPT_y_fit, 'g--', linewidth=2, label='QPT Fit')

ax1.errorbar(x_data, ellipsoid_y_data, ellipsoid_y_err,
                    linestyle='none', fmt='s', markersize=4, markerfacecolor='blue', 
                    markeredgecolor='blue', ecolor='blue', elinewidth=2, capsize=4, capthick=1.2,
                    label='Ellipsoid Data (All)')
ax1.plot(ellipsoid_x_fit, ellipsoid_y_fit, 'b--', linewidth=2, label='Ellipsoid Fit (All)')

ax1.set_xlim(0.85, 1.0)
ax1.set_ylim(0.7, 1)
ax1.set_xlabel('Gate Fidelity', fontsize=11)
ax1.set_ylabel('Robustness', fontsize=11)
ax1.set_title('Original Data (All Points)', fontsize=12, fontweight='bold')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=9)

# Filtered data (both QPT and ellipsoid)
ax2.errorbar(filtered_x, filtered_QPT_y, filtered_QPT_err,
                    linestyle='none', fmt='o', markersize=5, markerfacecolor='green', 
                    markeredgecolor='green', ecolor='green', elinewidth=2, capsize=4, capthick=1.2,
                    label='QPT Data (Filtered)')
ax2.plot(x_fit_filtered, QPT_y_fit_filtered, 'g--', linewidth=2, label='QPT Fit (Filtered)')

ax2.errorbar(filtered_x, filtered_ellipsoid_y, filtered_ellipsoid_err,
                    linestyle='none', fmt='s', markersize=5, markerfacecolor='red', 
                    markeredgecolor='red', ecolor='red', elinewidth=2, capsize=4, capthick=1.2,
                    label='Ellipsoid Data (Filtered)')
ax2.plot(x_fit_filtered, ellipsoid_y_fit_filtered, 'r--', linewidth=2, label='Ellipsoid Fit (Filtered)')

# Show removed points in gray
removed_mask = ~mask
ax2.errorbar(x_data_array[removed_mask], ellipsoid_y_data_array[removed_mask], ellipsoid_y_err_array[removed_mask],
                    linestyle='none', fmt='x', markersize=6, color='gray', ecolor='gray', elinewidth=1, capsize=3,
                    alpha=0.5, label='Removed Points (by ellipsoid error bar)')

ax2.set_xlim(0.85, 1.0)
ax2.set_ylim(0.7, 1)
ax2.set_xlabel('Gate Fidelity', fontsize=11)
ax2.set_ylabel('Robustness', fontsize=11)
ax2.set_title('Filtered Data (Removed by Ellipsoid Error Bar)', fontsize=12, fontweight='bold')
ax2.grid(True, alpha=0.3)
ax2.legend(fontsize=9)

plt.tight_layout()
plt.show()

print(f"\nFiltered data statistics:")
print(f"  QPT (filtered) - Mean: {filtered_QPT_y.mean():.6f}, Std: {filtered_QPT_err.mean():.6f}")
print(f"  Ellipsoid (filtered) - Mean: {filtered_ellipsoid_y.mean():.6f}, Std: {filtered_ellipsoid_err.mean():.6f}")
# Out:
# Error bar threshold (based on ellipsoid): 0.050420
# Median error: 0.012669
# Std of errors: 0.083891
#
# Filtering results:
#   Original data points: 31
#   Filtered data points: 24
#   Removed: 7 (22.6%)
#
# Fit comparison (Original vs Filtered):
#   QPT:
#     Original:  y = 0.0377*x + 0.8773
#     Filtered:  y = 0.2039*x + 0.7410
#   Ellipsoid:
#     Original:  y = 0.0377*x + 0.8773
#     Filtered:  y = 0.0034*x + 0.9309
# Filtered data statistics:
#   QPT (filtered) - Mean: 0.799609, Std: 0.007413
#   Ellipsoid (filtered) - Mean: 0.931859, Std: 0.014013

# %%
filtered_x = 100*filtered_x  
x_fit_filtered = 100*x_fit_filtered

# %%
fig, ax2 = plt.subplots(1, 1, figsize=(8, 6))

# Filtered data (both QPT and ellipsoid)
ax2.errorbar(filtered_x, filtered_QPT_y, filtered_QPT_err,
                    linestyle='none', fmt='o', markersize=5, markerfacecolor='green', 
                    markeredgecolor='green', ecolor='green', elinewidth=2, capsize=4, capthick=1.2,
                    label='QPT Data')
ax2.plot(x_fit_filtered, QPT_y_fit_filtered, 'g--', linewidth=2, label='QPT Fit')

ax2.errorbar(filtered_x, filtered_ellipsoid_y, filtered_ellipsoid_err,
                    linestyle='none', fmt='s', markersize=5, markerfacecolor='red', 
                    markeredgecolor='red', ecolor='red', elinewidth=2, capsize=4, capthick=1.2,
                    label='Ellipsoid Data')
ax2.plot(x_fit_filtered, ellipsoid_y_fit_filtered, 'r--', linewidth=2, label='Ellipsoid Fit')

ax2.set_xlim(85.5, 100)
ax2.set_ylim(0.7, 1)
ax2.set_xlabel('Gate Fidelity (%)', fontsize=16)
ax2.set_ylabel('Robustness', fontsize=16)
ax2.tick_params(axis='x', labelsize=13) 
ax2.tick_params(axis='y', labelsize=13) 
ax2.set_xticks([86,89,92,95,98])
ax2.set_yticks([0.74,0.81, 0.89,0.97])
ax2.grid(True, alpha=0.3)
ax2.legend(fontsize=14)

plt.tight_layout()
plt.show()

# Print fitted results
print(f"\n{'='*60}")
print(f"Fitted Results (Filtered Data)")
print(f"{'='*60}")
print(f"\nQPT (x in percentage scale [85, 100]):")
a_QPT = p_QPT_filtered.coef[1] / 100
b_QPT = p_QPT_filtered.coef[0]
print(f"  y = {a_QPT:.6f} * x + {b_QPT:.6f}")
print(f"  OR: y = {p_QPT_filtered.coef[1]:.6f} * x + {b_QPT:.6f}  (x in [0, 1])")

print(f"\nEllipsoid (x in percentage scale [85, 100]):")
a_ellipsoid = p_ellipsoid_filtered.coef[1] / 100
b_ellipsoid = p_ellipsoid_filtered.coef[0]
print(f"  y = {a_ellipsoid:.6f} * x + {b_ellipsoid:.6f}")
print(f"  OR: y = {p_ellipsoid_filtered.coef[1]:.6f} * x + {b_ellipsoid:.6f}  (x in [0, 1])")
print(f"{'='*60}\n")

# fig.savefig(
#     "/Users/jackchao/Desktop/Project/Phd_thesis/CH5_5GZdemonstration/data/Quantum_memory/paper_fig/Fig2_referee.pdf",
#     dpi=300,
#     bbox_inches="tight",
#     transparent=True,
#     facecolor="none",   
# )
# Out:
# ============================================================
# Fitted Results (Filtered Data)
# ============================================================
#
# QPT (x in percentage scale [85, 100]):
#   y = 0.002039 * x + 0.740952
#   OR: y = 0.203940 * x + 0.740952  (x in [0, 1])
#
# Ellipsoid (x in percentage scale [85, 100]):
#   y = 0.000034 * x + 0.930885
#   OR: y = 0.003386 * x + 0.930885  (x in [0, 1])
# ============================================================

# %%
import pandas as pd

# Create DataFrame from unfiltered (original) data
# Note: x_data_array is in decimal scale (0.85-1.0)
amps = np.arange(1,1.3,0.01)
df_unfiltered = pd.DataFrame({
    "amps": amps,
    'gate_fidelity': x_data_array,
    'ellipsoid_robustness': ellipsoid_y_data_array,
    'QPT_robustness': QPT_y_data_array,
    'ellipsoid_robustness_std': ellipsoid_y_err_array,
    'QPT_robustness_std': QPT_y_err_array
})

print("Unfiltered Data DataFrame:")
print(df_unfiltered)
print(f"\nDataFrame shape: {df_unfiltered.shape}")
print(f"\nData types:\n{df_unfiltered.dtypes}")

# Save to CSV
csv_path = "/Users/jackchao/Desktop/Project/Phd_thesis/CH5_5GZdemonstration/data/Quantum_memory_referee/300QPT10000_ellipsoid190_robustness_data.csv"
df_unfiltered.to_csv(csv_path, index=False)
print(f"\nDataFrame saved to: {csv_path}")

# Display summary statistics
print(f"\nSummary Statistics:")
print(df_unfiltered.describe())
# Out:
# Unfiltered Data DataFrame:
#     amps  gate_fidelity  ellipsoid_robustness  QPT_robustness  \
# 0   1.00       0.995448              0.952819        0.955831
# 1   1.01       0.854146              0.937105        0.634708
# 2   1.02       0.971409              0.926658        0.843343
# 3   1.03       0.951870              0.709703        0.864001
# 4   1.04       0.976544              0.874777        0.887601
# 5   1.05       0.985238              0.929595        0.911132
# 6   1.06       0.973002              0.924845        0.901972
# 7   1.07       0.935571              0.816284        0.801541
# 8   1.08       0.932914              0.936463        0.792101
# 9   1.09       0.936893              0.937096        0.854960
# 10  1.10       0.974226              0.915714        0.921125
# 11  1.11       0.934555              0.950547        0.781541
# 12  1.12       0.941803              0.762039        0.857212
# 13  1.13       0.959658              0.940865        0.898254
# 14  1.14       0.946789              0.948007        0.880986
# 15  1.15       0.943501              0.926264        0.874905
# 16  1.16       0.804308              0.887716        0.662626
# 17  1.17       0.871180              0.950877        0.738016
# 18  1.18       0.779954              0.631671        0.591596
# 19  1.19       0.909923              0.949882        0.841872
# 20  1.20       0.898257              0.477415        0.826958
# 21  1.21       0.903501              0.949604        0.845656
# 22  1.22       0.891809              0.893498        0.834579
# 23  1.23       0.888935              0.962397        0.832853
# 24  1.24       0.842980              0.656097        0.764182
# 25  1.25       0.860898              0.923243        0.808678
# 26  1.26       0.733260              0.900453        0.375691
# 27  1.27       0.848694              0.958759        0.805567
# 28  1.28       0.799182              0.955527        0.677814
# 29  1.29       0.798626              0.958966        0.687828
# 30  1.30       0.792459              0.963828        0.711649
#
#     ellipsoid_robustness_std  QPT_robustness_std
# 0                   0.048980            0.008879
# 1                   0.008905            0.011103
# 2                   0.046078            0.008848
# 3                   0.147919            0.007599
# 4                   0.051119            0.007295
# 5                   0.014588            0.006713
# 6                   0.002540            0.006408
# 7                   0.013795            0.007250
# 8                   0.002332            0.008718
# 9                   0.005603            0.007691
# 10                  0.036675            0.006759
# 11                  0.010369            0.006931
# 12                  0.255653            0.006511
# 13                  0.007046            0.006345
# 14                  0.003390            0.006639
# 15                  0.018779            0.006640
# 16                  0.022354            0.007508
# 17                  0.012638            0.007734
# 18                  0.174903            0.007164
# 19                  0.004990            0.006315
# 20                  0.339035            0.006822
# 21                  0.003630            0.006591
# 22                  0.018331            0.006763
# 23                  0.000758            0.006727
# 24                  0.145381            0.007384
# 25                  0.004683            0.007070
# 26                  0.006797            0.008050
# 27                  0.007929            0.007409
# 28                  0.008476            0.007401
# 29                  0.010083            0.006741
# 30                  0.005686            0.007266
#
# DataFrame shape: (31, 6)
#
# Data types:
# amps                        float64
# gate_fidelity               float64
# ellipsoid_robustness        float64
# QPT_robustness              float64
# ellipsoid_robustness_std    float64
# QPT_robustness_std          float64
# dtype: object
#
# DataFrame saved to: /Users/jackchao/Desktop/Project/Phd_thesis/CH5_5GZdemonstration/data/Quantum_memory_referee/300QPT10000_ellipsoid190_robustness_data.csv
#
# Summary Statistics:
#             amps  gate_fidelity  ellipsoid_robustness  QPT_robustness  \
# count  31.000000      31.000000             31.000000       31.000000
# mean    1.150000       0.897985              0.884152        0.795703
# std     0.090921       0.070488              0.116614        0.118372
# min     1.000000       0.733260              0.477415        0.375691
# 25%     1.075000       0.851420              0.890607        0.751099
# 50%     1.150000       0.909923              0.929595        0.832853
# 75%     1.225000       0.949329              0.950215        0.869453
# max     1.300000       0.995448              0.963828        0.955831
#
#        ellipsoid_robustness_std  QPT_robustness_std
# count                 31.000000           31.000000
# mean                   0.046434            0.007331
# std                    0.081234            0.000985
# min                    0.000758            0.006315
# 25%                    0.005644            0.006720
# 50%                    0.010369            0.007164
# 75%                    0.041376            0.007554
# max                    0.339035            0.011103
