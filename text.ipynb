# %%
from qualibrate import QualibrationNode
from pathlib import Path
# Out:
# 2026-02-12 15:44:14,773 - qm - INFO     - Starting session: 28be2bf9-7394-4688-8730-4a8505c37dbf

# %%
node  = QualibrationNode(name="QPT_vs_ellipsoid")
QPT_ellipsoid_data_path = Path("/Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/data/QPT_vs_ellipsoid")
# Out:
# 2026-02-12 15:44:20,402 - qualibrate - INFO - Creating node QPT_vs_ellipsoid

# %%
QPT = node.load_from_id(1926, base_path=QPT_ellipsoid_data_path)

# %%
QPT.results['ds']
# Out:
# <xarray.Dataset> Size: 560kB
# Dimensions:        (qubit: 1, N: 10000, initial_state: 4, axis: 3)
# Coordinates:
#   * qubit          (qubit) object 8B 'q0'
#   * N              (N) float64 80kB 1.0 2.0 3.0 ... 9.998e+03 9.999e+03 1e+04
#   * initial_state  (initial_state) object 32B '0' '1' '+' 'i+'
#   * axis           (axis) object 24B 'x' 'y' 'z'
# Data variables:
#     state          (qubit, N, initial_state, axis) int32 480kB ...
