# %%
from qualibrate import QualibrationNode
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2026-03-05 22:53:57,429 - qm - INFO     - Starting session: 831925af-d6e4-4b19-a1ba-d62a47c1914f

# %%
node  = QualibrationNode(name="quantum_memory_swapping")
# Out:
# 2026-03-05 22:53:58,574 - qualibrate - INFO - Creating node quantum_memory_swapping

# %%
non_Markovian_data = {
    'raw':{
    },
    'mle':{
    },
    'sim_raw':{
    },
    'sim_mle':{
    },
    'qpt':{
        
    }
}

# %%
from pathlib import Path
data_path = Path("data/non_Markovian").resolve()

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Raw

# %% [markdown]
# ### Experimental

# %%
non_Markovian_experiment_index = [1764,1765,1766,1767,1768,1769,1770,1771,1772,1773,1774,1775,1776,1777,1778,1779,1780,1781,1782,1783,1784,1785,1786,1787,1788,1789,1790,1791,1792,1793,1794,1795,1796,1797,1798,1799,1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819]
interaction_time = np.arange(0,111,2)

# %%
non_Markovian_ds ={
    f'interaction_time={interaction_time[i]}ns':node.load_from_id(non_Markovian_experiment_index[i],base_path=data_path).results['ds']
    for i in range(len(non_Markovian_experiment_index))
}
non_Markovian_key = non_Markovian_ds.keys()

# %%
from quam_libs.QI_utils import bloch_vector_to_density_matrix
from quam_libs.analyzer import QuantumMemoryAnalyze, EllipsoidFitParameters

fit_params = EllipsoidFitParameters(
    filter_method="convex",      # "none" | "convex" | "ransac"
    correct_rotation_orientation =True,
    find_best_order=False
)

# %%
'''
Data processing: raw data to quantum information data
Step1: convert bloch vector to density matrix and make sure its valid
Step2: fit the bloch vector data to get the ellipsoid parameters
Step3: construct the choi state from the fitted ellipsoid parameters, and calculate the robustness of memory
'''
non_Markovian_data_raw = {}
non_Markovian_analyze_raw={}
do_convex_hull = True
for i, key in enumerate(non_Markovian_key):
    ds = non_Markovian_ds[key]
    data_xyz = np.array([[ds.Bloch_vector_x.values[0][i], ds.Bloch_vector_y.values[0][i], ds.Bloch_vector_z.values[0][i]] for i in range(len(ds.n_points.values))])
    data_angle = np.array([[ds.theta.values[i], ds.phi.values[i]] for i in range(len(ds.n_points.values))])
    data_dm = np.array([bloch_vector_to_density_matrix(data_xyz[i]) for i in range(len(data_xyz))])

    noise_analyzer = QuantumMemoryAnalyze(data_xyz,data_angle,fit_params)
    corrected_dm = noise_analyzer.corrected_dm
    corrected_bloch = noise_analyzer.corrected_bloch
    ellipsoid_results = noise_analyzer.ellipsoid_fit_results()
    # Get choi state from the property
    choi_state = noise_analyzer.choi
    # Compute robustness using the static method
    robustness_value = QuantumMemoryAnalyze.memory_robustness(choi_state)
    non_Markovian_data_raw[key] = {
        'data':{
            'original_xyz': data_xyz,
            'original_dm' :data_dm,
            'angle': data_angle,
            'corrected_xyz': corrected_bloch,
            'corrected_dm': corrected_dm
        },
        'ellipsoid':{
            'axes':ellipsoid_results['axes'],
            'center':ellipsoid_results['center'],
            'volume':ellipsoid_results['volume'],
            'param':ellipsoid_results['fit_param'],
            "rotation_matrix":ellipsoid_results['rotation_matrix'],
        },
        "quantum_information":{
            "choi":choi_state,
            "robustness":robustness_value
        }
    }
    non_Markovian_analyze_raw[key] = noise_analyzer

# %% [markdown]
# #### find the best fit

# %% [markdown]
# by constructing choi state via different order of eigen vector, we calculate the robustness to find the best fit.

# %%
import itertools
from quam_libs.macros import ellipsoid_to_quadric

# Reload the module to get the updated staticmethod definition
import importlib
import quam_libs.analyzer
importlib.reload(quam_libs.analyzer)
from quam_libs.analyzer import QuantumMemoryAnalyze

np.set_printoptions(precision=3, suppress=True)

keys = non_Markovian_data_raw.keys()
perm_robustness_dict = {}
for i in range(1):
    for key in keys:
        print(f"Results for {key}:")
        R = non_Markovian_data_raw[key]['ellipsoid']['rotation_matrix']
        center = non_Markovian_data_raw[key]['ellipsoid']['center']
        axes = non_Markovian_data_raw[key]['ellipsoid']['axes']
        print(f"R for {key}:\n{R}")
        print(f"Center for {key}:\n{center}")
        print(f"Axes for {key}:\n{axes}")
        
        # Compute Choi state from ellipsoid parameters
        choi = QuantumMemoryAnalyze.choi_state(center, axes, R)
        correct_choi = QuantumMemoryAnalyze.correct_choi(choi)
        # Recompute robustness from the Choi state using static method
        robustness = QuantumMemoryAnalyze.memory_robustness(correct_choi)
        print(f"Quantum robustness for {key}: {robustness:.3f}")
        print('-'*75)

        perms = list(itertools.permutations([0,1,2]))
        perm_robustness_dict[key] = {}
        for perm in np.array(perms):
            # Properly permute rotation matrix columns to match axes permutation
            R_perm = non_Markovian_data_raw[key]['ellipsoid']['rotation_matrix'][:, perm]
            axes_perm = non_Markovian_data_raw[key]['ellipsoid']['axes'][perm]
            
            # Compute robustness for this permutation
            choi_perm = QuantumMemoryAnalyze.choi_state(center, axes_perm, R_perm)
            correct_choi_perm = QuantumMemoryAnalyze.correct_choi(choi_perm)
            robustness_perm = QuantumMemoryAnalyze.memory_robustness(correct_choi_perm)
            
            perm_robustness_dict[key][tuple(perm)] = robustness_perm
            print(f"Permutation {perm} robustness: {robustness_perm:.3f}")
        
        # Find permutation with maximum robustness
        max_perm = list(max(perm_robustness_dict[key], key=perm_robustness_dict[key].get))
        print(f"Best permutation {max_perm} with robustness {perm_robustness_dict[key][tuple(max_perm)]:.3f}")

        # Apply best permutation to rotation matrix columns
        R = R[:, max_perm]
        axes = axes[max_perm]
        if np.linalg.det(R) < 0:
            R[:,2]*=-1 
        print(f'after swap')
        print(f"R for {key}:\n{R} and det(R) = {np.linalg.det(R)}")
        print(f"Center for {key}:\n{center}")
        print(f"Axes for {key}:\n{axes}")
        choi = QuantumMemoryAnalyze.choi_state(center, axes, R)
        correct_choi = QuantumMemoryAnalyze.correct_choi(choi)
        robustness = QuantumMemoryAnalyze.memory_robustness(correct_choi)
        print(f"Robustness for {key}: {robustness:.3f}")
        print(f"Choi state for {key}:\n{correct_choi}")
        print('-'*100)
        non_Markovian_data_raw[key]['ellipsoid']['rotation_matrix'] = R
        non_Markovian_data_raw[key]['ellipsoid']['axes'] = axes
        non_Markovian_data_raw[key]['ellipsoid']['center'] = center
        non_Markovian_data_raw[key]['quantum_information']['robustness'] = robustness
        non_Markovian_data_raw[key]['quantum_information']['choi'] = correct_choi
# Out:
# Results for interaction_time=0ns:
# R for interaction_time=0ns:
# [[ 0.41   0.365 -0.836]
#  [ 0.664 -0.748 -0.   ]
#  [-0.625 -0.555 -0.549]]
# Center for interaction_time=0ns:
# [0.024 0.024 0.03 ]
# Axes for interaction_time=0ns:
# [0.722 0.631 0.665]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=0ns: 0.472
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.472
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.255
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.420
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.472
# after swap
# R for interaction_time=0ns:
# [[ 0.41   0.365 -0.836]
#  [ 0.664 -0.748 -0.   ]
#  [-0.625 -0.555 -0.549]] and det(R) = 0.9999999999999999
# Center for interaction_time=0ns:
# [0.024 0.024 0.03 ]
# Axes for interaction_time=0ns:
# [0.722 0.631 0.665]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=0ns: 0.472
# Choi state for interaction_time=0ns:
# [[ 0.166+0.j    -0.12 +0.038j -0.126-0.044j -0.044+0.j   ]
#  [-0.12 -0.038j  0.334+0.j     0.192+0.177j  0.126+0.044j]
#  [-0.126+0.044j  0.192-0.177j  0.349+0.j     0.132-0.05j ]
#  [-0.044-0.j     0.126-0.044j  0.132+0.05j   0.151+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=2ns:
# R for interaction_time=2ns:
# [[-0.713  0.701 -0.013]
#  [ 0.565  0.585  0.581]
#  [ 0.415  0.406 -0.814]]
# Center for interaction_time=2ns:
# [0.025 0.024 0.046]
# Axes for interaction_time=2ns:
# [0.635 0.674 0.699]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=2ns: 0.485
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.485
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain_utils.py:30: UserWarning: The problem includes expressions that don't support CPP backend. Defaulting to the SCIPY backend for canonicalization.
#   warnings.warn(UserWarning(
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.072
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.485
# after swap
# R for interaction_time=2ns:
# [[-0.713  0.701 -0.013]
#  [ 0.565  0.585  0.581]
#  [ 0.415  0.406 -0.814]] and det(R) = 1.0000000000000002
# Center for interaction_time=2ns:
# [0.025 0.024 0.046]
# Axes for interaction_time=2ns:
# [0.635 0.674 0.699]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=2ns: 0.485
# Choi state for interaction_time=2ns:
# [[ 0.119+0.j     0.038-0.091j  0.032+0.085j -0.014-0.j   ]
#  [ 0.038+0.091j  0.381+0.j    -0.212+0.208j -0.032-0.085j]
#  [ 0.032-0.085j -0.212-0.208j  0.404+0.j    -0.026+0.079j]
#  [-0.014+0.j    -0.032+0.085j -0.026-0.079j  0.096+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=4ns:
# R for interaction_time=4ns:
# [[-0.735  0.677  0.041]
#  [ 0.581  0.598  0.552]
#  [ 0.349  0.43  -0.833]]
# Center for interaction_time=4ns:
# [0.023 0.024 0.05 ]
# Axes for interaction_time=4ns:
# [0.624 0.655 0.696]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=4ns: 0.477
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.477
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.023
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.477
# after swap
# R for interaction_time=4ns:
# [[-0.735  0.677  0.041]
#  [ 0.581  0.598  0.552]
#  [ 0.349  0.43  -0.833]] and det(R) = 1.0
# Center for interaction_time=4ns:
# [0.023 0.024 0.05 ]
# Axes for interaction_time=4ns:
# [0.624 0.655 0.696]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=4ns: 0.477
# Choi state for interaction_time=4ns:
# [[ 0.118+0.j     0.037-0.089j  0.031+0.083j -0.017-0.j   ]
#  [ 0.037+0.089j  0.382+0.j    -0.213+0.201j -0.031-0.083j]
#  [ 0.031-0.083j -0.213-0.201j  0.407+0.j    -0.025+0.077j]
#  [-0.017+0.j    -0.031+0.083j -0.025-0.077j  0.093+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=6ns:
# R for interaction_time=6ns:
# [[-0.703  0.711  0.026]
#  [ 0.551  0.521  0.652]
#  [ 0.45   0.472 -0.758]]
# Center for interaction_time=6ns:
# [0.015 0.011 0.065]
# Axes for interaction_time=6ns:
# [0.611 0.637 0.666]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=6ns: 0.437
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.437
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.081
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.437
# after swap
# R for interaction_time=6ns:
# [[-0.703  0.711  0.026]
#  [ 0.551  0.521  0.652]
#  [ 0.45   0.472 -0.758]] and det(R) = 1.0
# Center for interaction_time=6ns:
# [0.015 0.011 0.065]
# Axes for interaction_time=6ns:
# [0.611 0.637 0.666]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=6ns: 0.437
# Choi state for interaction_time=6ns:
# [[ 0.14 +0.j     0.04 -0.095j  0.037+0.092j -0.024+0.j   ]
#  [ 0.04 +0.095j  0.36 +0.j    -0.19 +0.197j -0.037-0.092j]
#  [ 0.037-0.092j -0.19 -0.197j  0.392+0.j    -0.033+0.089j]
#  [-0.024-0.j    -0.037+0.092j -0.033-0.089j  0.108+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=8ns:
# R for interaction_time=8ns:
# [[-0.633 -0.611  0.475]
#  [-0.768  0.569 -0.293]
#  [-0.092 -0.551 -0.83 ]]
# Center for interaction_time=8ns:
# [0.007 0.004 0.115]
# Axes for interaction_time=8ns:
# [0.651 0.575 0.589]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=8ns: 0.375
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.375
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.406
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.360
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [1, 2, 0] with robustness 0.406
# after swap
# R for interaction_time=8ns:
# [[-0.611  0.475 -0.633]
#  [ 0.569 -0.293 -0.768]
#  [-0.551 -0.83  -0.092]] and det(R) = 1.0
# Center for interaction_time=8ns:
# [0.007 0.004 0.115]
# Axes for interaction_time=8ns:
# [0.575 0.589 0.651]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=8ns: 0.406
# Choi state for interaction_time=8ns:
# [[ 0.264+0.j    -0.089+0.123j -0.091-0.124j -0.131-0.j   ]
#  [-0.089-0.123j  0.236+0.j    -0.045+0.152j  0.091+0.124j]
#  [-0.091+0.124j -0.045-0.152j  0.294+0.j     0.093-0.125j]
#  [-0.131+0.j     0.091-0.124j  0.093+0.125j  0.206+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=10ns:
# R for interaction_time=10ns:
# [[ 0.606  0.613 -0.507]
#  [ 0.582  0.093  0.808]
#  [ 0.543 -0.784 -0.301]]
# Center for interaction_time=10ns:
# [0.01  0.012 0.15 ]
# Axes for interaction_time=10ns:
# [0.588 0.527 0.539]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=10ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.041
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.249
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [2, 0, 1] with robustness 0.249
# after swap
# R for interaction_time=10ns:
# [[-0.507  0.606  0.613]
#  [ 0.808  0.582  0.093]
#  [-0.301  0.543 -0.784]] and det(R) = 0.9999999999999998
# Center for interaction_time=10ns:
# [0.01  0.012 0.15 ]
# Axes for interaction_time=10ns:
# [0.539 0.588 0.527]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=10ns: 0.249
# Choi state for interaction_time=10ns:
# [[ 0.184+0.j     0.023-0.049j  0.02 +0.046j  0.017+0.j   ]
#  [ 0.023+0.049j  0.316+0.j    -0.154+0.198j -0.02 -0.046j]
#  [ 0.02 -0.046j -0.154-0.198j  0.391+0.j    -0.018+0.043j]
#  [ 0.017-0.j    -0.02 +0.046j -0.018-0.043j  0.109+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=12ns:
# R for interaction_time=12ns:
# [[-0.652 -0.665  0.364]
#  [-0.744  0.654 -0.138]
#  [-0.147 -0.36  -0.921]]
# Center for interaction_time=12ns:
# [0.002 0.003 0.2  ]
# Axes for interaction_time=12ns:
# [0.552 0.486 0.458]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=12ns: 0.228
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.228
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.236
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.182
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [1, 2, 0] with robustness 0.236
# after swap
# R for interaction_time=12ns:
# [[-0.665  0.364 -0.652]
#  [ 0.654 -0.138 -0.744]
#  [-0.36  -0.921 -0.147]] and det(R) = 0.9999999999999999
# Center for interaction_time=12ns:
# [0.002 0.003 0.2  ]
# Axes for interaction_time=12ns:
# [0.486 0.458 0.552]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=12ns: 0.236
# Choi state for interaction_time=12ns:
# [[ 0.28 +0.j    -0.066+0.103j -0.067-0.104j -0.097+0.j   ]
#  [-0.066-0.103j  0.22 +0.j    -0.065+0.121j  0.067+0.104j]
#  [-0.067+0.104j -0.065-0.121j  0.32 +0.j     0.067-0.105j]
#  [-0.097-0.j     0.067-0.104j  0.067+0.105j  0.18 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=14ns:
# R for interaction_time=14ns:
# [[ 0.623  0.593 -0.511]
#  [ 0.667 -0.743 -0.049]
#  [-0.408 -0.31  -0.858]]
# Center for interaction_time=14ns:
# [-0.008 -0.013  0.228]
# Axes for interaction_time=14ns:
# [0.489 0.423 0.4  ]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=14ns: 0.152
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.152
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.152
# after swap
# R for interaction_time=14ns:
# [[ 0.623  0.593 -0.511]
#  [ 0.667 -0.743 -0.049]
#  [-0.408 -0.31  -0.858]] and det(R) = 0.9999999999999999
# Center for interaction_time=14ns:
# [-0.008 -0.013  0.228]
# Axes for interaction_time=14ns:
# [0.489 0.423 0.4  ]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=14ns: 0.152
# Choi state for interaction_time=14ns:
# [[ 0.221+0.j    -0.052+0.022j -0.051-0.019j -0.002+0.j   ]
#  [-0.052-0.022j  0.279+0.j     0.155+0.144j  0.051+0.019j]
#  [-0.051+0.019j  0.155-0.144j  0.393+0.j     0.049-0.016j]
#  [-0.002-0.j     0.051-0.019j  0.049+0.016j  0.107+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=16ns:
# R for interaction_time=16ns:
# [[ 0.51   0.675 -0.533]
#  [ 0.681 -0.695 -0.23 ]
#  [-0.526 -0.246 -0.814]]
# Center for interaction_time=16ns:
# [-0.021 -0.022  0.246]
# Axes for interaction_time=16ns:
# [0.43  0.354 0.334]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=16ns: 0.063
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.063
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.063
# after swap
# R for interaction_time=16ns:
# [[ 0.51   0.675 -0.533]
#  [ 0.681 -0.695 -0.23 ]
#  [-0.526 -0.246 -0.814]] and det(R) = 1.0000000000000002
# Center for interaction_time=16ns:
# [-0.021 -0.022  0.246]
# Axes for interaction_time=16ns:
# [0.43  0.354 0.334]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=16ns: 0.063
# Choi state for interaction_time=16ns:
# [[ 0.244+0.j    -0.056+0.026j -0.051-0.02j  -0.007+0.j   ]
#  [-0.056-0.026j  0.256+0.j     0.116+0.133j  0.051+0.02j ]
#  [-0.051+0.02j   0.116-0.133j  0.379+0.j     0.045-0.015j]
#  [-0.007-0.j     0.051-0.02j   0.045+0.015j  0.121+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=18ns:
# R for interaction_time=18ns:
# [[ 0.522  0.363 -0.772]
#  [ 0.671  0.385  0.634]
#  [ 0.527 -0.849 -0.042]]
# Center for interaction_time=18ns:
# [-0.011 -0.006  0.275]
# Axes for interaction_time=18ns:
# [0.388 0.318 0.289]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=18ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.013
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [2, 0, 1] with robustness 0.013
# after swap
# R for interaction_time=18ns:
# [[-0.772  0.522  0.363]
#  [ 0.634  0.671  0.385]
#  [-0.042  0.527 -0.849]] and det(R) = 1.0
# Center for interaction_time=18ns:
# [-0.011 -0.006  0.275]
# Axes for interaction_time=18ns:
# [0.289 0.388 0.318]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=18ns: 0.013
# Choi state for interaction_time=18ns:
# [[ 0.251+0.j     0.01 -0.039j  0.013+0.041j  0.009+0.j   ]
#  [ 0.01 +0.039j  0.249+0.j    -0.121+0.096j -0.013-0.041j]
#  [ 0.013-0.041j -0.121-0.096j  0.386+0.j    -0.016+0.042j]
#  [ 0.009-0.j    -0.013+0.041j -0.016-0.042j  0.114+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=20ns:
# R for interaction_time=20ns:
# [[-0.616 -0.634  0.467]
#  [-0.786  0.536 -0.308]
#  [-0.055 -0.557 -0.829]]
# Center for interaction_time=20ns:
# [-0.021 -0.018  0.336]
# Axes for interaction_time=20ns:
# [0.352 0.258 0.231]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=20ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.000
# after swap
# R for interaction_time=20ns:
# [[-0.616 -0.634  0.467]
#  [-0.786  0.536 -0.308]
#  [-0.055 -0.557 -0.829]] and det(R) = 1.0000000000000002
# Center for interaction_time=20ns:
# [-0.021 -0.018  0.336]
# Axes for interaction_time=20ns:
# [0.352 0.258 0.231]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=20ns: 0.000
# Choi state for interaction_time=20ns:
# [[ 0.286+0.j     0.006+0.031j  0.011-0.027j -0.02 +0.j   ]
#  [ 0.006-0.031j  0.214+0.j    -0.089-0.11j  -0.011+0.027j]
#  [ 0.011+0.027j -0.089+0.11j   0.382+0.j    -0.016-0.022j]
#  [-0.02 -0.j    -0.011-0.027j -0.016+0.022j  0.118+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=22ns:
# R for interaction_time=22ns:
# [[-0.686  0.727  0.029]
#  [ 0.509  0.451  0.733]
#  [ 0.52   0.518 -0.679]]
# Center for interaction_time=22ns:
# [-0.002 -0.003  0.346]
# Axes for interaction_time=22ns:
# [0.163 0.218 0.299]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=22ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [2, 0, 1] with robustness 0.000
# after swap
# R for interaction_time=22ns:
# [[ 0.029 -0.686  0.727]
#  [ 0.733  0.509  0.451]
#  [-0.679  0.52   0.518]] and det(R) = 1.0000000000000004
# Center for interaction_time=22ns:
# [-0.002 -0.003  0.346]
# Axes for interaction_time=22ns:
# [0.299 0.163 0.218]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=22ns: 0.000
# Choi state for interaction_time=22ns:
# [[ 0.365+0.j    -0.006-0.022j -0.006+0.023j  0.023-0.j   ]
#  [-0.006+0.022j  0.135+0.j    -0.019+0.027j  0.006-0.023j]
#  [-0.006-0.023j -0.019-0.027j  0.308+0.j     0.005+0.024j]
#  [ 0.023+0.j     0.006+0.023j  0.005-0.024j  0.192+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=24ns:
# R for interaction_time=24ns:
# [[-0.694  0.719  0.041]
#  [ 0.514  0.455  0.727]
#  [ 0.504  0.525 -0.686]]
# Center for interaction_time=24ns:
# [-0.021 -0.022  0.353]
# Axes for interaction_time=24ns:
# [0.11  0.228 0.295]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=24ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.000
# after swap
# R for interaction_time=24ns:
# [[-0.694  0.719  0.041]
#  [ 0.514  0.455  0.727]
#  [ 0.504  0.525 -0.686]] and det(R) = 0.9999999999999998
# Center for interaction_time=24ns:
# [-0.021 -0.022  0.353]
# Axes for interaction_time=24ns:
# [0.11  0.228 0.295]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=24ns: 0.000
# Choi state for interaction_time=24ns:
# [[ 0.288+0.j     0.003-0.036j  0.008+0.042j  0.007+0.j   ]
#  [ 0.003+0.036j  0.212+0.j    -0.045+0.055j -0.008-0.042j]
#  [ 0.008-0.042j -0.045-0.055j  0.389+0.j    -0.014+0.047j]
#  [ 0.007-0.j    -0.008+0.042j -0.014-0.047j  0.111+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=26ns:
# R for interaction_time=26ns:
# [[-0.715  0.7    0.   ]
#  [ 0.59   0.602  0.538]
#  [ 0.376  0.385 -0.843]]
# Center for interaction_time=26ns:
# [ 0.001 -0.008  0.373]
# Axes for interaction_time=26ns:
# [0.064 0.196 0.275]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=26ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.000
# after swap
# R for interaction_time=26ns:
# [[-0.715  0.7    0.   ]
#  [ 0.59   0.602  0.538]
#  [ 0.376  0.385 -0.843]] and det(R) = 0.9999999999999998
# Center for interaction_time=26ns:
# [ 0.001 -0.008  0.373]
# Axes for interaction_time=26ns:
# [0.064 0.196 0.275]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=26ns: 0.000
# Choi state for interaction_time=26ns:
# [[ 0.285+0.j     0.003-0.026j  0.003+0.028j  0.018-0.j   ]
#  [ 0.003+0.026j  0.215+0.j    -0.041+0.044j -0.003-0.028j]
#  [ 0.003-0.028j -0.041-0.044j  0.401+0.j    -0.003+0.03j ]
#  [ 0.018+0.j    -0.003+0.028j -0.003-0.03j   0.099+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=28ns:
# R for interaction_time=28ns:
# [[ 0.689 -0.725 -0.001]
#  [-0.683 -0.649 -0.336]
#  [ 0.243  0.233 -0.942]]
# Center for interaction_time=28ns:
# [0.008 0.005 0.358]
# Axes for interaction_time=28ns:
# [0.092 0.218 0.258]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=28ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [1, 2, 0] with robustness 0.000
# after swap
# R for interaction_time=28ns:
# [[-0.725 -0.001  0.689]
#  [-0.649 -0.336 -0.683]
#  [ 0.233 -0.942  0.243]] and det(R) = 1.0
# Center for interaction_time=28ns:
# [0.008 0.005 0.358]
# Axes for interaction_time=28ns:
# [0.218 0.258 0.092]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=28ns: 0.000
# Choi state for interaction_time=28ns:
# [[ 0.345+0.j     0.016+0.037j  0.014-0.038j -0.061-0.j   ]
#  [ 0.016-0.037j  0.155+0.j    -0.018-0.036j -0.014+0.038j]
#  [ 0.014+0.038j -0.018+0.036j  0.334+0.j    -0.012-0.04j ]
#  [-0.061+0.j    -0.014-0.038j -0.012+0.04j   0.166+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=30ns:
# R for interaction_time=30ns:
# [[-0.784  0.621  0.001]
#  [ 0.417  0.526  0.741]
#  [ 0.459  0.581 -0.672]]
# Center for interaction_time=30ns:
# [0.009 0.003 0.346]
# Axes for interaction_time=30ns:
# [0.166 0.223 0.276]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=30ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.000
# after swap
# R for interaction_time=30ns:
# [[-0.784  0.621  0.001]
#  [ 0.417  0.526  0.741]
#  [ 0.459  0.581 -0.672]] and det(R) = 1.0
# Center for interaction_time=30ns:
# [0.009 0.003 0.346]
# Axes for interaction_time=30ns:
# [0.166 0.223 0.276]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=30ns: 0.000
# Choi state for interaction_time=30ns:
# [[ 0.29 +0.j     0.012-0.043j  0.01 +0.042j -0.003+0.j   ]
#  [ 0.012+0.043j  0.21 +0.j    -0.062+0.052j -0.01 -0.042j]
#  [ 0.01 -0.042j -0.062-0.052j  0.383+0.j    -0.007+0.041j]
#  [-0.003-0.j    -0.01 +0.042j -0.007-0.041j  0.117+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=32ns:
# R for interaction_time=32ns:
# [[-0.59  -0.775  0.225]
#  [-0.801  0.598 -0.042]
#  [-0.102 -0.205 -0.973]]
# Center for interaction_time=32ns:
# [-0.004 -0.015  0.346]
# Axes for interaction_time=32ns:
# [0.36  0.247 0.235]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=32ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.000
# after swap
# R for interaction_time=32ns:
# [[-0.59  -0.775  0.225]
#  [-0.801  0.598 -0.042]
#  [-0.102 -0.205 -0.973]] and det(R) = 1.0
# Center for interaction_time=32ns:
# [-0.004 -0.015  0.346]
# Axes for interaction_time=32ns:
# [0.36  0.247 0.235]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=32ns: 0.000
# Choi state for interaction_time=32ns:
# [[ 0.279+0.j     0.001+0.011j  0.002-0.008j -0.016+0.j   ]
#  [ 0.001-0.011j  0.221+0.j    -0.09 -0.12j  -0.002+0.008j]
#  [ 0.002+0.008j -0.09 +0.12j   0.394+0.j    -0.003-0.004j]
#  [-0.016-0.j    -0.002-0.008j -0.003+0.004j  0.106+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=34ns:
# R for interaction_time=34ns:
# [[-0.769  0.638 -0.046]
#  [ 0.52   0.666  0.535]
#  [ 0.372  0.388 -0.843]]
# Center for interaction_time=34ns:
# [0.012 0.007 0.277]
# Axes for interaction_time=34ns:
# [0.273 0.329 0.374]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=34ns: 0.007
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.007
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.007
# after swap
# R for interaction_time=34ns:
# [[-0.769  0.638 -0.046]
#  [ 0.52   0.666  0.535]
#  [ 0.372  0.388 -0.843]] and det(R) = 1.0000000000000002
# Center for interaction_time=34ns:
# [0.012 0.007 0.277]
# Axes for interaction_time=34ns:
# [0.273 0.329 0.374]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=34ns: 0.007
# Choi state for interaction_time=34ns:
# [[ 0.24 +0.j     0.014-0.043j  0.011+0.041j  0.002-0.j   ]
#  [ 0.014+0.043j  0.26 +0.j    -0.107+0.088j -0.011-0.041j]
#  [ 0.011-0.041j -0.107-0.088j  0.398+0.j    -0.008+0.039j]
#  [ 0.002+0.j    -0.011+0.041j -0.008-0.039j  0.102+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=36ns:
# R for interaction_time=36ns:
# [[-0.71   0.704 -0.02 ]
#  [ 0.552  0.539 -0.636]
#  [-0.437 -0.463 -0.771]]
# Center for interaction_time=36ns:
# [0.005 0.001 0.259]
# Axes for interaction_time=36ns:
# [0.318 0.394 0.359]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=36ns: 0.038
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.038
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.038
# after swap
# R for interaction_time=36ns:
# [[-0.71   0.704 -0.02 ]
#  [ 0.552  0.539 -0.636]
#  [-0.437 -0.463 -0.771]] and det(R) = 1.0000000000000002
# Center for interaction_time=36ns:
# [0.005 0.001 0.259]
# Axes for interaction_time=36ns:
# [0.318 0.394 0.359]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=36ns: 0.038
# Choi state for interaction_time=36ns:
# [[ 0.245+0.j    -0.017+0.051j -0.018-0.051j -0.003+0.j   ]
#  [-0.017-0.051j  0.255+0.j    -0.11 +0.113j  0.018+0.051j]
#  [-0.018+0.051j -0.11 -0.113j  0.384+0.j     0.02 -0.052j]
#  [-0.003-0.j     0.018-0.051j  0.02 +0.052j  0.116+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=38ns:
# R for interaction_time=38ns:
# [[ 0.54   0.538 -0.647]
#  [ 0.751 -0.656  0.081]
#  [-0.381 -0.529 -0.758]]
# Center for interaction_time=38ns:
# [ 0.005 -0.001  0.233]
# Axes for interaction_time=38ns:
# [0.42  0.366 0.371]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=38ns: 0.059
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.059
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.059
# after swap
# R for interaction_time=38ns:
# [[ 0.54   0.538 -0.647]
#  [ 0.751 -0.656  0.081]
#  [-0.381 -0.529 -0.758]] and det(R) = 1.0
# Center for interaction_time=38ns:
# [ 0.005 -0.001  0.233]
# Axes for interaction_time=38ns:
# [0.42  0.366 0.371]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=38ns: 0.059
# Choi state for interaction_time=38ns:
# [[ 0.238+0.j    -0.049+0.021j -0.05 -0.02j  -0.003+0.j   ]
#  [-0.049-0.021j  0.262+0.j     0.117+0.128j  0.05 +0.02j ]
#  [-0.05 +0.02j   0.117-0.128j  0.379+0.j     0.051-0.02j ]
#  [-0.003-0.j     0.05 -0.02j   0.051+0.02j   0.121+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=40ns:
# R for interaction_time=40ns:
# [[ 0.507  0.515 -0.691]
#  [ 0.7   -0.714 -0.018]
#  [-0.502 -0.475 -0.723]]
# Center for interaction_time=40ns:
# [ 0.008 -0.002  0.197]
# Axes for interaction_time=40ns:
# [0.496 0.405 0.412]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=40ns: 0.142
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.142
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.049
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.142
# after swap
# R for interaction_time=40ns:
# [[ 0.507  0.515 -0.691]
#  [ 0.7   -0.714 -0.018]
#  [-0.502 -0.475 -0.723]] and det(R) = 1.0000000000000002
# Center for interaction_time=40ns:
# [ 0.008 -0.002  0.197]
# Axes for interaction_time=40ns:
# [0.496 0.405 0.412]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=40ns: 0.142
# Choi state for interaction_time=40ns:
# [[ 0.225+0.j    -0.065+0.025j -0.067-0.025j -0.009-0.j   ]
#  [-0.065-0.025j  0.275+0.j     0.135+0.139j  0.067+0.025j]
#  [-0.067+0.025j  0.135-0.139j  0.374+0.j     0.069-0.024j]
#  [-0.009+0.j     0.067-0.025j  0.069+0.024j  0.126+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=42ns:
# R for interaction_time=42ns:
# [[ 0.29   0.366 -0.884]
#  [ 0.662 -0.744 -0.092]
#  [-0.691 -0.559 -0.458]]
# Center for interaction_time=42ns:
# [0.008 0.005 0.174]
# Axes for interaction_time=42ns:
# [0.517 0.429 0.456]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=42ns: 0.181
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.181
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.062
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.152
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.181
# after swap
# R for interaction_time=42ns:
# [[ 0.29   0.366 -0.884]
#  [ 0.662 -0.744 -0.092]
#  [-0.691 -0.559 -0.458]] and det(R) = 1.0
# Center for interaction_time=42ns:
# [0.008 0.005 0.174]
# Axes for interaction_time=42ns:
# [0.517 0.429 0.456]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=42ns: 0.181
# Choi state for interaction_time=42ns:
# [[ 0.241+0.j    -0.093+0.034j -0.095-0.035j -0.042-0.j   ]
#  [-0.093-0.034j  0.259+0.j     0.117+0.125j  0.095+0.035j]
#  [-0.095+0.035j  0.117-0.125j  0.346+0.j     0.097-0.036j]
#  [-0.042+0.j     0.095-0.035j  0.097+0.036j  0.154+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=44ns:
# R for interaction_time=44ns:
# [[-0.593  0.805 -0.03 ]
#  [ 0.725  0.55   0.414]
#  [ 0.35   0.223 -0.91 ]]
# Center for interaction_time=44ns:
# [-0.007 -0.003  0.135]
# Axes for interaction_time=44ns:
# [0.457 0.494 0.559]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=44ns: 0.243
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.243
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.243
# after swap
# R for interaction_time=44ns:
# [[-0.593  0.805 -0.03 ]
#  [ 0.725  0.55   0.414]
#  [ 0.35   0.223 -0.91 ]] and det(R) = 0.9999999999999999
# Center for interaction_time=44ns:
# [-0.007 -0.003  0.135]
# Axes for interaction_time=44ns:
# [0.457 0.494 0.559]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=44ns: 0.243
# Choi state for interaction_time=44ns:
# [[ 0.156+0.j     0.016-0.042j  0.018+0.043j  0.   -0.j   ]
#  [ 0.016+0.042j  0.344+0.j    -0.136+0.182j -0.018-0.043j]
#  [ 0.018-0.043j -0.136-0.182j  0.411+0.j    -0.02 +0.044j]
#  [ 0.   +0.j    -0.018+0.043j -0.02 -0.044j  0.089+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=46ns:
# R for interaction_time=46ns:
# [[ 0.294  0.223 -0.929]
#  [ 0.75   0.549  0.369]
#  [ 0.592 -0.806 -0.006]]
# Center for interaction_time=46ns:
# [0.019 0.012 0.124]
# Axes for interaction_time=46ns:
# [0.587 0.492 0.472]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=46ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.272
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [2, 0, 1] with robustness 0.272
# after swap
# R for interaction_time=46ns:
# [[-0.929  0.294  0.223]
#  [ 0.369  0.75   0.549]
#  [-0.006  0.592 -0.806]] and det(R) = 1.0000000000000002
# Center for interaction_time=46ns:
# [0.019 0.012 0.124]
# Axes for interaction_time=46ns:
# [0.472 0.587 0.492]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=46ns: 0.272
# Choi state for interaction_time=46ns:
# [[ 0.182+0.j     0.018-0.08j   0.013+0.077j  0.   +0.j   ]
#  [ 0.018+0.08j   0.318+0.j    -0.22 +0.087j -0.013-0.077j]
#  [ 0.013-0.077j -0.22 -0.087j  0.38 +0.j    -0.009+0.074j]
#  [ 0.   -0.j    -0.013+0.077j -0.009-0.074j  0.12 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=48ns:
# R for interaction_time=48ns:
# [[ 0.701 -0.713  0.014]
#  [-0.703 -0.694 -0.156]
#  [ 0.121  0.1   -0.988]]
# Center for interaction_time=48ns:
# [0.019 0.011 0.123]
# Axes for interaction_time=48ns:
# [0.471 0.51  0.597]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=48ns: 0.284
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.284
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.223
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.184
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.284
# after swap
# R for interaction_time=48ns:
# [[ 0.701 -0.713  0.014]
#  [-0.703 -0.694 -0.156]
#  [ 0.121  0.1   -0.988]] and det(R) = 0.9999999999999999
# Center for interaction_time=48ns:
# [0.019 0.011 0.123]
# Axes for interaction_time=48ns:
# [0.471 0.51  0.597]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=48ns: 0.284
# Choi state for interaction_time=48ns:
# [[ 0.134+0.j     0.013+0.003j  0.008-0.005j -0.006+0.j   ]
#  [ 0.013-0.003j  0.366+0.j     0.171-0.174j -0.008+0.005j]
#  [ 0.008+0.005j  0.171+0.174j  0.428+0.j    -0.003-0.008j]
#  [-0.006-0.j    -0.008-0.005j -0.003+0.008j  0.072+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=50ns:
# R for interaction_time=50ns:
# [[ 0.712 -0.7    0.049]
#  [-0.674 -0.701 -0.233]
#  [ 0.198  0.133 -0.971]]
# Center for interaction_time=50ns:
# [0.021 0.016 0.126]
# Axes for interaction_time=50ns:
# [0.468 0.519 0.611]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=50ns: 0.288
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.288
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.228
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.167
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.288
# after swap
# R for interaction_time=50ns:
# [[ 0.712 -0.7    0.049]
#  [-0.674 -0.701 -0.233]
#  [ 0.198  0.133 -0.971]] and det(R) = 0.9999999999999998
# Center for interaction_time=50ns:
# [0.021 0.016 0.126]
# Axes for interaction_time=50ns:
# [0.468 0.519 0.611]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=50ns: 0.288
# Choi state for interaction_time=50ns:
# [[ 0.133+0.j     0.021+0.005j  0.015-0.009j -0.008+0.j   ]
#  [ 0.021-0.005j  0.367+0.j     0.174-0.17j  -0.015+0.009j]
#  [ 0.015+0.009j  0.174+0.17j   0.43 +0.j    -0.01 -0.013j]
#  [-0.008-0.j    -0.015-0.009j -0.01 +0.013j  0.07 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=52ns:
# R for interaction_time=52ns:
# [[-0.71   0.701 -0.059]
#  [ 0.596  0.645  0.478]
#  [ 0.373  0.305 -0.876]]
# Center for interaction_time=52ns:
# [0.005 0.009 0.13 ]
# Axes for interaction_time=52ns:
# [0.44  0.502 0.564]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=52ns: 0.238
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.238
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.238
# after swap
# R for interaction_time=52ns:
# [[-0.71   0.701 -0.059]
#  [ 0.596  0.645  0.478]
#  [ 0.373  0.305 -0.876]] and det(R) = 0.9999999999999998
# Center for interaction_time=52ns:
# [0.005 0.009 0.13 ]
# Axes for interaction_time=52ns:
# [0.44  0.502 0.564]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=52ns: 0.238
# Choi state for interaction_time=52ns:
# [[ 0.159+0.j     0.018-0.055j  0.016+0.053j  0.003-0.j   ]
#  [ 0.018+0.055j  0.341+0.j    -0.159+0.154j -0.016-0.053j]
#  [ 0.016-0.053j -0.159-0.154j  0.406+0.j    -0.015+0.051j]
#  [ 0.003+0.j    -0.016+0.053j -0.015-0.051j  0.094+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=54ns:
# R for interaction_time=54ns:
# [[ 0.354  0.34  -0.871]
#  [ 0.787 -0.611  0.081]
#  [-0.505 -0.715 -0.484]]
# Center for interaction_time=54ns:
# [0.006 0.008 0.155]
# Axes for interaction_time=54ns:
# [0.534 0.424 0.462]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=54ns: 0.151
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.151
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.165
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [2, 0, 1] with robustness 0.165
# after swap
# R for interaction_time=54ns:
# [[-0.871  0.354  0.34 ]
#  [ 0.081  0.787 -0.611]
#  [-0.484 -0.505 -0.715]] and det(R) = 1.0
# Center for interaction_time=54ns:
# [0.006 0.008 0.155]
# Axes for interaction_time=54ns:
# [0.462 0.534 0.424]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=54ns: 0.165
# Choi state for interaction_time=54ns:
# [[ 0.213+0.j    -0.009+0.064j -0.01 -0.066j  0.004+0.j   ]
#  [-0.009-0.064j  0.287+0.j    -0.206+0.057j  0.01 +0.066j]
#  [-0.01 +0.066j -0.206-0.057j  0.365+0.j     0.011-0.068j]
#  [ 0.004-0.j     0.01 -0.066j  0.011+0.068j  0.135+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=56ns:
# R for interaction_time=56ns:
# [[-0.771  0.635 -0.044]
#  [ 0.582  0.731  0.356]
#  [ 0.258  0.249 -0.933]]
# Center for interaction_time=56ns:
# [ 0.009 -0.003  0.192]
# Axes for interaction_time=56ns:
# [0.395 0.43  0.495]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=56ns: 0.155
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.155
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# ...
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.150
# after swap
# R for interaction_time=92ns:
# [[ 0.706 -0.708  0.011]
#  [-0.696 -0.697 -0.172]
#  [ 0.13   0.114 -0.985]] and det(R) = 1.0000000000000002
# Center for interaction_time=92ns:
# [-0.002 -0.006  0.107]
# Axes for interaction_time=92ns:
# [0.324 0.381 0.607]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=92ns: 0.150
# Choi state for interaction_time=92ns:
# [[ 0.127+0.j     0.006+0.009j  0.006-0.008j -0.009+0.j   ]
#  [ 0.006-0.009j  0.373+0.j     0.124-0.124j -0.006+0.008j]
#  [ 0.006+0.008j  0.124+0.124j  0.426+0.j    -0.007-0.006j]
#  [-0.009-0.j    -0.006-0.008j -0.007+0.006j  0.074+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=94ns:
# R for interaction_time=94ns:
# [[ 0.57  -0.821 -0.02 ]
#  [-0.807 -0.556 -0.198]
#  [ 0.152  0.129 -0.98 ]]
# Center for interaction_time=94ns:
# [0.001 0.005 0.121]
# Axes for interaction_time=94ns:
# [0.335 0.392 0.59 ]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=94ns: 0.150
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.150
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.130
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.096
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.150
# after swap
# R for interaction_time=94ns:
# [[ 0.57  -0.821 -0.02 ]
#  [-0.807 -0.556 -0.198]
#  [ 0.152  0.129 -0.98 ]] and det(R) = 0.9999999999999998
# Center for interaction_time=94ns:
# [0.001 0.005 0.121]
# Axes for interaction_time=94ns:
# [0.335 0.392 0.59 ]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=94ns: 0.150
# Choi state for interaction_time=94ns:
# [[ 0.136+0.j     0.005+0.007j  0.005-0.008j -0.007+0.j   ]
#  [ 0.005-0.007j  0.364+0.j     0.102-0.148j -0.005+0.008j]
#  [ 0.005+0.008j  0.102+0.148j  0.425+0.j    -0.005-0.01j ]
#  [-0.007-0.j    -0.005-0.008j -0.005+0.01j   0.075+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=96ns:
# R for interaction_time=96ns:
# [[ 0.825 -0.565  0.014]
#  [-0.557 -0.817 -0.149]
#  [ 0.096  0.116 -0.989]]
# Center for interaction_time=96ns:
# [-0.005 -0.004  0.13 ]
# Axes for interaction_time=96ns:
# [0.34  0.378 0.571]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=96ns: 0.140
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.140
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.064
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.029
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.140
# after swap
# R for interaction_time=96ns:
# [[ 0.825 -0.565  0.014]
#  [-0.557 -0.817 -0.149]
#  [ 0.096  0.116 -0.989]] and det(R) = 1.0000000000000002
# Center for interaction_time=96ns:
# [-0.005 -0.004  0.13 ]
# Axes for interaction_time=96ns:
# [0.34  0.378 0.571]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=96ns: 0.140
# Choi state for interaction_time=96ns:
# [[ 0.141+0.j     0.004+0.006j  0.005-0.005j -0.007-0.j   ]
#  [ 0.004-0.006j  0.359+0.j     0.147-0.101j -0.005+0.005j]
#  [ 0.005+0.005j  0.147+0.101j  0.424+0.j    -0.006-0.004j]
#  [-0.007+0.j    -0.005-0.005j -0.006+0.004j  0.076+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=98ns:
# R for interaction_time=98ns:
# [[ 0.7   -0.714  0.013]
#  [-0.712 -0.698 -0.078]
#  [ 0.065  0.046 -0.997]]
# Center for interaction_time=98ns:
# [0.014 0.009 0.156]
# Axes for interaction_time=98ns:
# [0.311 0.342 0.535]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=98ns: 0.093
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.093
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.044
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.033
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.093
# after swap
# R for interaction_time=98ns:
# [[ 0.7   -0.714  0.013]
#  [-0.712 -0.698 -0.078]
#  [ 0.065  0.046 -0.997]] and det(R) = 1.0
# Center for interaction_time=98ns:
# [0.014 0.009 0.156]
# Axes for interaction_time=98ns:
# [0.311 0.342 0.535]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=98ns: 0.093
# Choi state for interaction_time=98ns:
# [[ 0.156+0.j     0.007+0.001j  0.003-0.003j -0.005-0.j   ]
#  [ 0.007-0.001j  0.344+0.j     0.114-0.116j -0.003+0.003j]
#  [ 0.003+0.003j  0.114+0.116j  0.422+0.j     0.   -0.005j]
#  [-0.005+0.j    -0.003-0.003j  0.   +0.005j  0.078+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=100ns:
# R for interaction_time=100ns:
# [[ 0.736 -0.677  0.008]
#  [-0.67  -0.73  -0.131]
#  [ 0.095  0.091 -0.991]]
# Center for interaction_time=100ns:
# [ 0.001 -0.001  0.193]
# Axes for interaction_time=100ns:
# [0.289 0.348 0.504]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=100ns: 0.069
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.069
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.025
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.007
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.069
# after swap
# R for interaction_time=100ns:
# [[ 0.736 -0.677  0.008]
#  [-0.67  -0.73  -0.131]
#  [ 0.095  0.091 -0.991]] and det(R) = 0.9999999999999999
# Center for interaction_time=100ns:
# [ 0.001 -0.001  0.193]
# Axes for interaction_time=100ns:
# [0.289 0.348 0.504]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=100ns: 0.069
# Choi state for interaction_time=100ns:
# [[ 0.173+0.j     0.004+0.005j  0.004-0.004j -0.01 +0.j   ]
#  [ 0.004-0.005j  0.327+0.j     0.117-0.107j -0.004+0.004j]
#  [ 0.004+0.004j  0.117+0.107j  0.423+0.j    -0.004-0.004j]
#  [-0.01 -0.j    -0.004-0.004j -0.004+0.004j  0.077+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=102ns:
# R for interaction_time=102ns:
# [[ 0.767 -0.642  0.008]
#  [-0.634 -0.76  -0.14 ]
#  [ 0.095  0.102 -0.99 ]]
# Center for interaction_time=102ns:
# [0.004 0.004 0.212]
# Axes for interaction_time=102ns:
# [0.275 0.335 0.475]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=102ns: 0.045
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.045
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.003
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.045
# after swap
# R for interaction_time=102ns:
# [[ 0.767 -0.642  0.008]
#  [-0.634 -0.76  -0.14 ]
#  [ 0.095  0.102 -0.99 ]] and det(R) = 1.0
# Center for interaction_time=102ns:
# [0.004 0.004 0.212]
# Axes for interaction_time=102ns:
# [0.275 0.335 0.475]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=102ns: 0.045
# Choi state for interaction_time=102ns:
# [[ 0.186+0.j     0.005+0.003j  0.004-0.004j -0.011+0.j   ]
#  [ 0.005-0.003j  0.314+0.j     0.116-0.097j -0.004+0.004j]
#  [ 0.004+0.004j  0.116+0.097j  0.421+0.j    -0.003-0.005j]
#  [-0.011-0.j    -0.004-0.004j -0.003+0.005j  0.079+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=104ns:
# R for interaction_time=104ns:
# [[ 0.706 -0.708  0.012]
#  [-0.694 -0.695 -0.191]
#  [ 0.143  0.127 -0.982]]
# Center for interaction_time=104ns:
# [-0.004 -0.009  0.245]
# Axes for interaction_time=104ns:
# [0.248 0.302 0.432]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=104ns: 0.008
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.008
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [0, 1, 2] with robustness 0.008
# after swap
# R for interaction_time=104ns:
# [[ 0.706 -0.708  0.012]
#  [-0.694 -0.695 -0.191]
#  [ 0.143  0.127 -0.982]] and det(R) = 0.9999999999999999
# Center for interaction_time=104ns:
# [-0.004 -0.009  0.245]
# Axes for interaction_time=104ns:
# [0.248 0.302 0.432]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=104ns: 0.008
# Choi state for interaction_time=104ns:
# [[ 0.205+0.j     0.004+0.008j  0.005-0.006j -0.009+0.j   ]
#  [ 0.004-0.008j  0.295+0.j     0.096-0.096j -0.005+0.006j]
#  [ 0.005+0.006j  0.096+0.096j  0.417+0.j    -0.006-0.003j]
#  [-0.009-0.j    -0.005-0.006j -0.006+0.003j  0.083+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=106ns:
# R for interaction_time=106ns:
# [[ 0.681 -0.732 -0.02 ]
#  [-0.716 -0.66  -0.226]
#  [ 0.153  0.168 -0.974]]
# Center for interaction_time=106ns:
# [-0.014 -0.016  0.259]
# Axes for interaction_time=106ns:
# [0.209 0.292 0.381]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=106ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [2, 1, 0] with robustness 0.000
# after swap
# R for interaction_time=106ns:
# [[-0.02  -0.732 -0.681]
#  [-0.226 -0.66   0.716]
#  [-0.974  0.168 -0.153]] and det(R) = 1.0000000000000002
# Center for interaction_time=106ns:
# [-0.014 -0.016  0.259]
# Axes for interaction_time=106ns:
# [0.381 0.292 0.209]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=106ns: 0.000
# Choi state for interaction_time=106ns:
# [[ 0.307+0.j    -0.068-0.021j -0.064+0.025j -0.05 +0.j   ]
#  [-0.068+0.021j  0.193+0.j     0.046-0.075j  0.064-0.025j]
#  [-0.064-0.025j  0.046+0.075j  0.323+0.j     0.061+0.029j]
#  [-0.05 -0.j     0.064+0.025j  0.061-0.029j  0.177+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=108ns:
# R for interaction_time=108ns:
# [[ 0.695 -0.719 -0.012]
#  [-0.716 -0.69  -0.11 ]
#  [ 0.071  0.085 -0.994]]
# Center for interaction_time=108ns:
# [-0.007 -0.012  0.261]
# Axes for interaction_time=108ns:
# [0.178 0.268 0.373]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=108ns: 0.000
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.000
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.000
# Best permutation [1, 0, 2] with robustness 0.000
# after swap
# R for interaction_time=108ns:
# [[-0.719  0.695  0.012]
#  [-0.69  -0.716  0.11 ]
#  [ 0.085  0.071  0.994]] and det(R) = 0.9999999999999998
# Center for interaction_time=108ns:
# [-0.007 -0.012  0.261]
# Axes for interaction_time=108ns:
# [0.268 0.178 0.373]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=108ns: 0.000
# Choi state for interaction_time=108ns:
# [[ 0.408+0.j     0.002-0.004j  0.003+0.007j -0.08 +0.j   ]
#  [ 0.002+0.004j  0.092+0.j    -0.016-0.015j -0.003-0.007j]
#  [ 0.003-0.007j -0.016+0.015j  0.223+0.j    -0.005+0.01j ]
#  [-0.08 -0.j    -0.003+0.007j -0.005-0.01j   0.277+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for interaction_time=110ns:
# R for interaction_time=110ns:
# [[-0.29  -0.582 -0.76 ]
#  [-0.715  0.66  -0.231]
#  [ 0.636  0.476 -0.607]]
# Center for interaction_time=110ns:
# [-0.809 -0.567 -0.335]
# Axes for interaction_time=110ns:
# [0.224 0.466 1.633]
# After 2 iterations, the Choi state is valid.
# Quantum robustness for interaction_time=110ns: 0.095
# ---------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# Permutation [0 1 2] robustness: 0.095
# After 2 iterations, the Choi state is valid.
# Permutation [0 2 1] robustness: 0.018
# After 2 iterations, the Choi state is valid.
# Permutation [1 0 2] robustness: 0.100
# After 2 iterations, the Choi state is valid.
# Permutation [1 2 0] robustness: 0.161
# After 2 iterations, the Choi state is valid.
# Permutation [2 0 1] robustness: 0.299
# After 2 iterations, the Choi state is valid.
# Permutation [2 1 0] robustness: 0.032
# Best permutation [2, 0, 1] with robustness 0.299
# after swap
# R for interaction_time=110ns:
# [[-0.76  -0.29  -0.582]
#  [-0.231 -0.715  0.66 ]
#  [-0.607  0.636  0.476]] and det(R) = 1.0
# Center for interaction_time=110ns:
# [-0.809 -0.567 -0.335]
# Axes for interaction_time=110ns:
# [1.633 0.224 0.466]
# After 2 iterations, the Choi state is valid.
# Robustness for interaction_time=110ns: 0.299
# Choi state for interaction_time=110ns:
# [[ 0.273+0.j    -0.14 +0.015j -0.088+0.065j -0.225-0.033j]
#  [-0.14 -0.015j  0.227+0.j    -0.09 -0.034j  0.088-0.065j]
#  [-0.088-0.065j -0.09 +0.034j  0.186+0.j     0.059+0.16j ]
#  [-0.225+0.033j  0.088+0.065j  0.059-0.16j   0.314+0.j   ]]
# ----------------------------------------------------------------------------------------------------

# %%
axes_list = np.array([non_Markovian_data_raw[key]['ellipsoid']['axes'] for key in non_Markovian_key])
volume_list = np.array([non_Markovian_data_raw[key]['ellipsoid']['volume'] for key in non_Markovian_key])
robustness_list = [non_Markovian_data_raw[key]['quantum_information']['robustness'] for key in non_Markovian_key]
fig = plt.figure(figsize=(6, 10))
ax_name = ['axes', 'volume', 'QM']
ax_axes = fig.add_subplot(len(ax_name), 1, 1)
fitted_axes = np.zeros_like(axes_list)
ax_volume = fig.add_subplot(len(ax_name), 1, 2)
ax_QM = fig.add_subplot(len(ax_name), 1, 3)
ax_axes.plot(interaction_time, axes_list[:,0], marker='o', label='axis x')
ax_axes.plot(interaction_time, axes_list[:,1], marker='o', label='axis y')
ax_axes.plot(interaction_time, axes_list[:,2], marker='o', label='axis z')
ax_axes.set_ylim(0,1)
ax_axes.set_ylabel('Ellipsoid axes')
ax_axes.grid(alpha=0.3)
ax_axes.set_title('Raw data analysis')
ax_volume.plot(interaction_time, volume_list, marker='o')
ax_volume.set_ylabel('Ellipsoid volume')
ax_QM.plot(interaction_time, robustness_list, marker='o')
ax_QM.set_xlabel('Interaction time (ns)')
ax_QM.set_ylabel('Quantum robustness')
plt.show()

# %%
non_Markovian_data['raw'] = non_Markovian_data_raw

# %% [markdown]
# ### Simulation with readout error

# %%
from quam_libs.macros import generate_uniform_sphere_angles
swap_time = np.arange(0, 111e-9,2e-9)  # time in seconds

n_points =1000
error_rate = 0.16
t1 = 1e-6
t2= 0.5e-6

data_angle_list = []
theta_range, phi_range = generate_uniform_sphere_angles(n_points)
for i in range(len(swap_time)):
    data_angle = []
    for j in range(len(theta_range)):
        data_angle.append([theta_range[j], phi_range[j]])
    data_angle_list.append(np.array(data_angle))


simulation_data = {
    f"swap={int(swap_time[i]*1e9)}ns": {'data_angle':data_angle_list[i].tolist(),'data_xyz': []}
    for i in range(len(swap_time))
}

# %%
from quam_libs.nonMarkovian_simulation import BR_swap_dm, wait_dm,error_gate
from quam_libs.QI_utils import bloch_vector_to_density_matrix,density_matrix_to_bloch_vector

# xyz_data ={}
# bloch_vector_list = []
for i in range(n_points):
    theta, phi = data_angle_list[0][i]
    #dm = BR_swap_dm(theta, phi, tlist=swap_time)
    delay_dm = wait_dm(theta, phi,T1=t1,T2=t2)[-1]
    dm = BR_swap_dm(delay_dm,g=41.5e6/2*np.pi,T2=t2, T1=t1,tlist=swap_time)
    for j in range(len(swap_time)):
        dm_j = dm[j].ptrace(1)
        dm_j = error_gate(dm_j, error_rate).full()
        bloch_vector = density_matrix_to_bloch_vector(dm_j)
        simulation_data[f"swap={int(swap_time[j]*1e9)}ns"]['data_xyz'].append(bloch_vector.tolist())
# Out:
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/pennylane/__init__.py:212: PennyLaneDeprecationWarning: PennyLane v0.44 has dropped maintainence support for NumPy < 2.0.0. You have version 1.26.4 installed. Future versions of PennyLane will not work with NumPy<2.0. Please consider upgrading NumPy using `python -m pip install numpy --upgrade`.
#   warnings.warn(
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/qutip/solver/options.py:16: FutureWarning: Dedicated options class are no longer needed, options should be passed as dict to solvers.
#   warnings.warn(

# %%
from quam_libs.quantum_memory.legacy.NoiseAnalyze import NoiseAnalyze, EllipsoidFitParameter  
ellipsoid_fit_parameters = EllipsoidFitParameter()

sim_swap_data = {}
sim_swap_analyze={}
do_convex_hull = True
for i, key in enumerate(simulation_data):
    data_xyz = simulation_data[key]['data_xyz']
    data_angle = simulation_data[key]['data_angle']
    data_dm = np.array([bloch_vector_to_density_matrix(data_xyz[i]) for i in range(len(data_xyz))])
    sim_swap_analyzer = NoiseAnalyze(data_xyz,data_angle,ellipsoid_fit_parameters)
    corrected_dm = sim_swap_analyzer.corrected_dm
    corrected_bloch = sim_swap_analyzer.corrected_bloch

    sim_swap_data[key] = {
        'data_xyz': data_xyz,
        'data_dm' :data_dm,
        'data_angle': data_angle,
        'corrected_xyz': corrected_bloch,
        'corrected_dm': corrected_dm,}
    sim_swap_analyze[key] = sim_swap_analyzer

# %%
from quam_libs.quantum_memory.legacy.NoiseAnalyze import QuantumMemory

swap_result_dict ={}
for key in sim_swap_data.keys():
    center, axes, R, volume, param = sim_swap_analyze[key].ellipsoid_fit()
    qm_analyze = QuantumMemory(axes,center,R)
    choi_state = qm_analyze.choi_state()
    swap_result_dict[key] ={
        'axes': axes,
        'center': center,
        'R': R,
        'param': param,
        'volume': volume,
        'choi state': choi_state,
        'memory robustness': qm_analyze.memory_robustness,
    }

# %%
def perm_order(axes,center,R_test,method='rotation'):
    """
    method axes: it use the axes to determine the order of the rotation matrix, the max axes should be z-axis
    method rotation: it use the rotation matrix to determine the order of the rotation matrix, it order the 
    rotation matrix by the maximum absolute value of each row, and then sort the rows based on the order    
    """
    if method == 'rotation':
        perm0 = np.argmax(np.abs(R_test[0]))
        perm1 = np.argmax(np.abs(R_test[1]))
        perm2 = np.argmax(np.abs(R_test[2]))
        perm = np.array([perm0, perm1, perm2])
        idx = np.argsort(perm)
    elif method == 'axes':
        z_min = np.argmin(np.abs(axes))
        if z_min == 0:
            idx = np.array([2,1,0])
        elif z_min == 1:
            idx = np.array([0,2,1])
        elif z_min == 2:
            idx = np.array([0,1,2])
    R_test = R_test[idx, :]
    axes = axes[idx]
    center = center[idx]
    if np.linalg.det(R_test) >0:
        pass
    elif np.linalg.det(R_test) < 0:
        R_test[0] *= -1  
    else:
        print(f"R_test is not a valid rotation matrix, det(R_test)={np.linalg.det(R_test)}")
        raise ValueError("R_test is not a valid rotation matrix")
    return axes,center,R_test,idx


keys= sim_swap_data.keys()
for key in keys:
    print(f"Results for {key}:")
    R = swap_result_dict[key]['R']
    center = swap_result_dict[key]['center']
    axes = swap_result_dict[key]['axes']
    print(f"R:\n{R}")
    print(f"Center:\n{center}")
    print(f"Axes:\n{axes}")
    print(f"choi state:\n{swap_result_dict[key]['choi state']}")
    print('-'*75)
    axes, center_,R,perm = perm_order(axes,center,R,method='rotation')
    print("After swapping the axes, center and R")
    print(f"R:\n{R}")
    print(f"Center:\n{center}")
    print(f"Axes:\n{axes}")
    choi = QuantumMemory(axes,center,R).choi_state()
    print(f"choi state:\n{choi}")
    print('-'*100)

    swap_result_dict[key]['R'] = R
    swap_result_dict[key]['axes'] = axes
    swap_result_dict[key]['center'] = center
    swap_result_dict[key]['choi state'] = choi
# Out:
# Results for swap=0ns:
# R:
# [[ 1.     0.015  0.   ]
#  [ 0.     1.    -0.   ]
#  [-0.     0.     1.   ]]
# Center:
# [-0.  0.  0.]
# Axes:
# [0.84 0.84 0.68]
# choi state:
# [[ 0.42+0.j    -0.  -0.j    -0.  +0.j     0.42+0.j   ]
#  [-0.  +0.j     0.08+0.j    -0.  +0.003j -0.  +0.j   ]
#  [-0.  -0.j    -0.  -0.003j  0.08+0.j    -0.  -0.j   ]
#  [ 0.42+0.j    -0.  -0.j    -0.  +0.j     0.42+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 1.     0.015  0.   ]
#  [ 0.     1.    -0.   ]
#  [-0.     0.     1.   ]]
# Center:
# [-0.  0.  0.]
# Axes:
# [0.84 0.84 0.68]
# choi state:
# [[ 0.42+0.j    -0.  -0.j    -0.  +0.j     0.42+0.j   ]
#  [-0.  +0.j     0.08+0.j    -0.  +0.003j -0.  +0.j   ]
#  [-0.  -0.j    -0.  -0.003j  0.08+0.j    -0.  -0.j   ]
#  [ 0.42+0.j    -0.  -0.j    -0.  +0.j     0.42+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=2ns:
# R:
# [[ 0.     0.     1.   ]
#  [ 0.35  -0.937 -0.   ]
#  [ 0.937  0.35  -0.   ]]
# Center:
# [ 0.    -0.     0.013]
# Axes:
# [0.667 0.827 0.827]
# choi state:
# [[ 0.256+0.j     0.181-0.036j  0.181+0.036j -0.194+0.j   ]
#  [ 0.181+0.036j  0.25 +0.j     0.194+0.058j -0.181-0.036j]
#  [ 0.181-0.036j  0.194-0.058j  0.25 +0.j    -0.181+0.036j]
#  [-0.194+0.j    -0.181+0.036j -0.181-0.036j  0.244+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.937 -0.35   0.   ]
#  [ 0.35  -0.937 -0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [ 0.    -0.     0.013]
# Axes:
# [0.827 0.827 0.667]
# choi state:
# [[ 0.423+0.j  0.   +0.j  0.   -0.j -0.387+0.j]
#  [ 0.   -0.j  0.083+0.j  0.   -0.j -0.   +0.j]
#  [ 0.   +0.j  0.   +0.j  0.083+0.j -0.   -0.j]
#  [-0.387+0.j -0.   -0.j -0.   +0.j  0.41 +0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=4ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.873  0.487 -0.   ]
#  [-0.487  0.873  0.   ]]
# Center:
# [ 0.    -0.     0.048]
# Axes:
# [0.632 0.8   0.8  ]
# choi state:
# [[ 0.274+0.j     0.062-0.087j  0.062+0.087j  0.097+0.j   ]
#  [ 0.062+0.087j  0.25 +0.j    -0.097+0.138j -0.062-0.087j]
#  [ 0.062-0.087j -0.097-0.138j  0.25 +0.j    -0.062+0.087j]
#  [ 0.097+0.j    -0.062+0.087j -0.062-0.087j  0.226+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.873  0.487 -0.   ]
#  [-0.487  0.873  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.048]
# Axes:
# [0.8   0.8   0.632]
# choi state:
# [[ 0.432+0.j  0.   -0.j  0.   +0.j  0.349+0.j]
#  [ 0.   +0.j  0.092+0.j -0.   +0.j -0.   -0.j]
#  [ 0.   -0.j -0.   -0.j  0.092+0.j -0.   +0.j]
#  [ 0.349+0.j -0.   +0.j -0.   -0.j  0.384+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=6ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.826  0.563 -0.   ]
#  [-0.563  0.826  0.   ]]
# Center:
# [ 0.    -0.     0.102]
# Axes:
# [0.578 0.76  0.76 ]
# choi state:
# [[ 0.301+0.j     0.054-0.079j  0.054+0.079j  0.107+0.j   ]
#  [ 0.054+0.079j  0.25 +0.j    -0.107+0.119j -0.054-0.079j]
#  [ 0.054-0.079j -0.107-0.119j  0.25 +0.j    -0.054+0.079j]
#  [ 0.107+0.j    -0.054+0.079j -0.054-0.079j  0.199+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.826  0.563 -0.   ]
#  [-0.563  0.826  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.102]
# Axes:
# [0.76  0.76  0.578]
# choi state:
# [[ 0.445+0.j  0.   +0.j  0.   -0.j  0.314+0.j]
#  [ 0.   -0.j  0.105+0.j -0.   +0.j -0.   -0.j]
#  [ 0.   +0.j -0.   -0.j  0.105+0.j -0.   +0.j]
#  [ 0.314+0.j -0.   +0.j -0.   -0.j  0.344+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=8ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.57   0.821  0.   ]
#  [-0.821 -0.57   0.   ]]
# Center:
# [ 0.    -0.     0.172]
# Axes:
# [0.508 0.707 0.707]
# choi state:
# [[ 0.336+0.j     0.036+0.05j   0.036-0.05j   0.145+0.j   ]
#  [ 0.036-0.05j   0.25 +0.j    -0.145-0.072j -0.036+0.05j ]
#  [ 0.036+0.05j  -0.145+0.072j  0.25 +0.j    -0.036-0.05j ]
#  [ 0.145+0.j    -0.036-0.05j  -0.036+0.05j   0.164+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.821  0.57  -0.   ]
#  [-0.57   0.821  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.172]
# Axes:
# [0.707 0.707 0.508]
# choi state:
# [[ 0.463+0.j  0.   -0.j  0.   +0.j  0.29 +0.j]
#  [ 0.   +0.j  0.123+0.j -0.   +0.j -0.   -0.j]
#  [ 0.   -0.j -0.   -0.j  0.123+0.j -0.   +0.j]
#  [ 0.29 +0.j -0.   +0.j -0.   -0.j  0.291+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=10ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.973  0.229 -0.   ]
#  [-0.229  0.973  0.   ]]
# Center:
# [ 0.    -0.     0.253]
# Axes:
# [0.427 0.643 0.643]
# choi state:
# [[ 0.376+0.j     0.068-0.078j  0.068+0.078j  0.037+0.j   ]
#  [ 0.068+0.078j  0.25 +0.j    -0.037+0.104j -0.068-0.078j]
#  [ 0.068-0.078j -0.037-0.104j  0.25 +0.j    -0.068+0.078j]
#  [ 0.037+0.j    -0.068+0.078j -0.068-0.078j  0.124+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.973  0.229 -0.   ]
#  [-0.229  0.973  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.253]
# Axes:
# [0.643 0.643 0.427]
# choi state:
# [[ 0.483+0.j  0.   +0.j  0.   -0.j  0.313+0.j]
#  [ 0.   -0.j  0.143+0.j -0.   +0.j  0.   -0.j]
#  [ 0.   +0.j -0.   -0.j  0.143+0.j  0.   +0.j]
#  [ 0.313+0.j  0.   +0.j  0.   -0.j  0.231+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=12ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.888  0.46  -0.   ]
#  [-0.46   0.888  0.   ]]
# Center:
# [ 0.    -0.     0.339]
# Axes:
# [0.341 0.568 0.568]
# choi state:
# [[ 0.419+0.j     0.051-0.063j  0.051+0.063j  0.065+0.j   ]
#  [ 0.051+0.063j  0.25 +0.j    -0.065+0.076j -0.051-0.063j]
#  [ 0.051-0.063j -0.065-0.076j  0.25 +0.j    -0.051+0.063j]
#  [ 0.065+0.j    -0.051+0.063j -0.051-0.063j  0.081+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.888  0.46  -0.   ]
#  [-0.46   0.888  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.339]
# Axes:
# [0.568 0.568 0.341]
# choi state:
# [[ 0.505+0.j  0.   +0.j  0.   -0.j  0.252+0.j]
#  [ 0.   -0.j  0.165+0.j -0.   +0.j -0.   -0.j]
#  [ 0.   +0.j -0.   -0.j  0.165+0.j -0.   +0.j]
#  [ 0.252+0.j -0.   +0.j -0.   -0.j  0.166+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=14ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.752  0.659 -0.   ]
#  [-0.659  0.752  0.   ]]
# Center:
# [ 0.    -0.     0.424]
# Axes:
# [0.256 0.484 0.484]
# choi state:
# [[ 0.462+0.j     0.039-0.046j  0.039+0.046j  0.08 +0.j   ]
#  [ 0.039+0.046j  0.25 +0.j    -0.08 +0.048j -0.039-0.046j]
#  [ 0.039-0.046j -0.08 -0.048j  0.25 +0.j    -0.039+0.046j]
#  [ 0.08 +0.j    -0.039+0.046j -0.039-0.046j  0.038+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.752  0.659 -0.   ]
#  [-0.659  0.752  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.424]
# Axes:
# [0.484 0.484 0.256]
# choi state:
# [[ 0.526+0.j  0.   +0.j  0.   -0.j  0.182+0.j]
#  [ 0.   -0.j  0.186+0.j -0.   +0.j -0.   -0.j]
#  [ 0.   +0.j -0.   -0.j  0.186+0.j -0.   +0.j]
#  [ 0.182+0.j -0.   +0.j -0.   -0.j  0.102+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=16ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.904  0.428  0.   ]
#  [-0.428 -0.904 -0.   ]]
# Center:
# [ 0.    -0.     0.504]
# Axes:
# [0.176 0.393 0.393]
# choi state:
# [[ 0.502+0.j     0.04 +0.044j  0.04 -0.044j  0.042+0.j   ]
#  [ 0.04 -0.044j  0.25 +0.j    -0.042-0.04j  -0.04 +0.044j]
#  [ 0.04 +0.044j -0.042+0.04j   0.25 +0.j    -0.04 -0.044j]
#  [ 0.042+0.j    -0.04 -0.044j -0.04 +0.044j -0.002+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.904  0.428  0.   ]
#  [-0.428 -0.904 -0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.504]
# Axes:
# [0.393 0.393 0.176]
# choi state:
# [[ 0.546+0.j  0.   +0.j  0.   -0.j -0.177+0.j]
#  [ 0.   -0.j  0.206+0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.206+0.j -0.   -0.j]
#  [-0.177+0.j -0.   -0.j -0.   +0.j  0.042+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=18ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.943  0.333  0.   ]
#  [-0.333 -0.943 -0.   ]]
# Center:
# [ 0.    -0.     0.572]
# Axes:
# [0.108 0.295 0.295]
# choi state:
# [[ 0.536+0.j     0.032+0.035j  0.032-0.035j  0.025+0.j   ]
#  [ 0.032-0.035j  0.25 +0.j    -0.025-0.025j -0.032+0.035j]
#  [ 0.032+0.035j -0.025+0.025j  0.25 +0.j    -0.032-0.035j]
#  [ 0.025+0.j    -0.032-0.035j -0.032+0.035j -0.036+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.943  0.333  0.   ]
#  [-0.333 -0.943 -0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.572]
# Axes:
# [0.295 0.295 0.108]
# choi state:
# [[ 0.563+0.j  0.   +0.j  0.   -0.j -0.139+0.j]
#  [ 0.   -0.j  0.223+0.j  0.   +0.j -0.   +0.j]
#  [ 0.   +0.j  0.   -0.j  0.223+0.j -0.   -0.j]
#  [-0.139+0.j -0.   -0.j -0.   +0.j -0.009+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=20ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.959  0.282  0.   ]
#  [-0.282 -0.959 -0.   ]]
# Center:
# [0.    0.    0.624]
# Axes:
# [0.056 0.193 0.193]
# choi state:
# [[ 0.562+0.j     0.022+0.023j  0.022-0.023j  0.014+0.j   ]
#  [ 0.022-0.023j  0.25 +0.j    -0.014-0.013j -0.022+0.023j]
#  [ 0.022+0.023j -0.014+0.013j  0.25 +0.j    -0.022-0.023j]
#  [ 0.014+0.j    -0.022-0.023j -0.022+0.023j -0.062+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.959  0.282  0.   ]
#  [-0.282 -0.959 -0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [0.    0.    0.624]
# Axes:
# [0.193 0.193 0.056]
# choi state:
# [[ 0.576+0.j  0.   +0.j  0.   -0.j -0.093+0.j]
#  [ 0.   -0.j  0.236+0.j  0.   +0.j -0.   +0.j]
#  [ 0.   +0.j  0.   -0.j  0.236+0.j -0.   -0.j]
#  [-0.093+0.j -0.   -0.j -0.   +0.j -0.048+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=22ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.963  0.269  0.   ]
#  [-0.269 -0.963 -0.   ]]
# Center:
# [0.    0.    0.657]
# Axes:
# [0.023 0.089 0.089]
# choi state:
# [[ 0.578+0.j     0.01 +0.011j  0.01 -0.011j  0.006+0.j   ]
#  [ 0.01 -0.011j  0.25 +0.j    -0.006-0.006j -0.01 +0.011j]
#  [ 0.01 +0.011j -0.006+0.006j  0.25 +0.j    -0.01 -0.011j]
#  [ 0.006+0.j    -0.01 -0.011j -0.01 +0.011j -0.078+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.963  0.269  0.   ]
#  [-0.269 -0.963 -0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [0.    0.    0.657]
# Axes:
# [0.089 0.089 0.023]
# choi state:
# [[ 0.584+0.j  0.   +0.j  0.   -0.j -0.043+0.j]
#  [ 0.   -0.j  0.244+0.j  0.   +0.j -0.   +0.j]
#  [ 0.   +0.j  0.   -0.j  0.244+0.j -0.   -0.j]
#  [-0.043+0.j -0.   -0.j -0.   +0.j -0.073+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=24ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.963  0.269 -0.   ]
#  [ 0.269  0.963 -0.   ]]
# Center:
# [-0.    -0.     0.668]
# Axes:
# [0.012 0.016 0.016]
# choi state:
# [[ 0.584+0.j    -0.002-0.002j -0.002+0.002j  0.001+0.j   ]
#  [-0.002+0.002j  0.25 +0.j    -0.001-0.003j  0.002-0.002j]
#  [-0.002-0.002j -0.001+0.003j  0.25 +0.j     0.002+0.002j]
#  [ 0.001+0.j     0.002+0.002j  0.002-0.002j -0.084+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.963  0.269 -0.   ]
#  [ 0.269  0.963 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.    -0.     0.668]
# Axes:
# [0.016 0.016 0.012]
# choi state:
# [[ 0.581+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.253+0.j    -0.008+0.002j -0.   +0.j   ]
#  [ 0.   +0.j    -0.008-0.002j  0.253+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.087+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=26ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.962  0.273 -0.   ]
#  [ 0.273  0.962 -0.   ]]
# Center:
# [ 0.    -0.     0.658]
# Axes:
# [0.022 0.12  0.12 ]
# choi state:
# [[ 0.579+0.j    -0.014-0.014j -0.014+0.014j  0.008+0.j   ]
#  [-0.014+0.014j  0.25 +0.j    -0.008-0.005j  0.014-0.014j]
#  [-0.014-0.014j -0.008+0.005j  0.25 +0.j     0.014+0.014j]
#  [ 0.008+0.j     0.014+0.014j  0.014-0.014j -0.079+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.962  0.273 -0.   ]
#  [ 0.273  0.962 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.658]
# Axes:
# [0.12  0.12  0.022]
# choi state:
# [[ 0.573+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.256+0.j    -0.058+0.016j -0.   -0.j   ]
#  [ 0.   +0.j    -0.058-0.016j  0.256+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.084+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=28ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.957  0.29  -0.   ]
#  [ 0.29   0.957 -0.   ]]
# Center:
# [ 0.    -0.     0.626]
# Axes:
# [0.054 0.222 0.222]
# choi state:
# [[ 0.563+0.j    -0.026-0.027j -0.026+0.027j  0.016+0.j   ]
#  [-0.026+0.027j  0.25 +0.j    -0.016-0.013j  0.026-0.027j]
#  [-0.026-0.027j -0.016+0.013j  0.25 +0.j     0.026+0.027j]
#  [ 0.016+0.j     0.026+0.027j  0.026-0.027j -0.063+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.957  0.29  -0.   ]
#  [ 0.29   0.957 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.626]
# Axes:
# [0.222 0.222 0.054]
# choi state:
# [[ 0.55 +0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.263+0.j    -0.106+0.032j -0.   -0.j   ]
#  [ 0.   +0.j    -0.106-0.032j  0.263+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.077+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=30ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.952  0.307 -0.   ]
#  [ 0.307  0.952 -0.   ]]
# Center:
# [ 0.    -0.     0.576]
# Axes:
# [0.104 0.319 0.319]
# choi state:
# [[ 0.538+0.j    -0.036-0.038j -0.036+0.038j  0.024+0.j   ]
#  [-0.036+0.038j  0.25 +0.j    -0.024-0.025j  0.036-0.038j]
#  [-0.036-0.038j -0.024+0.025j  0.25 +0.j     0.036+0.038j]
#  [ 0.024+0.j     0.036+0.038j  0.036-0.038j -0.038+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.952  0.307 -0.   ]
#  [ 0.307  0.952 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.576]
# Axes:
# [0.319 0.319 0.104]
# choi state:
# [[ 0.512+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.276+0.j    -0.152+0.049j -0.   -0.j   ]
#  [ 0.   +0.j    -0.152-0.049j  0.276+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.064+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=32ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.938  0.347 -0.   ]
#  [ 0.347  0.938 -0.   ]]
# Center:
# [ 0.    -0.     0.511]
# Axes:
# [0.169 0.409 0.409]
# choi state:
# [[ 0.505+0.j    -0.044-0.048j -0.044+0.048j  0.035+0.j   ]
#  [-0.044+0.048j  0.25 +0.j    -0.035-0.04j   0.044-0.048j]
#  [-0.044-0.048j -0.035+0.04j   0.25 +0.j     0.044+0.048j]
#  [ 0.035+0.j     0.044+0.048j  0.044-0.048j -0.005+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.938  0.347 -0.   ]
#  [ 0.347  0.938 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.511]
# Axes:
# [0.409 0.409 0.169]
# choi state:
# [[ 0.463+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.292+0.j    -0.192+0.071j  0.   -0.j   ]
#  [ 0.   +0.j    -0.192-0.071j  0.292+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.048+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=34ns:
# R:
# [[-0.935  0.355  0.   ]
#  [ 0.355  0.935  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.435]
# Axes:
# [0.493 0.493 0.245]
# choi state:
# [[ 0.406+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.311+0.j    -0.23 +0.087j  0.   -0.j   ]
#  [ 0.   -0.j    -0.23 -0.087j  0.311+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.029+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.935  0.355  0.   ]
#  [ 0.355  0.935  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.435]
# Axes:
# [0.493 0.493 0.245]
# choi state:
# [[ 0.406+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.311+0.j    -0.23 +0.087j  0.   -0.j   ]
#  [ 0.   -0.j    -0.23 -0.087j  0.311+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.029+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=36ns:
# R:
# [[-0.874  0.486  0.   ]
#  [ 0.486  0.874  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.353]
# Axes:
# [0.567 0.567 0.327]
# choi state:
# [[ 0.345+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.332+0.j    -0.248+0.138j  0.   -0.j   ]
#  [ 0.   -0.j    -0.248-0.138j  0.332+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.008+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.874  0.486  0.   ]
#  [ 0.486  0.874  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.353]
# Axes:
# [0.567 0.567 0.327]
# choi state:
# [[ 0.345+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.332+0.j    -0.248+0.138j  0.   -0.j   ]
#  [ 0.   -0.j    -0.248-0.138j  0.332+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.008+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=38ns:
# R:
# [[ 0.   -0.    1.  ]
#  [ 0.65  0.76  0.  ]
#  [-0.76  0.65  0.  ]]
# Center:
# [ 0.    -0.     0.272]
# Axes:
# [0.408 0.631 0.631]
# choi state:
# [[ 0.386+0.j     0.04 -0.051j  0.04 +0.051j  0.12 +0.j   ]
#  [ 0.04 +0.051j  0.25 +0.j    -0.12 +0.066j -0.04 -0.051j]
#  [ 0.04 -0.051j -0.12 -0.066j  0.25 +0.j    -0.04 +0.051j]
#  [ 0.12 +0.j    -0.04 +0.051j -0.04 -0.051j  0.114+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.76 -0.65 -0.  ]
#  [ 0.65  0.76  0.  ]
#  [ 0.   -0.    1.  ]]
# Center:
# [ 0.    -0.     0.272]
# Axes:
# [0.631 0.631 0.408]
# choi state:
# [[ 0.488+0.j  0.   +0.j  0.   -0.j  0.24 +0.j]
#  [ 0.   -0.j  0.148+0.j -0.   -0.j  0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.148+0.j  0.   -0.j]
#  [ 0.24 +0.j  0.   -0.j  0.   +0.j  0.216+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=40ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.729  0.685  0.   ]
#  [-0.685  0.729  0.   ]]
# Center:
# [ 0.    -0.     0.197]
# Axes:
# [0.483 0.684 0.684]
# choi state:
# [[ 0.348+0.j     0.044-0.062j  0.044+0.062j  0.117+0.j   ]
#  [ 0.044+0.062j  0.25 +0.j    -0.117+0.088j -0.044-0.062j]
#  [ 0.044-0.062j -0.117-0.088j  0.25 +0.j    -0.044+0.062j]
#  [ 0.117+0.j    -0.044+0.062j -0.044-0.062j  0.152+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.729  0.685  0.   ]
#  [-0.685  0.729  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.197]
# Axes:
# [0.684 0.684 0.483]
# choi state:
# [[ 0.469+0.j  0.   +0.j  0.   -0.j  0.249+0.j]
#  [ 0.   -0.j  0.129+0.j  0.   -0.j -0.   +0.j]
#  [ 0.   +0.j  0.   +0.j  0.129+0.j -0.   -0.j]
#  [ 0.249+0.j -0.   -0.j -0.   +0.j  0.272+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=42ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.764  0.645 -0.   ]
#  [-0.645  0.764  0.   ]]
# Center:
# [ 0.    -0.     0.132]
# Axes:
# [0.548 0.726 0.726]
# choi state:
# [[ 0.316+0.j     0.047-0.069j  0.047+0.069j  0.117+0.j   ]
#  [ 0.047+0.069j  0.25 +0.j    -0.117+0.105j -0.047-0.069j]
#  [ 0.047-0.069j -0.117-0.105j  0.25 +0.j    -0.047+0.069j]
#  [ 0.117+0.j    -0.047+0.069j -0.047-0.069j  0.184+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.764  0.645 -0.   ]
#  [-0.645  0.764  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.132]
# Axes:
# [0.726 0.726 0.548]
# choi state:
# [[ 0.453+0.j  0.   -0.j  0.   +0.j  0.277+0.j]
#  [ 0.   +0.j  0.113+0.j  0.   -0.j -0.   -0.j]
#  [ 0.   -0.j  0.   +0.j  0.113+0.j -0.   +0.j]
#  [ 0.277+0.j -0.   +0.j -0.   -0.j  0.321+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=44ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.998  0.061  0.   ]
#  [-0.061 -0.998 -0.   ]]
# Center:
# [-0.     0.     0.082]
# Axes:
# [0.598 0.754 0.754]
# choi state:
# [[ 0.291+0.j     0.09 +0.094j  0.09 -0.094j  0.012+0.j   ]
#  [ 0.09 -0.094j  0.25 +0.j    -0.012-0.149j -0.09 +0.094j]
#  [ 0.09 +0.094j -0.012+0.149j  0.25 +0.j    -0.09 -0.094j]
#  [ 0.012+0.j    -0.09 -0.094j -0.09 +0.094j  0.209+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.998  0.061  0.   ]
#  [-0.061 -0.998 -0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [-0.     0.     0.082]
# Axes:
# [0.754 0.754 0.598]
# choi state:
# [[ 0.441+0.j  0.   +0.j  0.   -0.j -0.376+0.j]
#  [ 0.   -0.j  0.101+0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.101+0.j -0.   -0.j]
#  [-0.376+0.j -0.   -0.j -0.   +0.j  0.358+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=46ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.838  0.546  0.   ]
#  [-0.546 -0.838 -0.   ]]
# Center:
# [-0.     0.     0.051]
# Axes:
# [0.629 0.77  0.77 ]
# choi state:
# [[ 0.275+0.j     0.053+0.081j  0.053-0.081j  0.105+0.j   ]
#  [ 0.053-0.081j  0.25 +0.j    -0.105-0.132j -0.053+0.081j]
#  [ 0.053+0.081j -0.105+0.132j  0.25 +0.j    -0.053-0.081j]
#  [ 0.105+0.j    -0.053-0.081j -0.053+0.081j  0.225+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.838  0.546  0.   ]
#  [-0.546 -0.838 -0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [-0.     0.     0.051]
# Axes:
# [0.77  0.77  0.629]
# choi state:
# [[ 0.433+0.j  0.   +0.j  0.   -0.j -0.323+0.j]
#  [ 0.   -0.j  0.093+0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.093+0.j -0.   -0.j]
#  [-0.323+0.j -0.   -0.j -0.   +0.j  0.382+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=48ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.841  0.541  0.   ]
#  [-0.541 -0.841 -0.   ]]
# Center:
# [-0.     0.     0.039]
# Axes:
# [0.641 0.773 0.773]
# choi state:
# [[ 0.27 +0.j     0.053+0.081j  0.053-0.081j  0.105+0.j   ]
#  [ 0.053-0.081j  0.25 +0.j    -0.105-0.135j -0.053+0.081j]
#  [ 0.053+0.081j -0.105+0.135j  0.25 +0.j    -0.053-0.081j]
#  [ 0.105+0.j    -0.053-0.081j -0.053+0.081j  0.23 +0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.841  0.541  0.   ]
#  [-0.541 -0.841 -0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [-0.     0.     0.039]
# Axes:
# [0.773 0.773 0.641]
# choi state:
# [[ 0.43 +0.j  0.   +0.j  0.   -0.j -0.325+0.j]
#  [ 0.   -0.j  0.09 +0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.09 +0.j -0.   -0.j]
#  [-0.325+0.j -0.   -0.j -0.   +0.j  0.391+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=50ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.846  0.533  0.   ]
#  [-0.533 -0.846  0.   ]]
# Center:
# [-0.     0.     0.049]
# Axes:
# [0.631 0.762 0.762]
# choi state:
# [[ 0.274+0.j     0.053+0.081j  0.053-0.081j  0.102+0.j   ]
#  [ 0.053-0.081j  0.25 +0.j    -0.102-0.133j -0.053+0.081j]
#  [ 0.053+0.081j -0.102+0.133j  0.25 +0.j    -0.053-0.081j]
#  [ 0.102+0.j    -0.053-0.081j -0.053+0.081j  0.226+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.846  0.533  0.   ]
#  [-0.533 -0.846  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [-0.     0.     0.049]
# Axes:
# [0.762 0.762 0.631]
# choi state:
# [[ 0.432+0.j  0.   +0.j  0.   -0.j -0.322+0.j]
#  [ 0.   -0.j  0.092+0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.092+0.j -0.   -0.j]
#  [-0.322+0.j -0.   -0.j -0.   +0.j  0.383+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=52ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.849  0.528  0.   ]
#  [-0.528 -0.849  0.   ]]
# Center:
# [-0.     0.     0.079]
# Axes:
# [0.601 0.739 0.739]
# choi state:
# [[ 0.289+0.j     0.053+0.078j  0.053-0.078j  0.098+0.j   ]
#  [ 0.053-0.078j  0.25 +0.j    -0.098-0.128j -0.053+0.078j]
#  [ 0.053+0.078j -0.098+0.128j  0.25 +0.j    -0.053-0.078j]
#  [ 0.098+0.j    -0.053-0.078j -0.053+0.078j  0.211+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.849  0.528  0.   ]
#  [-0.528 -0.849  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [-0.     0.     0.079]
# Axes:
# [0.739 0.739 0.601]
# choi state:
# [[ 0.44 +0.j  0.   +0.j  0.   -0.j -0.314+0.j]
#  [ 0.   -0.j  0.1  +0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.1  +0.j -0.   -0.j]
#  [-0.314+0.j -0.   -0.j -0.   +0.j  0.361+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=54ns:
# R:
# [[ 0.    -0.     1.   ]
#  [-0.855  0.518  0.   ]
#  [-0.518 -0.855  0.   ]]
# Center:
# [-0.     0.     0.126]
# Axes:
# [0.554 0.703 0.703]
# choi state:
# [[ 0.313+0.j     0.052+0.075j  0.052-0.075j  0.091+0.j   ]
#  [ 0.052-0.075j  0.25 +0.j    -0.091-0.118j -0.052+0.075j]
#  [ 0.052+0.075j -0.091+0.118j  0.25 +0.j    -0.052-0.075j]
#  [ 0.091+0.j    -0.052-0.075j -0.052+0.075j  0.187+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.855  0.518  0.   ]
#  [-0.518 -0.855  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [-0.     0.     0.126]
# Axes:
# [0.703 0.703 0.554]
# choi state:
# [[ 0.452+0.j  0.   +0.j  0.   -0.j -0.301+0.j]
#  [ 0.   -0.j  0.112+0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.112+0.j -0.   -0.j]
#  [-0.301+0.j -0.   -0.j -0.   +0.j  0.325+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=56ns:
# R:
# [[ 0.849 -0.528 -0.   ]
#  [-0.528 -0.849  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.189]
# Axes:
# [0.656 0.656 0.491]
# choi state:
# [[ 0.221+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.373+0.j     0.278-0.173j  0.   -0.j   ]
#  [-0.   -0.j     0.278+0.173j  0.373+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j     0.033+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.849 -0.528 -0.   ]
#  [-0.528 -0.849  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.189]
# Axes:
# [0.656 0.656 0.491]
# choi state:
# [[ 0.221+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.373+0.j     0.278-0.173j  0.   -0.j   ]
#  [-0.   -0.j     0.278+0.173j  0.373+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j     0.033+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=58ns:
# R:
# [[ 0.845 -0.535 -0.   ]
#  [-0.535 -0.845  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.261]
# Axes:
# [0.598 0.598 0.419]
# choi state:
# [[ 0.276+0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.355+0.j    0.252-0.16j  0.   +0.j  ]
#  [-0.   -0.j    0.252+0.16j  0.355+0.j    0.   -0.j  ]
#  [ 0.   +0.j    0.   -0.j    0.   +0.j    0.015+0.j  ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.845 -0.535 -0.   ]
#  [-0.535 -0.845  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.261]
# Axes:
# [0.598 0.598 0.419]
# choi state:
# [[ 0.276+0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.355+0.j    0.252-0.16j  0.   +0.j  ]
#  [-0.   -0.j    0.252+0.16j  0.355+0.j    0.   -0.j  ]
#  [ 0.   +0.j    0.   -0.j    0.   +0.j    0.015+0.j  ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=60ns:
# R:
# [[ 0.823 -0.567  0.   ]
#  [-0.567 -0.823  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.339]
# Axes:
# [0.53  0.53  0.341]
# choi state:
# [[ 0.334+0.j   -0.   +0.j   -0.   -0.j    0.   +0.j  ]
#  [-0.   -0.j    0.335+0.j    0.218-0.15j -0.   +0.j  ]
#  [-0.   +0.j    0.218+0.15j  0.335+0.j   -0.   -0.j  ]
#  [ 0.   +0.j   -0.   -0.j   -0.   +0.j   -0.005+0.j  ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.823 -0.567  0.   ]
#  [-0.567 -0.823  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.339]
# Axes:
# [0.53  0.53  0.341]
# choi state:
# [[ 0.334+0.j   -0.   +0.j   -0.   -0.j    0.   +0.j  ]
#  [-0.   -0.j    0.335+0.j    0.218-0.15j -0.   +0.j  ]
#  [-0.   +0.j    0.218+0.15j  0.335+0.j   -0.   -0.j  ]
#  [ 0.   +0.j   -0.   -0.j   -0.   +0.j   -0.005+0.j  ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=62ns:
# R:
# [[-0.729 -0.684  0.   ]
#  [-0.684  0.729 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.417]
# Axes:
# [0.453 0.453 0.263]
# choi state:
# [[ 0.393+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.316+0.j    -0.165-0.155j -0.   +0.j   ]
#  [ 0.   +0.j    -0.165+0.155j  0.316+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.024+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.729 -0.684  0.   ]
#  [-0.684  0.729 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.417]
# Axes:
# [0.453 0.453 0.263]
# choi state:
# [[ 0.393+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.316+0.j    -0.165-0.155j -0.   +0.j   ]
#  [ 0.   +0.j    -0.165+0.155j  0.316+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.024+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=64ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [ 0.863  0.506  0.   ]
#  [ 0.506 -0.863  0.   ]]
# Center:
# [0.   0.   0.49]
# Axes:
# [0.19 0.37 0.37]
# choi state:
# [[ 0.495+0.j    -0.034+0.04j  -0.034-0.04j   0.047+0.j   ]
#  [-0.034-0.04j   0.25 +0.j    -0.047+0.041j  0.034+0.04j ]
#  [-0.034+0.04j  -0.047-0.041j  0.25 +0.j     0.034-0.04j ]
#  [ 0.047+0.j     0.034-0.04j   0.034+0.04j   0.005+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.863  0.506  0.   ]
#  [ 0.506 -0.863  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [0.   0.   0.49]
# Axes:
# [0.37 0.37 0.19]
# choi state:
# [[ 0.448+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.297+0.j     0.16 +0.094j -0.   +0.j   ]
#  [ 0.   +0.j     0.16 -0.094j  0.297+0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j    -0.043+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=66ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [ 0.941  0.338  0.   ]
#  [ 0.338 -0.941  0.   ]]
# Center:
# [ 0.    -0.     0.553]
# Axes:
# [0.127 0.281 0.281]
# choi state:
# [[ 0.527+0.j    -0.03 +0.033j -0.03 -0.033j  0.024+0.j   ]
#  [-0.03 -0.033j  0.25 +0.j    -0.024+0.03j   0.03 +0.033j]
#  [-0.03 +0.033j -0.024-0.03j   0.25 +0.j     0.03 -0.033j]
#  [ 0.024+0.j     0.03 -0.033j  0.03 +0.033j -0.027+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.941  0.338  0.   ]
#  [ 0.338 -0.941  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.553]
# Axes:
# [0.281 0.281 0.127]
# choi state:
# [[ 0.495+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.282+0.j     0.132+0.047j -0.   +0.j   ]
#  [ 0.   +0.j     0.132-0.047j  0.282+0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j    -0.058+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=68ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [ 0.994  0.105  0.   ]
#  [ 0.105 -0.994  0.   ]]
# Center:
# [ 0.    -0.     0.602]
# Axes:
# [0.078 0.188 0.188]
# choi state:
# [[ 0.551+0.j    -0.022+0.023j -0.022-0.023j  0.005+0.j   ]
#  [-0.022-0.023j  0.25 +0.j    -0.005+0.019j  0.022+0.023j]
#  [-0.022+0.023j -0.005-0.019j  0.25 +0.j     0.022-0.023j]
#  [ 0.005+0.j     0.022-0.023j  0.022+0.023j -0.051+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.994  0.105  0.   ]
#  [ 0.105 -0.994  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.602]
# Axes:
# [0.188 0.188 0.078]
# choi state:
# [[ 0.532+0.j    0.   +0.j    0.   -0.j   -0.   +0.j  ]
#  [ 0.   -0.j    0.269+0.j    0.093+0.01j -0.   +0.j  ]
#  [ 0.   +0.j    0.093-0.01j  0.269+0.j   -0.   -0.j  ]
#  [-0.   +0.j   -0.   -0.j   -0.   +0.j   -0.071+0.j  ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=70ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.998  0.065 -0.   ]
#  [ 0.065  0.998 -0.   ]]
# Center:
# [ 0.    -0.     0.634]
# Axes:
# [0.046 0.092 0.092]
# choi state:
# [[ 0.567+0.j    -0.011-0.011j -0.011+0.011j  0.001+0.j   ]
#  [-0.011+0.011j  0.25 +0.j    -0.001-0.011j  0.011-0.011j]
#  [-0.011-0.011j -0.001+0.011j  0.25 +0.j     0.011+0.011j]
#  [ 0.001+0.j     0.011+0.011j  0.011-0.011j -0.067+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.998  0.065 -0.   ]
#  [ 0.065  0.998 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.634]
# Axes:
# [0.092 0.092 0.046]
# choi state:
# [[ 0.555+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.262+0.j    -0.046+0.003j -0.   +0.j   ]
#  [ 0.   +0.j    -0.046-0.003j  0.262+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.078+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=72ns:
# R:
# [[-0.994  0.11  -0.   ]
#  [ 0.11   0.994 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.646]
# Axes:
# [0.005 0.005 0.034]
# choi state:
# [[ 0.565+0.j -0.   +0.j -0.   -0.j  0.   +0.j]
#  [-0.   -0.j  0.258+0.j -0.002+0.j  0.   +0.j]
#  [-0.   +0.j -0.002-0.j  0.258+0.j  0.   -0.j]
#  [ 0.   +0.j  0.   -0.j  0.   +0.j -0.082+0.j]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.994  0.11  -0.   ]
#  [ 0.11   0.994 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.646]
# Axes:
# [0.005 0.005 0.034]
# choi state:
# [[ 0.565+0.j -0.   +0.j -0.   -0.j  0.   +0.j]
#  [-0.   -0.j  0.258+0.j -0.002+0.j  0.   +0.j]
#  [-0.   +0.j -0.002-0.j  0.258+0.j  0.   -0.j]
#  [ 0.   +0.j  0.   -0.j  0.   +0.j -0.082+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=74ns:
# R:
# [[ 0.     0.     1.   ]
#  [-0.953  0.304  0.   ]
#  [-0.304 -0.953  0.   ]]
# Center:
# [-0.     0.     0.639]
# Axes:
# [0.041 0.101 0.101]
# choi state:
# [[ 0.569+0.j     0.011+0.012j  0.011-0.012j  0.008+0.j   ]
#  [ 0.011-0.012j  0.25 +0.j    -0.008-0.01j  -0.011+0.012j]
#  [ 0.011+0.012j -0.008+0.01j   0.25 +0.j    -0.011-0.012j]
#  [ 0.008+0.j    -0.011-0.012j -0.011+0.012j -0.069+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.953  0.304  0.   ]
#  [-0.304 -0.953  0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [-0.     0.     0.639]
# Axes:
# [0.101 0.101 0.041]
# choi state:
# [[ 0.58 +0.j  0.   -0.j  0.   +0.j -0.048+0.j]
#  [ 0.   +0.j  0.24 +0.j  0.   +0.j -0.   +0.j]
#  [ 0.   -0.j  0.   -0.j  0.24 +0.j -0.   -0.j]
#  [-0.048+0.j -0.   -0.j -0.   +0.j -0.059+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=76ns:
# R:
# [[ 0.     0.     1.   ]
#  [-0.918  0.397  0.   ]
#  [-0.397 -0.918  0.   ]]
# Center:
# [-0.     0.     0.612]
# Axes:
# [0.068 0.194 0.194]
# choi state:
# [[ 0.556+0.j     0.021+0.022j  0.021-0.022j  0.019+0.j   ]
#  [ 0.021-0.022j  0.25 +0.j    -0.019-0.016j -0.021+0.022j]
#  [ 0.021+0.022j -0.019+0.016j  0.25 +0.j    -0.021-0.022j]
#  [ 0.019+0.j    -0.021-0.022j -0.021+0.022j -0.056+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.918  0.397  0.   ]
#  [-0.397 -0.918  0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [-0.     0.     0.612]
# Axes:
# [0.194 0.194 0.068]
# choi state:
# [[ 0.573+0.j  0.   -0.j  0.   +0.j -0.089+0.j]
#  [ 0.   +0.j  0.233+0.j  0.   +0.j -0.   +0.j]
#  [ 0.   -0.j  0.   -0.j  0.233+0.j -0.   -0.j]
#  [-0.089+0.j -0.   -0.j -0.   +0.j -0.039+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=78ns:
# R:
# [[ 0.     0.     1.   ]
#  [-0.886  0.464  0.   ]
#  [-0.464 -0.886  0.   ]]
# Center:
# [-0.     0.     0.568]
# Axes:
# [0.112 0.284 0.284]
# choi state:
# [[ 0.534+0.j     0.029+0.031j  0.029-0.031j  0.033+0.j   ]
#  [ 0.029-0.031j  0.25 +0.j    -0.033-0.025j -0.029+0.031j]
#  [ 0.029+0.031j -0.033+0.025j  0.25 +0.j    -0.029-0.031j]
#  [ 0.033+0.j    -0.029-0.031j -0.029+0.031j -0.034+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.886  0.464  0.   ]
#  [-0.464 -0.886  0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [-0.     0.     0.568]
# Axes:
# [0.284 0.284 0.112]
# choi state:
# [[ 0.562+0.j  0.   -0.j  0.   +0.j -0.126+0.j]
#  [ 0.   +0.j  0.222+0.j  0.   +0.j -0.   +0.j]
#  [ 0.   -0.j  0.   -0.j  0.222+0.j -0.   -0.j]
#  [-0.126+0.j -0.   -0.j -0.   +0.j -0.006+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=80ns:
# R:
# [[ 0.     0.     1.   ]
#  [-0.845  0.535  0.   ]
#  [-0.535 -0.845  0.   ]]
# Center:
# [-0.    0.    0.51]
# Axes:
# [0.17  0.368 0.368]
# choi state:
# [[ 0.505+0.j     0.035+0.039j  0.035-0.039j  0.049+0.j   ]
#  [ 0.035-0.039j  0.25 +0.j    -0.049-0.036j -0.035+0.039j]
#  [ 0.035+0.039j -0.049+0.036j  0.25 +0.j    -0.035-0.039j]
#  [ 0.049+0.j    -0.035-0.039j -0.035+0.039j -0.005+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.845  0.535  0.   ]
#  [-0.535 -0.845  0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [-0.    0.    0.51]
# Axes:
# [0.368 0.368 0.17 ]
# choi state:
# [[ 0.547+0.j  0.   -0.j  0.   +0.j -0.155+0.j]
#  [ 0.   +0.j  0.207+0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.207+0.j -0.   +0.j]
#  [-0.155+0.j -0.   +0.j -0.   -0.j  0.038+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=82ns:
# R:
# [[-0.81   0.586 -0.   ]
#  [ 0.586  0.81  -0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.442]
# Axes:
# [0.445 0.445 0.238]
# choi state:
# [[ 0.411+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.31 +0.j    -0.18 +0.131j  0.   +0.j   ]
#  [-0.   +0.j    -0.18 -0.131j  0.31 +0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j    -0.03 +0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.81   0.586 -0.   ]
#  [ 0.586  0.81  -0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.442]
# Axes:
# [0.445 0.445 0.238]
# choi state:
# [[ 0.411+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.31 +0.j    -0.18 +0.131j  0.   +0.j   ]
#  [-0.   +0.j    -0.18 -0.131j  0.31 +0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j    -0.03 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=84ns:
# R:
# [[ 0.881 -0.473  0.   ]
#  [-0.473 -0.881  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.368]
# Axes:
# [0.514 0.514 0.312]
# choi state:
# [[ 0.356+0.j    -0.   -0.j    -0.   +0.j    -0.   +0.j   ]
#  [-0.   +0.j     0.328+0.j     0.227-0.122j  0.   +0.j   ]
#  [-0.   -0.j     0.227+0.122j  0.328+0.j     0.   -0.j   ]
#  [-0.   +0.j     0.   -0.j     0.   +0.j    -0.012+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.881 -0.473  0.   ]
#  [-0.473 -0.881  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.368]
# Axes:
# [0.514 0.514 0.312]
# choi state:
# [[ 0.356+0.j    -0.   -0.j    -0.   +0.j    -0.   +0.j   ]
#  [-0.   +0.j     0.328+0.j     0.227-0.122j  0.   +0.j   ]
#  [-0.   -0.j     0.227+0.122j  0.328+0.j     0.   -0.j   ]
#  [-0.   +0.j     0.   -0.j     0.   +0.j    -0.012+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=86ns:
# R:
# [[-0.827  0.563 -0.   ]
#  [ 0.563  0.827 -0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.294]
# Axes:
# [0.575 0.575 0.386]
# choi state:
# [[ 0.301+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.346+0.j    -0.237+0.162j  0.   +0.j   ]
#  [-0.   +0.j    -0.237-0.162j  0.346+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.006+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.827  0.563 -0.   ]
#  [ 0.563  0.827 -0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.294]
# Axes:
# [0.575 0.575 0.386]
# choi state:
# [[ 0.301+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.346+0.j    -0.237+0.162j  0.   +0.j   ]
#  [-0.   +0.j    -0.237-0.162j  0.346+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.006+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=88ns:
# R:
# [[ 0.833  0.553 -0.   ]
#  [ 0.553 -0.833  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.225]
# Axes:
# [0.624 0.624 0.455]
# choi state:
# [[ 0.249+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.364+0.j     0.26 +0.173j  0.   +0.j   ]
#  [-0.   -0.j     0.26 -0.173j  0.364+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.024+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.833  0.553 -0.   ]
#  [ 0.553 -0.833  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.225]
# Axes:
# [0.624 0.624 0.455]
# choi state:
# [[ 0.249+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.364+0.j     0.26 +0.173j  0.   +0.j   ]
#  [-0.   -0.j     0.26 -0.173j  0.364+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.024+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=90ns:
# R:
# [[ 0.918  0.395 -0.   ]
#  [ 0.395 -0.918  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.165]
# Axes:
# [0.664 0.664 0.515]
# choi state:
# [[ 0.204+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.379+0.j     0.305+0.131j  0.   +0.j   ]
#  [-0.   -0.j     0.305-0.131j  0.379+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.039+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.918  0.395 -0.   ]
#  [ 0.395 -0.918  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.165]
# Axes:
# [0.664 0.664 0.515]
# choi state:
# [[ 0.204+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.379+0.j     0.305+0.131j  0.   +0.j   ]
#  [-0.   -0.j     0.305-0.131j  0.379+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.039+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=92ns:
# R:
# [[ 0.987  0.162  0.   ]
#  [ 0.162 -0.987  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.118]
# Axes:
# [0.691 0.691 0.562]
# choi state:
# [[ 0.169+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.39 +0.j     0.341+0.056j -0.   +0.j   ]
#  [ 0.   -0.j     0.341-0.056j  0.39 +0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j     0.05 +0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.987  0.162  0.   ]
#  [ 0.162 -0.987  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.118]
# Axes:
# [0.691 0.691 0.562]
# choi state:
# [[ 0.169+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.39 +0.j     0.341+0.056j -0.   +0.j   ]
#  [ 0.   -0.j     0.341-0.056j  0.39 +0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j     0.05 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=94ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.998  0.059 -0.   ]
#  [ 0.059  0.998 -0.   ]]
# Center:
# [0.    0.    0.088]
# Axes:
# [0.592 0.707 0.707]
# choi state:
# [[ 0.294+0.j    -0.084-0.088j -0.084+0.088j  0.01 +0.j   ]
#  [-0.084+0.088j  0.25 +0.j    -0.01 -0.148j  0.084-0.088j]
#  [-0.084-0.088j -0.01 +0.148j  0.25 +0.j     0.084+0.088j]
#  [ 0.01 +0.j     0.084+0.088j  0.084-0.088j  0.206+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.998  0.059 -0.   ]
#  [ 0.059  0.998 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [0.    0.    0.088]
# Axes:
# [0.707 0.707 0.592]
# choi state:
# [[ 0.146+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.398+0.j    -0.353+0.021j  0.   +0.j   ]
#  [ 0.   +0.j    -0.353-0.021j  0.398+0.j     0.   -0.j   ]
#  [-0.   +0.j     0.   -0.j     0.   +0.j     0.058+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=96ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.978  0.211 -0.   ]
#  [ 0.211  0.978  0.   ]]
# Center:
# [ 0.    -0.     0.076]
# Axes:
# [0.604 0.71  0.71 ]
# choi state:
# [[ 0.288+0.j    -0.073-0.087j -0.073+0.087j  0.037+0.j   ]
#  [-0.073+0.087j  0.25 +0.j    -0.037-0.148j  0.073-0.087j]
#  [-0.073-0.087j -0.037+0.148j  0.25 +0.j     0.073+0.087j]
#  [ 0.037+0.j     0.073+0.087j  0.073-0.087j  0.212+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.978  0.211 -0.   ]
#  [ 0.211  0.978  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.076]
# Axes:
# [0.71  0.71  0.604]
# choi state:
# [[ 0.137+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.401+0.j    -0.347+0.075j -0.   -0.j   ]
#  [ 0.   +0.j    -0.347-0.075j  0.401+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j     0.061+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=98ns:
# R:
# [[ 0.     0.    -1.   ]
#  [-0.939  0.345 -0.   ]
#  [ 0.345  0.939  0.   ]]
# Center:
# [ 0.    -0.     0.083]
# Axes:
# [0.597 0.702 0.702]
# choi state:
# [[ 0.291+0.j    -0.062-0.082j -0.062+0.082j  0.061+0.j   ]
#  [-0.062+0.082j  0.25 +0.j    -0.061-0.14j   0.062-0.082j]
#  [-0.062-0.082j -0.061+0.14j   0.25 +0.j     0.062+0.082j]
#  [ 0.061+0.j     0.062+0.082j  0.062-0.082j  0.209+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.939  0.345 -0.   ]
#  [ 0.345  0.939  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.083]
# Axes:
# [0.702 0.702 0.597]
# choi state:
# [[ 0.142+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.399+0.j    -0.329+0.121j -0.   -0.j   ]
#  [ 0.   -0.j    -0.329-0.121j  0.399+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j     0.059+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=100ns:
# R:
# [[ 0.     0.    -1.   ]
#  [-0.9    0.437 -0.   ]
#  [ 0.437  0.9    0.   ]]
# Center:
# [-0.    -0.     0.108]
# Axes:
# [0.572 0.682 0.682]
# choi state:
# [[ 0.304+0.j    -0.054-0.077j -0.054+0.077j  0.074+0.j   ]
#  [-0.054+0.077j  0.25 +0.j    -0.074-0.129j  0.054-0.077j]
#  [-0.054-0.077j -0.074+0.129j  0.25 +0.j     0.054+0.077j]
#  [ 0.074+0.j     0.054+0.077j  0.054-0.077j  0.196+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.9    0.437 -0.   ]
#  [ 0.437  0.9    0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.108]
# Axes:
# [0.682 0.682 0.572]
# choi state:
# [[ 0.161+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.393+0.j    -0.307+0.149j -0.   -0.j   ]
#  [ 0.   -0.j    -0.307-0.149j  0.393+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j     0.053+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=102ns:
# R:
# [[ 0.     0.    -1.   ]
#  [-0.856  0.517 -0.   ]
#  [ 0.517  0.856  0.   ]]
# Center:
# [-0.   -0.    0.15]
# Axes:
# [0.53 0.65 0.65]
# choi state:
# [[ 0.325+0.j    -0.047-0.07j  -0.047+0.07j   0.084+0.j   ]
#  [-0.047+0.07j   0.25 +0.j    -0.084-0.113j  0.047-0.07j ]
#  [-0.047-0.07j  -0.084+0.113j  0.25 +0.j     0.047+0.07j ]
#  [ 0.084+0.j     0.047+0.07j   0.047-0.07j   0.175+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.856  0.517 -0.   ]
#  [ 0.517  0.856  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.   -0.    0.15]
# Axes:
# [0.65 0.65 0.53]
# choi state:
# [[ 0.192+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.383+0.j    -0.278+0.168j -0.   -0.j   ]
#  [ 0.   -0.j    -0.278-0.168j  0.383+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j     0.043+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=104ns:
# R:
# [[ 0.     0.    -1.   ]
#  [-0.788  0.616 -0.   ]
#  [ 0.616  0.788  0.   ]]
# Center:
# [-0.    -0.     0.205]
# Axes:
# [0.475 0.608 0.608]
# choi state:
# [[ 0.353+0.j    -0.039-0.06j  -0.039+0.06j   0.094+0.j   ]
#  [-0.039+0.06j   0.25 +0.j    -0.094-0.094j  0.039-0.06j ]
#  [-0.039-0.06j  -0.094+0.094j  0.25 +0.j     0.039+0.06j ]
#  [ 0.094+0.j     0.039+0.06j   0.039-0.06j   0.147+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.788  0.616 -0.   ]
#  [ 0.616  0.788  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.205]
# Axes:
# [0.608 0.608 0.475]
# choi state:
# [[ 0.234+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.369+0.j    -0.239+0.187j -0.   -0.j   ]
#  [ 0.   -0.j    -0.239-0.187j  0.369+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j     0.029+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=106ns:
# R:
# [[ 0.738 -0.675 -0.   ]
#  [-0.675 -0.738 -0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.271]
# Axes:
# [0.555 0.555 0.409]
# choi state:
# [[ 0.283+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.352+0.j     0.205-0.187j -0.   -0.j   ]
#  [ 0.   +0.j     0.205+0.187j  0.352+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j     0.012+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.738 -0.675 -0.   ]
#  [-0.675 -0.738 -0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.271]
# Axes:
# [0.555 0.555 0.409]
# choi state:
# [[ 0.283+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.352+0.j     0.205-0.187j -0.   -0.j   ]
#  [ 0.   +0.j     0.205+0.187j  0.352+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j     0.012+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=108ns:
# R:
# [[-0.747 -0.665 -0.   ]
#  [-0.665  0.747  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.341]
# Axes:
# [0.494 0.494 0.339]
# choi state:
# [[ 0.336+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.335+0.j    -0.184-0.164j  0.   -0.j   ]
#  [-0.   -0.j    -0.184+0.164j  0.335+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.005+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.747 -0.665 -0.   ]
#  [-0.665  0.747  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.341]
# Axes:
# [0.494 0.494 0.339]
# choi state:
# [[ 0.336+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.335+0.j    -0.184-0.164j  0.   -0.j   ]
#  [-0.   -0.j    -0.184+0.164j  0.335+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.005+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=110ns:
# R:
# [[-0.87  -0.494 -0.   ]
#  [-0.494  0.87   0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.412]
# Axes:
# [0.424 0.424 0.268]
# choi state:
# [[ 0.389+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.317+0.j    -0.185-0.105j  0.   -0.j   ]
#  [-0.   -0.j    -0.185+0.105j  0.317+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.023+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.87  -0.494 -0.   ]
#  [-0.494  0.87   0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.412]
# Axes:
# [0.424 0.424 0.268]
# choi state:
# [[ 0.389+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.317+0.j    -0.185-0.105j  0.   -0.j   ]
#  [-0.   -0.j    -0.185+0.105j  0.317+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.023+0.j   ]]
# ----------------------------------------------------------------------------------------------------

# %%
from quam_libs.quantum_memory.legacy.marcos import diagnose_choi_states
tol = 1e-6
swap_choi_list = [swap_result_dict[key]["choi state"] for key in swap_result_dict.keys()]
keys = list(swap_result_dict.keys())
df = diagnose_choi_states(swap_choi_list,keys,tol_pos=tol, tol_tp=tol)

# %%
from quam_libs.quantum_memory.legacy.NoiseAnalyze import Checker
np.set_printoptions(precision=3, suppress=True)
for i,key in enumerate(swap_result_dict.keys()):
    checker = Checker(swap_choi_list[i])
    choi, count = checker.choi_checker(index=[1], repeat=100, tol=tol, print_reason=False)
    print(f"After {count} iterations, the Choi state is:\n{choi}")
    print('-'*100)
    swap_result_dict[key]["choi state"] = choi
# Out:
# After 5 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is:
# [[ 0.42+0.j    -0.  +0.j    -0.  +0.j     0.42-0.j   ]
#  [-0.  -0.j     0.08+0.j    -0.  +0.003j  0.  -0.j   ]
#  [-0.  -0.j    -0.  -0.003j  0.08+0.j    -0.  +0.j   ]
#  [ 0.42+0.j     0.  +0.j    -0.  -0.j     0.42+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.387+0.j]
#  [ 0.   -0.j  0.08 +0.j  0.   -0.j -0.   +0.j]
#  [ 0.   +0.j  0.   +0.j  0.086+0.j -0.   -0.j]
#  [-0.387-0.j -0.   -0.j -0.   +0.j  0.414+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   -0.j  0.   +0.j  0.349+0.j]
#  [ 0.   +0.j  0.08 +0.j -0.   +0.j -0.   -0.j]
#  [ 0.   -0.j -0.   -0.j  0.104+0.j -0.   +0.j]
#  [ 0.349-0.j -0.   +0.j -0.   -0.j  0.396+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   +0.j  0.314-0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   +0.j -0.   -0.j]
#  [ 0.   -0.j -0.   -0.j  0.131+0.j -0.   +0.j]
#  [ 0.314+0.j -0.   +0.j -0.   -0.j  0.369+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   -0.j  0.   +0.j  0.29 -0.j]
#  [ 0.   +0.j  0.08 +0.j -0.   +0.j -0.   -0.j]
#  [ 0.   -0.j -0.   -0.j  0.166+0.j -0.   +0.j]
#  [ 0.29 +0.j -0.   +0.j -0.   -0.j  0.334+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j  0.313+0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   +0.j -0.   +0.j]
#  [ 0.   +0.j -0.   -0.j  0.206+0.j  0.   +0.j]
#  [ 0.313-0.j -0.   -0.j  0.   -0.j  0.294+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j  0.252-0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   +0.j -0.   +0.j]
#  [ 0.   +0.j -0.   -0.j  0.249+0.j -0.   +0.j]
#  [ 0.252+0.j -0.   -0.j -0.   -0.j  0.251+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   +0.j  0.182-0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   +0.j -0.   -0.j]
#  [ 0.   -0.j -0.   -0.j  0.292+0.j -0.   +0.j]
#  [ 0.182+0.j -0.   +0.j -0.   -0.j  0.208+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.177+0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.332+0.j -0.   -0.j]
#  [-0.177-0.j -0.   -0.j -0.   +0.j  0.168+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.139-0.j]
#  [ 0.   -0.j  0.08 +0.j  0.   +0.j -0.   +0.j]
#  [ 0.   +0.j  0.   -0.j  0.366+0.j -0.   -0.j]
#  [-0.139+0.j -0.   -0.j -0.   +0.j  0.134+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.093-0.j]
#  [ 0.   -0.j  0.08 +0.j  0.   +0.j -0.   +0.j]
#  [ 0.   +0.j  0.   -0.j  0.392+0.j -0.   -0.j]
#  [-0.093+0.j -0.   -0.j -0.   +0.j  0.108+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.043-0.j]
#  [ 0.   -0.j  0.08 +0.j  0.   +0.j -0.   +0.j]
#  [ 0.   +0.j  0.   -0.j  0.408+0.j -0.   -0.j]
#  [-0.043+0.j -0.   -0.j -0.   +0.j  0.092+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.414+0.j     0.   +0.j     0.   -0.j     0.   -0.j   ]
#  [ 0.   -0.j     0.086+0.j    -0.008+0.002j -0.   +0.j   ]
#  [ 0.   +0.j    -0.008-0.002j  0.42 +0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.409+0.j     0.   +0.j     0.   -0.j     0.   -0.j   ]
#  [ 0.   -0.j     0.091+0.j    -0.058+0.016j -0.   +0.j   ]
#  [ 0.   +0.j    -0.058-0.016j  0.42 +0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.393+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.107+0.j    -0.106+0.032j -0.   +0.j   ]
#  [ 0.   +0.j    -0.106-0.032j  0.42 +0.j    -0.   +0.j   ]
#  [ 0.   -0.j    -0.   -0.j    -0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.368+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.132+0.j    -0.152+0.049j -0.   +0.j   ]
#  [ 0.   +0.j    -0.152-0.049j  0.42 +0.j    -0.   +0.j   ]
#  [ 0.   -0.j    -0.   -0.j    -0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.335+0.j     0.   +0.j     0.   -0.j     0.   -0.j   ]
#  [ 0.   -0.j     0.165+0.j    -0.192+0.071j -0.   +0.j   ]
#  [ 0.   +0.j    -0.192-0.071j  0.42 +0.j     0.   +0.j   ]
#  [ 0.   +0.j    -0.   -0.j     0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.297+0.j     0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.203+0.j    -0.23 +0.087j  0.   -0.j   ]
#  [-0.   -0.j    -0.23 -0.087j  0.42 +0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.   +0.j     0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.257+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.243+0.j    -0.248+0.138j -0.   -0.j   ]
#  [ 0.   -0.j    -0.248-0.138j  0.42 +0.j     0.   +0.j   ]
#  [ 0.   -0.j    -0.   +0.j     0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j  0.24 -0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.216+0.j  0.   -0.j]
#  [ 0.24 +0.j -0.   -0.j  0.   +0.j  0.284+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j  0.249-0.j]
#  [ 0.   -0.j  0.08 +0.j  0.   -0.j -0.   +0.j]
#  [ 0.   +0.j  0.   +0.j  0.178+0.j -0.   -0.j]
#  [ 0.249+0.j -0.   -0.j -0.   +0.j  0.322+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   -0.j  0.   +0.j  0.277+0.j]
#  [ 0.   +0.j  0.08 +0.j  0.   -0.j -0.   -0.j]
#  [ 0.   -0.j  0.   +0.j  0.146+0.j -0.   +0.j]
#  [ 0.277-0.j -0.   +0.j -0.   -0.j  0.354+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.376+0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.121+0.j -0.   -0.j]
#  [-0.376-0.j -0.   -0.j -0.   +0.j  0.379+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.323-0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.105+0.j -0.   -0.j]
#  [-0.323+0.j -0.   -0.j -0.   +0.j  0.395+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.325+0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.1  +0.j -0.   -0.j]
#  [-0.325-0.j -0.   -0.j -0.   +0.j  0.4  +0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.322+0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.104+0.j -0.   -0.j]
#  [-0.322-0.j -0.   -0.j -0.   +0.j  0.396+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.314-0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.119+0.j -0.   -0.j]
#  [-0.314+0.j -0.   -0.j -0.   +0.j  0.381+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   +0.j  0.   -0.j -0.301-0.j]
#  [ 0.   -0.j  0.08 +0.j -0.   -0.j -0.   +0.j]
#  [ 0.   +0.j -0.   +0.j  0.143+0.j -0.   -0.j]
#  [-0.301+0.j -0.   -0.j -0.   +0.j  0.357+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.174+0.j    -0.   -0.j    -0.   +0.j     0.   -0.j   ]
#  [-0.   +0.j     0.326+0.j     0.278-0.173j  0.   -0.j   ]
#  [-0.   -0.j     0.278+0.173j  0.42 +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.211+0.j   -0.   -0.j   -0.   -0.j    0.   -0.j  ]
#  [-0.   +0.j    0.289+0.j    0.252-0.16j  0.   +0.j  ]
#  [-0.   +0.j    0.252+0.16j  0.42 +0.j    0.   -0.j  ]
#  [ 0.   +0.j    0.   -0.j    0.   +0.j    0.08 +0.j  ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.25 +0.j   -0.   +0.j    0.   -0.j    0.   +0.j  ]
#  [-0.   -0.j    0.25 +0.j    0.218-0.15j -0.   +0.j  ]
#  [ 0.   +0.j    0.218+0.15j  0.42 +0.j   -0.   -0.j  ]
#  [ 0.   -0.j   -0.   -0.j   -0.   +0.j    0.08 +0.j  ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.289+0.j     0.   +0.j     0.   -0.j     0.   -0.j   ]
#  [ 0.   -0.j     0.211+0.j    -0.165-0.155j -0.   +0.j   ]
#  [ 0.   +0.j    -0.165+0.155j  0.42 +0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.325+0.j     0.   +0.j     0.   -0.j    -0.   -0.j   ]
#  [ 0.   -0.j     0.175+0.j     0.16 +0.094j -0.   +0.j   ]
#  [ 0.   +0.j     0.16 -0.094j  0.42 +0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.357+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.143+0.j     0.132+0.047j -0.   +0.j   ]
#  [ 0.   +0.j     0.132-0.047j  0.42 +0.j    -0.   -0.j   ]
#  [-0.   -0.j    -0.   -0.j    -0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.381+0.j    0.   +0.j    0.   -0.j   -0.   -0.j  ]
#  [ 0.   -0.j    0.119+0.j    0.093+0.01j -0.   +0.j  ]
#  [ 0.   +0.j    0.093-0.01j  0.42 +0.j   -0.   -0.j  ]
#  [-0.   +0.j   -0.   -0.j   -0.   +0.j    0.08 +0.j  ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.397+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.103+0.j    -0.046+0.003j -0.   +0.j   ]
#  [ 0.   +0.j    -0.046-0.003j  0.42 +0.j    -0.   -0.j   ]
#  [ 0.   -0.j    -0.   -0.j    -0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.403+0.j -0.   +0.j -0.   -0.j  0.   +0.j]
#  [-0.   -0.j  0.097+0.j -0.002+0.j  0.   +0.j]
#  [-0.   +0.j -0.002-0.j  0.42 +0.j  0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.   +0.j  0.08 +0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   -0.j  0.   +0.j -0.048-0.j]
#  [ 0.   +0.j  0.08 +0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.399+0.j -0.   -0.j]
#  [-0.048+0.j -0.   +0.j -0.   +0.j  0.101+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   -0.j  0.   +0.j -0.089-0.j]
#  [ 0.   +0.j  0.08 +0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.386+0.j -0.   -0.j]
#  [-0.089+0.j -0.   +0.j -0.   +0.j  0.114+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   -0.j  0.   +0.j -0.126-0.j]
#  [ 0.   +0.j  0.08 +0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.364+0.j -0.   -0.j]
#  [-0.126+0.j -0.   +0.j -0.   +0.j  0.136+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.42 +0.j  0.   -0.j  0.   +0.j -0.155-0.j]
#  [ 0.   +0.j  0.08 +0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.335+0.j -0.   +0.j]
#  [-0.155+0.j -0.   +0.j -0.   -0.j  0.165+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.301+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.199+0.j    -0.18 +0.131j  0.   +0.j   ]
#  [-0.   +0.j    -0.18 -0.131j  0.42 +0.j     0.   -0.j   ]
#  [ 0.   -0.j     0.   -0.j     0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.264+0.j    -0.   -0.j    -0.   -0.j    -0.   -0.j   ]
#  [-0.   +0.j     0.236+0.j     0.227-0.122j  0.   +0.j   ]
#  [-0.   +0.j     0.227+0.122j  0.42 +0.j     0.   -0.j   ]
#  [-0.   +0.j     0.   -0.j     0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.227+0.j    -0.   +0.j    -0.   -0.j     0.   -0.j   ]
#  [-0.   -0.j     0.273+0.j    -0.237+0.162j  0.   +0.j   ]
#  [-0.   +0.j    -0.237-0.162j  0.42 +0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.192+0.j    -0.   -0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   +0.j     0.308+0.j     0.26 +0.173j  0.   +0.j   ]
#  [-0.   +0.j     0.26 -0.173j  0.42 +0.j     0.   -0.j   ]
#  [ 0.   -0.j     0.   -0.j     0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.162+0.j    -0.   -0.j    -0.   -0.j     0.   -0.j   ]
#  [-0.   +0.j     0.338+0.j     0.305+0.131j  0.   +0.j   ]
#  [-0.   +0.j     0.305-0.131j  0.42 +0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.139+0.j     0.   -0.j     0.   -0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.361+0.j     0.341+0.056j -0.   +0.j   ]
#  [ 0.   +0.j     0.341-0.056j  0.42 +0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.124+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.376+0.j    -0.353+0.021j -0.   +0.j   ]
#  [ 0.   +0.j    -0.353-0.021j  0.42 +0.j     0.   -0.j   ]
#  [-0.   -0.j    -0.   -0.j     0.   +0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.118+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.382+0.j    -0.347+0.075j -0.   +0.j   ]
#  [ 0.   +0.j    -0.347-0.075j  0.42 +0.j    -0.   +0.j   ]
#  [-0.   -0.j    -0.   -0.j    -0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.121+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.379+0.j    -0.329+0.121j -0.   -0.j   ]
#  [ 0.   -0.j    -0.329-0.121j  0.42 +0.j    -0.   +0.j   ]
#  [-0.   -0.j    -0.   +0.j    -0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.134+0.j     0.   -0.j     0.   +0.j    -0.   -0.j   ]
#  [ 0.   +0.j     0.366+0.j    -0.307+0.149j -0.   -0.j   ]
#  [ 0.   -0.j    -0.307-0.149j  0.42 +0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.155+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.345+0.j    -0.278+0.168j -0.   -0.j   ]
#  [ 0.   -0.j    -0.278-0.168j  0.42 +0.j    -0.   +0.j   ]
#  [-0.   -0.j    -0.   +0.j    -0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.183+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.317+0.j    -0.239+0.187j -0.   -0.j   ]
#  [ 0.   -0.j    -0.239-0.187j  0.42 +0.j    -0.   +0.j   ]
#  [-0.   -0.j    -0.   +0.j    -0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.215+0.j     0.   +0.j     0.   +0.j     0.   -0.j   ]
#  [ 0.   -0.j     0.285+0.j     0.205-0.187j -0.   -0.j   ]
#  [ 0.   -0.j     0.205+0.187j  0.42 +0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.251+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.249+0.j    -0.184-0.164j  0.   -0.j   ]
#  [-0.   -0.j    -0.184+0.164j  0.42 +0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.   +0.j     0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.286+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.214+0.j    -0.185-0.105j  0.   -0.j   ]
#  [-0.   -0.j    -0.185+0.105j  0.42 +0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.   +0.j     0.   -0.j     0.08 +0.j   ]]
# ----------------------------------------------------------------------------------------------------

# %%
swap_choi_list = [swap_result_dict[key]["choi state"] for key in swap_result_dict.keys()]
keys = list(swap_result_dict.keys())
df = diagnose_choi_states(swap_choi_list,keys,tol_pos=tol, tol_tp=tol)

# %%
from quam_libs.quantum_memory.entanglement_robustness import entanglementRobustness
for i,key in enumerate(swap_result_dict.keys()):
    swap_result_dict[key]['memory robustness'] = entanglementRobustness(swap_result_dict[key]["choi state"])

# %%
axes_list = np.array([swap_result_dict[key]['axes'] for key in sim_swap_analyze.keys()])
volume_list = np.array([swap_result_dict[key]['volume'] for key in sim_swap_analyze.keys()])
center_list = np.array([swap_result_dict[key]['center'] for key in sim_swap_analyze.keys()])
robustness_list = np.array([swap_result_dict[key]['memory robustness'] for key in sim_swap_analyze.keys()])

fig = plt.figure(figsize=(6, 10))
ax_name = ['axes', 'volume', 'QM']
ax_axes = fig.add_subplot(len(ax_name), 1, 1)
ax_volume = fig.add_subplot(len(ax_name), 1, 2)
ax_QM = fig.add_subplot(len(ax_name), 1, 3)
ax_axes.set_title('Raw simulation')
ax_axes.plot(swap_time,axes_list[:, 0]-0.01,'k' ,label='x-axis')
ax_axes.plot(swap_time,axes_list[:, 1],'r',label='y-axis')
ax_axes.plot(swap_time,axes_list[:, 2],'b', label='z-axis')
ax_axes.set_ylim(0, 1)  # Adjust the y-axis limits to focus on the axes values
ax_axes.legend()
ax_axes.grid(alpha=0.3)
ax_axes.set_ylabel('Axes')
ax_volume.plot(swap_time,volume_list,'k', label='volume')
ax_volume.plot(swap_time,volume_list,'.r', label='volume')
#ax_volume.set_ylim(3.5,4.5)
ax_volume.set_ylabel('Volume')
ax_QM.plot(swap_time,robustness_list,'.g',label='memory robustness')
ax_QM.set_ylabel('Robustness')
ax_QM.set_xlabel('swap time(s)')
plt.show()

# %%
non_Markovian_data['sim_raw'] = {key:{
    'data':sim_swap_data[key],
    'ellipsoid':{
        'axes': swap_result_dict[key]['axes'],
        'center': swap_result_dict[key]['center'],
        'R': swap_result_dict[key]['R'],
        'volume': swap_result_dict[key]['volume'],
        'param': swap_result_dict[key]['param']},
    'quantum_information':{
        'choi': swap_result_dict[key]['choi state'],
        'robustness': swap_result_dict[key]['memory robustness']
    }
} for key in sim_swap_data.keys()}

# %% [markdown]
# ### Plot togather

# %%
raw_robustness_list = [non_Markovian_data['raw'][key]['quantum_information']['robustness'] for key in non_Markovian_data['raw'].keys()]
sim_robustness_list = [non_Markovian_data['sim_raw'][key]['quantum_information']['robustness']  for key in non_Markovian_data['sim_raw'].keys()]

plt.plot(interaction_time*1e-9,raw_robustness_list,label = 'raw')
plt.plot(swap_time,sim_robustness_list,label='sim')
plt.ylabel('Quantum robustness')
plt.legend()
plt.show()

# %%
raw_center_list = np.array( [non_Markovian_data['raw'][key]['ellipsoid']['center'] for key in non_Markovian_data['raw'].keys()])
sim_center_list = np.array( [non_Markovian_data['sim_raw'][key]['ellipsoid']['center'] for key in non_Markovian_data['sim_raw'].keys()])

plt.plot(interaction_time*1e-9,raw_center_list[:,2],'.',label = 'raw')
plt.plot(swap_time,sim_center_list[:,2],label='sim')
plt.ylabel('Center z')
plt.ylim(0,0.7)
plt.legend()
plt.show()

# %% [markdown]
# ## MLE

# %% [markdown]
# ### Experimental

# %%
from quam_libs.quantum_memory.legacy.marcos import MLE
node_qm = node.load_from_id(1763,base_path=data_path)
conf_mat = node_qm.results['results']['q0']['confusion_matrix']
swap_time = np.arange(0,111,2)
non_Markovian_data_mle = {}
non_Markovian_analyze_mle = {}

for i,key in enumerate(list(non_Markovian_data['raw'].keys())):

    x = non_Markovian_data['raw'][key]['data']['original_xyz'][:,0]
    y = non_Markovian_data['raw'][key]['data']['original_xyz'][:,1]
    z = non_Markovian_data['raw'][key]['data']['original_xyz'][:,2]
    px, py, pz = (1-x)/2, (1-y)/2, (1-z)/2

    new_px_0 = np.array([MLE([1-px[j],px[j]],conf_mat)[0] for j in range(len(px))])
    new_py_0 = np.array([MLE([1-py[j],py[j]],conf_mat)[0] for j in range(len(py))])
    new_pz_0 = np.array([MLE([1-pz[j],pz[j]],conf_mat)[0] for j in range(len(pz))])
    
    MLE_data_xyz = np.array([2*new_px_0-1,2*new_py_0-1,2*new_pz_0-1]).T
    data_angle = non_Markovian_data['raw'][key]['data']['angle']
    data_dm = np.array([bloch_vector_to_density_matrix(MLE_data_xyz[i]) for i in range(len(MLE_data_xyz))])

    noise_analyzer = QuantumMemoryAnalyze(MLE_data_xyz,data_angle)
    corrected_dm = noise_analyzer.corrected_dm
    corrected_bloch = noise_analyzer.corrected_bloch
    ellipsoid_results = noise_analyzer.ellipsoid_fit_results()
    # Get choi state from the property
    choi_state = noise_analyzer.choi
    # Compute robustness using the static method
    robustness_value = QuantumMemoryAnalyze.memory_robustness(choi_state)
    non_Markovian_data_mle[key] = {
        'data':{
            'original_xyz': MLE_data_xyz,
            'original_dm' :data_dm,
            'angle': data_angle,
            'corrected_xyz': corrected_bloch,
            'corrected_dm': corrected_dm
        },
        'ellipsoid':{
            'axes':ellipsoid_results['axes'],
            'center':ellipsoid_results['center'],
            'volume':ellipsoid_results['volume'],
            'param':ellipsoid_results['fit_param'],
            "rotation_matrix":ellipsoid_results['rotation_matrix'],
        },
        "quantum_information":{
            "choi":choi_state,
            "robustness":robustness_value
        }
    }
    non_Markovian_analyze_mle[key] = noise_analyzer

# %%
from quam_libs.quantum_memory.legacy.NoiseAnalyze import Checker, QuantumMemory

def qm_value(axes,center,R):
    qm_analyze = QuantumMemory(axes,center,R)
    choi_state = qm_analyze.choi_state()
    checker = Checker(choi_state)
    choi, count = checker.choi_checker(index=[1], repeat=100, print_reason=False)
    return QuantumMemory.memory_robustness(choi)

# %%
from quam_libs.ellipsoid_utils.swap_axes_R_macros import align_max_axis_to_z
R_corrected1_list, axes_corrected1_list, qmr_maximum_z_1_list = [],[],[]

for key in non_Markovian_key:
    R = non_Markovian_data_mle[key]['ellipsoid']['rotation_matrix']
    axes = non_Markovian_data_mle[key]['ellipsoid']['axes']
    center = non_Markovian_data_mle[key]['ellipsoid']['center']
    R_corrected,axes_corrected = align_max_axis_to_z(R, axes)
    if np.linalg.det(R_corrected)<0:
        R_max = R_corrected.copy()
        qmr = qm_value(axes_corrected, center, R_corrected)
        for j in range(3):
            R_copy = R_corrected.copy()
            R_copy[:,j] *= -1
            qmr_value = qm_value(axes_corrected, center, R_copy)
            if qmr_value > qmr:
                R_max = R_copy.copy()
                qmr = qmr_value
    non_Markovian_data_mle[key]['ellipsoid']['rotation_matrix'] = R_max
    non_Markovian_data_mle[key]['ellipsoid']['axes'] = axes_corrected
    non_Markovian_data_mle[key]['quantum_information']['robustness'] = qmr
# Out:
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.016  0.082  0.903]
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.048  0.078  0.874]
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.09   0.13   0.781]
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.283  0.335  0.382]
# ❌ Trace of the Choi state is not 1. Got trace = (0.9999999897416608+0j)
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 12 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 15 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.191  0.256  0.552]
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 11 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.12   0.272  0.607]
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 9 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 5 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 6 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 12 iterations, the Choi state is valid.
# After 12 iterations, the Choi state is valid.
# After 13 iterations, the Choi state is valid.
# After 13 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.

# %%
axes_list = np.array([non_Markovian_data_mle[key]['ellipsoid']['axes'] for key in non_Markovian_key])
volume_list = np.array([non_Markovian_data_mle[key]['ellipsoid']['volume'] for key in non_Markovian_key])
robustness_list = [non_Markovian_data_mle[key]['quantum_information']['robustness'] for key in non_Markovian_key]
fig = plt.figure(figsize=(6, 10))
ax_name = ['axes', 'volume', 'QM']
ax_axes = fig.add_subplot(len(ax_name), 1, 1)
fitted_axes = np.zeros_like(axes_list)
ax_volume = fig.add_subplot(len(ax_name), 1, 2)
ax_QM = fig.add_subplot(len(ax_name), 1, 3)
ax_axes.plot(interaction_time, axes_list[:,0], marker='o', label='axis x')
ax_axes.plot(interaction_time, axes_list[:,1], marker='o', label='axis y')
ax_axes.plot(interaction_time, axes_list[:,2], marker='o', label='axis z')
ax_axes.legend()
ax_axes.set_ylim(0,1)
ax_axes.set_ylabel('Ellipsoid axes')
ax_axes.grid(alpha=0.3)
ax_axes.set_title('MLE data analysis')
ax_volume.plot(interaction_time, volume_list, marker='o')
ax_volume.set_ylabel('Ellipsoid volume')
ax_volume.set_ylim(0,4)
ax_QM.set_ylim(0,1)
ax_QM.plot(interaction_time, robustness_list, marker='o')
ax_QM.set_xlabel('Interaction time (ns)')
ax_QM.set_ylabel('Quantum robustness')
plt.show()

# %%
non_Markovian_data['mle'] = non_Markovian_data_mle

# %% [markdown]
# ### Simulation

# %%
from quam_libs.macros import generate_uniform_sphere_angles
swap_time = np.arange(0, 111e-9,2e-9)  # time in seconds

n_points =1000
error_rate = 0
t1 = 1.5e-6
t2= 1e-6

data_angle_list = []
theta_range, phi_range = generate_uniform_sphere_angles(n_points)
for i in range(len(swap_time)):
    data_angle = []
    for j in range(len(theta_range)):
        data_angle.append([theta_range[j], phi_range[j]])
    data_angle_list.append(np.array(data_angle))


simulation_data = {
    f"swap={int(swap_time[i]*1e9)}ns": {'data_angle':data_angle_list[i].tolist(),'data_xyz': []}
    for i in range(len(swap_time))
}

# %%
from quam_libs.nonMarkovian_simulation import BR_swap_dm, wait_dm,error_gate
from quam_libs.QI_utils import bloch_vector_to_density_matrix,density_matrix_to_bloch_vector

# xyz_data ={}
# bloch_vector_list = []
for i in range(n_points):
    theta, phi = data_angle_list[0][i]
    #dm = BR_swap_dm(theta, phi, tlist=swap_time)
    delay_dm = wait_dm(theta, phi,T1=t1,T2=t2)[-1]
    dm = BR_swap_dm(delay_dm,g=41.5e6/2*np.pi,T2=t2, T1=t1,tlist=swap_time)
    for j in range(len(swap_time)):
        dm_j = dm[j].ptrace(1)
        dm_j = error_gate(dm_j, error_rate).full()
        bloch_vector = density_matrix_to_bloch_vector(dm_j)
        simulation_data[f"swap={int(swap_time[j]*1e9)}ns"]['data_xyz'].append(bloch_vector.tolist())
# Out:
# /Users/jackchao/Desktop/Project/publication/quantum_memory/data_availability/quantum_memory_data/.venv/lib/python3.12/site-packages/qutip/solver/options.py:16: FutureWarning: Dedicated options class are no longer needed, options should be passed as dict to solvers.
#   warnings.warn(

# %%
from quam_libs.quantum_memory.legacy.NoiseAnalyze import NoiseAnalyze, EllipsoidFitParameter  
ellipsoid_fit_parameters = EllipsoidFitParameter()

sim_swap_data = {}
sim_swap_analyze={}
do_convex_hull = True
for i, key in enumerate(simulation_data):
    data_xyz = simulation_data[key]['data_xyz']
    data_angle = simulation_data[key]['data_angle']
    data_dm = np.array([bloch_vector_to_density_matrix(data_xyz[i]) for i in range(len(data_xyz))])
    sim_swap_analyzer = NoiseAnalyze(data_xyz,data_angle,ellipsoid_fit_parameters)
    corrected_dm = sim_swap_analyzer.corrected_dm
    corrected_bloch = sim_swap_analyzer.corrected_bloch

    sim_swap_data[key] = {
        'data_xyz': data_xyz,
        'data_dm' :data_dm,
        'data_angle': data_angle,
        'corrected_xyz': corrected_bloch,
        'corrected_dm': corrected_dm,}
    sim_swap_analyze[key] = sim_swap_analyzer

# %%
from quam_libs.quantum_memory.legacy.NoiseAnalyze import QuantumMemory

swap_result_dict ={}
for key in sim_swap_data.keys():
    center, axes, R, volume, param = sim_swap_analyze[key].ellipsoid_fit()
    qm_analyze = QuantumMemory(axes,center,R)
    choi_state = qm_analyze.choi_state()
    swap_result_dict[key] ={
        'axes': axes,
        'center': center,
        'R': R,
        'param': param,
        'volume': volume,
        'choi state': choi_state,
        'memory robustness': qm_analyze.memory_robustness,
    }

# %%
def perm_order(axes,center,R_test,method='rotation'):
    """
    method axes: it use the axes to determine the order of the rotation matrix, the max axes should be z-axis
    method rotation: it use the rotation matrix to determine the order of the rotation matrix, it order the 
    rotation matrix by the maximum absolute value of each row, and then sort the rows based on the order    
    """
    if method == 'rotation':
        perm0 = np.argmax(np.abs(R_test[0]))
        perm1 = np.argmax(np.abs(R_test[1]))
        perm2 = np.argmax(np.abs(R_test[2]))
        perm = np.array([perm0, perm1, perm2])
        idx = np.argsort(perm)
    elif method == 'axes':
        z_min = np.argmin(np.abs(axes))
        if z_min == 0:
            idx = np.array([2,1,0])
        elif z_min == 1:
            idx = np.array([0,2,1])
        elif z_min == 2:
            idx = np.array([0,1,2])
    R_test = R_test[idx, :]
    axes = axes[idx]
    center = center[idx]
    if np.linalg.det(R_test) >0:
        pass
    elif np.linalg.det(R_test) < 0:
        R_test[0] *= -1  
    else:
        print(f"R_test is not a valid rotation matrix, det(R_test)={np.linalg.det(R_test)}")
        raise ValueError("R_test is not a valid rotation matrix")
    return axes,center,R_test,idx


keys= sim_swap_data.keys()
for key in keys:
    print(f"Results for {key}:")
    R = swap_result_dict[key]['R']
    center = swap_result_dict[key]['center']
    axes = swap_result_dict[key]['axes']
    print(f"R:\n{R}")
    print(f"Center:\n{center}")
    print(f"Axes:\n{axes}")
    print(f"choi state:\n{swap_result_dict[key]['choi state']}")
    print('-'*75)
    axes, center_,R,perm = perm_order(axes,center,R,method='rotation')
    print("After swapping the axes, center and R")
    print(f"R:\n{R}")
    print(f"Center:\n{center}")
    print(f"Axes:\n{axes}")
    choi = QuantumMemory(axes,center,R).choi_state()
    print(f"choi state:\n{choi}")
    print('-'*100)

    swap_result_dict[key]['R'] = R
    swap_result_dict[key]['axes'] = axes
    swap_result_dict[key]['center'] = center
    swap_result_dict[key]['choi state'] = choi
# Out:
# Results for swap=0ns:
# R:
# [[ 1.     0.001  0.003]
#  [ 0.    -0.05  -0.999]
#  [ 0.     0.999 -0.044]]
# Center:
# [-0.  0. -0.]
# Axes:
# [1. 1. 1.]
# choi state:
# [[ 0.239+0.j  0.   -0.j  0.   +0.j  0.238+0.j]
#  [ 0.   +0.j  0.261+0.j  0.262+0.j -0.   -0.j]
#  [ 0.   -0.j  0.262-0.j  0.261+0.j -0.   +0.j]
#  [ 0.238+0.j -0.   +0.j -0.   -0.j  0.239+0.j]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-1.    -0.001 -0.003]
#  [ 0.     0.999 -0.044]
#  [ 0.    -0.05  -0.999]]
# Center:
# [-0.  0. -0.]
# Axes:
# [1. 1. 1.]
# choi state:
# [[ 0. +0.j    -0. +0.012j -0. -0.012j -0. +0.j   ]
#  [-0. -0.012j  0.5+0.j    -0.5-0.j     0. +0.012j]
#  [-0. +0.012j -0.5+0.j     0.5+0.j     0. -0.012j]
#  [-0. +0.j     0. -0.012j  0. +0.012j  0. +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=2ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.446 -0.895 -0.   ]
#  [ 0.895  0.445 -0.   ]]
# Center:
# [ 0.    -0.     0.018]
# Axes:
# [0.982 0.988 0.988]
# choi state:
# [[ 0.259+0.j     0.233-0.055j  0.233+0.055j -0.221+0.j   ]
#  [ 0.233+0.055j  0.25 +0.j     0.221+0.109j -0.233-0.055j]
#  [ 0.233-0.055j  0.221-0.109j  0.25 +0.j    -0.233+0.055j]
#  [-0.221+0.j    -0.233+0.055j -0.233-0.055j  0.241+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.895 -0.445  0.   ]
#  [ 0.446 -0.895 -0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [ 0.    -0.     0.018]
# Axes:
# [0.988 0.988 0.982]
# choi state:
# [[ 0.505+0.j  0.   +0.j  0.   -0.j -0.442+0.j]
#  [ 0.   -0.j  0.005+0.j -0.   +0.j -0.   +0.j]
#  [ 0.   +0.j -0.   -0.j  0.005+0.j -0.   -0.j]
#  [-0.442+0.j -0.   -0.j -0.   +0.j  0.486+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=4ns:
# R:
# [[ 0.     0.    -1.   ]
#  [ 0.815  0.58   0.   ]
#  [ 0.58  -0.815 -0.   ]]
# Center:
# [-0.    -0.     0.069]
# Axes:
# [0.931 0.96  0.96 ]
# choi state:
# [[ 0.284+0.j    -0.052+0.098j -0.052-0.098j  0.139+0.j   ]
#  [-0.052-0.098j  0.25 +0.j    -0.139+0.19j   0.052+0.098j]
#  [-0.052+0.098j -0.139-0.19j   0.25 +0.j     0.052-0.098j]
#  [ 0.139+0.j     0.052-0.098j  0.052+0.098j  0.216+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.815  0.58   0.   ]
#  [ 0.58  -0.815 -0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.069]
# Axes:
# [0.96  0.96  0.931]
# choi state:
# [[ 0.052+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.483+0.j     0.391+0.278j -0.   -0.j   ]
#  [ 0.   -0.j     0.391-0.278j  0.483+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.017+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=6ns:
# R:
# [[-0.774 -0.634 -0.   ]
#  [-0.634  0.774  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.148]
# Axes:
# [0.915 0.915 0.852]
# choi state:
# [[ 0.111+0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.463+0.j   -0.354-0.29j  0.   -0.j  ]
#  [-0.   -0.j   -0.354+0.29j  0.463+0.j    0.   +0.j  ]
#  [ 0.   +0.j    0.   +0.j    0.   -0.j   -0.037+0.j  ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.774 -0.634 -0.   ]
#  [-0.634  0.774  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.148]
# Axes:
# [0.915 0.915 0.852]
# choi state:
# [[ 0.111+0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.463+0.j   -0.354-0.29j  0.   -0.j  ]
#  [-0.   -0.j   -0.354+0.29j  0.463+0.j    0.   +0.j  ]
#  [ 0.   +0.j    0.   +0.j    0.   -0.j   -0.037+0.j  ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=8ns:
# R:
# [[-0.831 -0.556 -0.   ]
#  [-0.556  0.831  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.252]
# Axes:
# [0.855 0.855 0.748]
# choi state:
# [[ 0.189+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.437+0.j    -0.355-0.238j  0.   -0.j   ]
#  [-0.   -0.j    -0.355+0.238j  0.437+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.063+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.831 -0.556 -0.   ]
#  [-0.556  0.831  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.252]
# Axes:
# [0.855 0.855 0.748]
# choi state:
# [[ 0.189+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.437+0.j    -0.355-0.238j  0.   -0.j   ]
#  [-0.   -0.j    -0.355+0.238j  0.437+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.063+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=10ns:
# R:
# [[-0.789 -0.614 -0.   ]
#  [-0.614  0.789  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.371]
# Axes:
# [0.781 0.781 0.629]
# choi state:
# [[ 0.278+0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.407+0.j   -0.308-0.24j  0.   -0.j  ]
#  [-0.   -0.j   -0.308+0.24j  0.407+0.j    0.   +0.j  ]
#  [ 0.   +0.j    0.   +0.j    0.   -0.j   -0.093+0.j  ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.789 -0.614 -0.   ]
#  [-0.614  0.789  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.371]
# Axes:
# [0.781 0.781 0.629]
# choi state:
# [[ 0.278+0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.407+0.j   -0.308-0.24j  0.   -0.j  ]
#  [-0.   -0.j   -0.308+0.24j  0.407+0.j    0.   +0.j  ]
#  [ 0.   +0.j    0.   +0.j    0.   -0.j   -0.093+0.j  ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=12ns:
# R:
# [[ 0.768 -0.64  -0.   ]
#  [-0.64  -0.768 -0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.499]
# Axes:
# [0.693 0.693 0.501]
# choi state:
# [[ 0.374+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.375+0.j     0.266-0.222j  0.   -0.j   ]
#  [-0.   -0.j     0.266+0.222j  0.375+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.125+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.768 -0.64  -0.   ]
#  [-0.64  -0.768 -0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.499]
# Axes:
# [0.693 0.693 0.501]
# choi state:
# [[ 0.374+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.375+0.j     0.266-0.222j  0.   -0.j   ]
#  [-0.   -0.j     0.266+0.222j  0.375+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.125+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=14ns:
# R:
# [[-0.794 -0.608 -0.   ]
#  [-0.608  0.794  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.626]
# Axes:
# [0.595 0.595 0.374]
# choi state:
# [[ 0.47 +0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.343+0.j    -0.236-0.181j  0.   -0.j   ]
#  [-0.   -0.j    -0.236+0.181j  0.343+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.157+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.794 -0.608 -0.   ]
#  [-0.608  0.794  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.626]
# Axes:
# [0.595 0.595 0.374]
# choi state:
# [[ 0.47 +0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.343+0.j    -0.236-0.181j  0.   -0.j   ]
#  [-0.   -0.j    -0.236+0.181j  0.343+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.157+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=16ns:
# R:
# [[-0.917 -0.399 -0.   ]
#  [-0.399  0.917  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.745]
# Axes:
# [0.486 0.486 0.255]
# choi state:
# [[ 0.559+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.314+0.j    -0.223-0.097j -0.   -0.j   ]
#  [-0.   -0.j    -0.223+0.097j  0.314+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.186+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.917 -0.399 -0.   ]
#  [-0.399  0.917  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.745]
# Axes:
# [0.486 0.486 0.255]
# choi state:
# [[ 0.559+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.314+0.j    -0.223-0.097j -0.   -0.j   ]
#  [-0.   -0.j    -0.223+0.097j  0.314+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.186+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=18ns:
# R:
# [[ 0.933  0.359  0.   ]
#  [ 0.359 -0.933 -0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.847]
# Axes:
# [0.37  0.37  0.153]
# choi state:
# [[ 0.635+0.j    -0.   -0.j    -0.   +0.j    -0.   +0.j   ]
#  [-0.   +0.j     0.288+0.j     0.173+0.066j -0.   -0.j   ]
#  [-0.   -0.j     0.173-0.066j  0.288+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j    -0.212+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.933  0.359  0.   ]
#  [ 0.359 -0.933 -0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.847]
# Axes:
# [0.37  0.37  0.153]
# choi state:
# [[ 0.635+0.j    -0.   -0.j    -0.   +0.j    -0.   +0.j   ]
#  [-0.   +0.j     0.288+0.j     0.173+0.066j -0.   -0.j   ]
#  [-0.   -0.j     0.173-0.066j  0.288+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j    -0.212+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=20ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.944  0.331 -0.   ]
#  [-0.331  0.944  0.   ]]
# Center:
# [-0.    -0.     0.925]
# Axes:
# [0.075 0.247 0.247]
# choi state:
# [[ 0.713+0.j     0.028-0.029j  0.028+0.029j  0.02 +0.j   ]
#  [ 0.028+0.029j  0.25 +0.j    -0.02 +0.018j -0.028-0.029j]
#  [ 0.028-0.029j -0.02 -0.018j  0.25 +0.j    -0.028+0.029j]
#  [ 0.02 +0.j    -0.028+0.029j -0.028-0.029j -0.213+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.944  0.331 -0.   ]
#  [-0.331  0.944  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [-0.    -0.     0.925]
# Axes:
# [0.247 0.247 0.075]
# choi state:
# [[ 0.731+0.j -0.   +0.j -0.   -0.j  0.117+0.j]
#  [-0.   -0.j  0.231+0.j -0.   +0.j -0.   +0.j]
#  [-0.   +0.j -0.   -0.j  0.231+0.j -0.   -0.j]
#  [ 0.117+0.j -0.   -0.j -0.   +0.j -0.194+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=22ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.952  0.305 -0.   ]
#  [-0.305  0.952  0.   ]]
# Center:
# [-0.     0.     0.975]
# Axes:
# [0.025 0.121 0.121]
# choi state:
# [[ 0.737+0.j     0.014-0.014j  0.014+0.014j  0.009+0.j   ]
#  [ 0.014+0.014j  0.25 +0.j    -0.009+0.006j -0.014-0.014j]
#  [ 0.014-0.014j -0.009-0.006j  0.25 +0.j    -0.014+0.014j]
#  [ 0.009+0.j    -0.014+0.014j -0.014-0.014j -0.237+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.952  0.305 -0.   ]
#  [-0.305  0.952  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [-0.     0.     0.975]
# Axes:
# [0.121 0.121 0.025]
# choi state:
# [[ 0.744+0.j -0.   +0.j -0.   -0.j  0.058+0.j]
#  [-0.   -0.j  0.244+0.j -0.   +0.j -0.   +0.j]
#  [-0.   +0.j -0.   -0.j  0.244+0.j -0.   -0.j]
#  [ 0.058+0.j -0.   -0.j -0.   +0.j -0.231+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=24ns:
# R:
# [[-0.966 -0.26   0.   ]
#  [-0.26   0.966  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.992]
# Axes:
# [0.006 0.006 0.008]
# choi state:
# [[ 0.744+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.252+0.j    -0.003-0.001j  0.   -0.j   ]
#  [ 0.   -0.j    -0.003+0.001j  0.252+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.248+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.966 -0.26   0.   ]
#  [-0.26   0.966  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.992]
# Axes:
# [0.006 0.006 0.008]
# choi state:
# [[ 0.744+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.252+0.j    -0.003-0.001j  0.   -0.j   ]
#  [ 0.   -0.j    -0.003+0.001j  0.252+0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.248+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=26ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [ 0.954  0.299  0.   ]
#  [ 0.299 -0.954  0.   ]]
# Center:
# [ 0.    -0.     0.977]
# Axes:
# [0.023 0.133 0.133]
# choi state:
# [[ 0.738+0.j    -0.016+0.016j -0.016-0.016j  0.01 +0.j   ]
#  [-0.016-0.016j  0.25 +0.j    -0.01 +0.006j  0.016+0.016j]
#  [-0.016+0.016j -0.01 -0.006j  0.25 +0.j     0.016-0.016j]
#  [ 0.01 +0.j     0.016-0.016j  0.016+0.016j -0.238+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.954  0.299  0.   ]
#  [ 0.299 -0.954  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.977]
# Axes:
# [0.133 0.133 0.023]
# choi state:
# [[ 0.732+0.j    0.   +0.j    0.   -0.j   -0.   +0.j  ]
#  [ 0.   -0.j    0.256+0.j    0.064+0.02j  0.   +0.j  ]
#  [ 0.   +0.j    0.064-0.02j  0.256+0.j    0.   -0.j  ]
#  [-0.   +0.j    0.   -0.j    0.   +0.j   -0.244+0.j  ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=28ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [ 0.958  0.288  0.   ]
#  [ 0.288 -0.958  0.   ]]
# Center:
# [ 0.    -0.     0.929]
# Axes:
# [0.071 0.258 0.258]
# choi state:
# [[ 0.715+0.j    -0.03 +0.031j -0.03 -0.031j  0.019+0.j   ]
#  [-0.03 -0.031j  0.25 +0.j    -0.019+0.017j  0.03 +0.031j]
#  [-0.03 +0.031j -0.019-0.017j  0.25 +0.j     0.03 -0.031j]
#  [ 0.019+0.j     0.03 -0.031j  0.03 +0.031j -0.215+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.958  0.288  0.   ]
#  [ 0.288 -0.958  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.929]
# Axes:
# [0.258 0.258 0.071]
# choi state:
# [[ 0.697+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.268+0.j     0.123+0.037j  0.   +0.j   ]
#  [ 0.   +0.j     0.123-0.037j  0.268+0.j     0.   -0.j   ]
#  [-0.   +0.j     0.   -0.j     0.   +0.j    -0.232+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=30ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [ 0.958  0.286  0.   ]
#  [ 0.286 -0.958  0.   ]]
# Center:
# [ 0.    -0.     0.853]
# Axes:
# [0.147 0.378 0.378]
# choi state:
# [[ 0.677+0.j    -0.042+0.045j -0.042-0.045j  0.027+0.j   ]
#  [-0.042-0.045j  0.25 +0.j    -0.027+0.035j  0.042+0.045j]
#  [-0.042+0.045j -0.027-0.035j  0.25 +0.j     0.042-0.045j]
#  [ 0.027+0.j     0.042-0.045j  0.042+0.045j -0.177+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.958  0.286  0.   ]
#  [ 0.286 -0.958  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.853]
# Axes:
# [0.378 0.378 0.147]
# choi state:
# [[ 0.64 +0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.287+0.j     0.181+0.054j -0.   +0.j   ]
#  [ 0.   +0.j     0.181-0.054j  0.287+0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j    -0.213+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=32ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [ 0.979  0.206  0.   ]
#  [ 0.206 -0.979  0.   ]]
# Center:
# [ 0.    -0.     0.754]
# Axes:
# [0.246 0.49  0.49 ]
# choi state:
# [[ 0.627+0.j   -0.055+0.06j -0.055-0.06j  0.025+0.j  ]
#  [-0.055-0.06j  0.25 +0.j   -0.025+0.06j  0.055+0.06j]
#  [-0.055+0.06j -0.025-0.06j  0.25 +0.j    0.055-0.06j]
#  [ 0.025+0.j    0.055-0.06j  0.055+0.06j -0.127+0.j  ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.979  0.206  0.   ]
#  [ 0.206 -0.979  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.754]
# Axes:
# [0.49  0.49  0.246]
# choi state:
# [[ 0.566+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.311+0.j     0.24 +0.051j -0.   -0.j   ]
#  [ 0.   +0.j     0.24 -0.051j  0.311+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j    -0.189+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=34ns:
# R:
# [[ 0.     0.    -1.   ]
#  [ 0.065  0.998  0.   ]
#  [ 0.998 -0.065  0.   ]]
# Center:
# [ 0.    -0.     0.639]
# Axes:
# [0.361 0.595 0.595]
# choi state:
# [[ 0.57 +0.j    -0.029+0.005j -0.029-0.005j  0.148+0.j   ]
#  [-0.029-0.005j  0.25 +0.j    -0.148+0.006j  0.029+0.005j]
#  [-0.029+0.005j -0.148-0.006j  0.25 +0.j     0.029-0.005j]
#  [ 0.148+0.j     0.029-0.005j  0.029+0.005j -0.07 +0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.998  0.065 -0.   ]
#  [ 0.065  0.998  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.639]
# Axes:
# [0.595 0.595 0.361]
# choi state:
# [[ 0.479+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.34 +0.j    -0.297+0.019j  0.   -0.j   ]
#  [ 0.   -0.j    -0.297-0.019j  0.34 +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j    -0.16 +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=36ns:
# R:
# [[-0.84   0.542  0.   ]
#  [ 0.542  0.84   0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.515]
# Axes:
# [0.688 0.688 0.485]
# choi state:
# [[ 0.386+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.371+0.j    -0.289+0.187j -0.   -0.j   ]
#  [ 0.   -0.j    -0.289-0.187j  0.371+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.129+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.84   0.542  0.   ]
#  [ 0.542  0.84   0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.515]
# Axes:
# [0.688 0.688 0.485]
# choi state:
# [[ 0.386+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.371+0.j    -0.289+0.187j -0.   -0.j   ]
#  [ 0.   -0.j    -0.289-0.187j  0.371+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.129+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=38ns:
# R:
# [[-0.709  0.705  0.   ]
#  [ 0.705  0.709  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.391]
# Axes:
# [0.77  0.77  0.609]
# choi state:
# [[ 0.293+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.402+0.j    -0.273+0.272j -0.   -0.j   ]
#  [ 0.   -0.j    -0.273-0.272j  0.402+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.098+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.709  0.705  0.   ]
#  [ 0.705  0.709  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.391]
# Axes:
# [0.77  0.77  0.609]
# choi state:
# [[ 0.293+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.402+0.j    -0.273+0.272j -0.   -0.j   ]
#  [ 0.   -0.j    -0.273-0.272j  0.402+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.098+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=40ns:
# R:
# [[-0.762  0.648  0.   ]
#  [ 0.648  0.762  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.275]
# Axes:
# [0.839 0.839 0.725]
# choi state:
# [[ 0.206+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.431+0.j    -0.319+0.272j -0.   -0.j   ]
#  [ 0.   -0.j    -0.319-0.272j  0.431+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.069+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.762  0.648  0.   ]
#  [ 0.648  0.762  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.275]
# Axes:
# [0.839 0.839 0.725]
# choi state:
# [[ 0.206+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.431+0.j    -0.319+0.272j -0.   -0.j   ]
#  [ 0.   -0.j    -0.319-0.272j  0.431+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.069+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=42ns:
# R:
# [[-0.817  0.576  0.   ]
#  [ 0.576  0.817  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.176]
# Axes:
# [0.893 0.893 0.824]
# choi state:
# [[ 0.132+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.456+0.j    -0.365+0.257j -0.   -0.j   ]
#  [ 0.   -0.j    -0.365-0.257j  0.456+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.044+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.817  0.576  0.   ]
#  [ 0.576  0.817  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.176]
# Axes:
# [0.893 0.893 0.824]
# choi state:
# [[ 0.132+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.456+0.j    -0.365+0.257j -0.   -0.j   ]
#  [ 0.   -0.j    -0.365-0.257j  0.456+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.044+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=44ns:
# R:
# [[-0.801  0.599  0.   ]
#  [ 0.599  0.801  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.099]
# Axes:
# [0.931 0.931 0.901]
# choi state:
# [[ 0.074+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.475+0.j    -0.373+0.279j -0.   -0.j   ]
#  [ 0.   -0.j    -0.373-0.279j  0.475+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.025+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.801  0.599  0.   ]
#  [ 0.599  0.801  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.099]
# Axes:
# [0.931 0.931 0.901]
# choi state:
# [[ 0.074+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.475+0.j    -0.373+0.279j -0.   -0.j   ]
#  [ 0.   -0.j    -0.373-0.279j  0.475+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.025+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=46ns:
# R:
# [[ 0.71  -0.704 -0.   ]
#  [-0.704 -0.71  -0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.049]
# Axes:
# [0.954 0.954 0.951]
# choi state:
# [[ 0.037+0.j    -0.   -0.j    -0.   +0.j    -0.   +0.j   ]
#  [-0.   +0.j     0.488+0.j     0.339-0.336j  0.   -0.j   ]
#  [-0.   -0.j     0.339+0.336j  0.488+0.j     0.   +0.j   ]
#  [-0.   +0.j     0.   +0.j     0.   -0.j    -0.012+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.71  -0.704 -0.   ]
#  [-0.704 -0.71  -0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.049]
# Axes:
# [0.954 0.954 0.951]
# choi state:
# [[ 0.037+0.j    -0.   -0.j    -0.   +0.j    -0.   +0.j   ]
#  [-0.   +0.j     0.488+0.j     0.339-0.336j  0.   -0.j   ]
#  [-0.   -0.j     0.339+0.336j  0.488+0.j     0.   +0.j   ]
#  [-0.   +0.j     0.   +0.j     0.   -0.j    -0.012+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=48ns:
# R:
# [[ 0.786  0.619  0.   ]
#  [ 0.619 -0.786  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.032]
# Axes:
# [0.961 0.961 0.968]
# choi state:
# [[ 0.024+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.492+0.j     0.378+0.297j -0.   -0.j   ]
#  [ 0.   -0.j     0.378-0.297j  0.492+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.008+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.786  0.619  0.   ]
#  [ 0.619 -0.786  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.032]
# Axes:
# [0.961 0.961 0.968]
# choi state:
# [[ 0.024+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.492+0.j     0.378+0.297j -0.   -0.j   ]
#  [ 0.   -0.j     0.378-0.297j  0.492+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.008+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=50ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.87  -0.494 -0.   ]
#  [-0.494  0.87  -0.   ]]
# Center:
# [ 0.    -0.     0.046]
# Axes:
# [0.954 0.951 0.951]
# choi state:
# [[ 0.273+0.j    -0.178-0.103j -0.178+0.103j -0.117+0.j   ]
#  [-0.178+0.103j  0.25 +0.j     0.117-0.207j  0.178-0.103j]
#  [-0.178-0.103j  0.117+0.207j  0.25 +0.j     0.178+0.103j]
#  [-0.117+0.j     0.178+0.103j  0.178-0.103j  0.227+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.87  -0.494 -0.   ]
#  [-0.494  0.87  -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [ 0.    -0.     0.046]
# Axes:
# [0.951 0.951 0.954]
# choi state:
# [[ 0.034+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.489+0.j    -0.414-0.235j -0.   +0.j   ]
#  [ 0.   +0.j    -0.414+0.235j  0.489+0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j    -0.011+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=52ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.964  0.267 -0.   ]
#  [-0.267  0.964  0.   ]]
# Center:
# [-0.     0.     0.091]
# Axes:
# [0.909 0.925 0.925]
# choi state:
# [[ 0.296+0.j     0.085-0.111j  0.085+0.111j  0.062+0.j   ]
#  [ 0.085+0.111j  0.25 +0.j    -0.062+0.219j -0.085-0.111j]
#  [ 0.085-0.111j -0.062-0.219j  0.25 +0.j    -0.085+0.111j]
#  [ 0.062+0.j    -0.085+0.111j -0.085-0.111j  0.204+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.964  0.267 -0.   ]
#  [-0.267  0.964  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [-0.     0.     0.091]
# Axes:
# [0.925 0.925 0.909]
# choi state:
# [[ 0.523+0.j  0.   -0.j  0.   +0.j  0.446+0.j]
#  [ 0.   +0.j  0.023+0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.023+0.j -0.   +0.j]
#  [ 0.446+0.j -0.   +0.j -0.   -0.j  0.432+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=54ns:
# R:
# [[ 0.     0.     1.   ]
#  [-0.995  0.1    0.   ]
#  [-0.1   -0.995  0.   ]]
# Center:
# [-0.     0.     0.165]
# Axes:
# [0.835 0.884 0.884]
# choi state:
# [[ 0.332+0.j     0.1  +0.11j   0.1  -0.11j   0.022+0.j   ]
#  [ 0.1  -0.11j   0.25 +0.j    -0.022-0.208j -0.1  +0.11j ]
#  [ 0.1  +0.11j  -0.022+0.208j  0.25 +0.j    -0.1  -0.11j ]
#  [ 0.022+0.j    -0.1  -0.11j  -0.1  +0.11j   0.168+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.995  0.1    0.   ]
#  [-0.1   -0.995  0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [-0.     0.     0.165]
# Axes:
# [0.884 0.884 0.835]
# choi state:
# [[ 0.541+0.j  0.   -0.j  0.   +0.j -0.44 +0.j]
#  [ 0.   +0.j  0.041+0.j -0.   -0.j -0.   -0.j]
#  [ 0.   -0.j -0.   +0.j  0.041+0.j -0.   +0.j]
#  [-0.44 +0.j -0.   +0.j -0.   -0.j  0.377+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=56ns:
# R:
# [[ 0.941 -0.339 -0.   ]
#  [-0.339 -0.941  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.261]
# Axes:
# [0.828 0.828 0.739]
# choi state:
# [[ 0.196+0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.435+0.j    0.389-0.14j  0.   +0.j  ]
#  [-0.   -0.j    0.389+0.14j  0.435+0.j    0.   -0.j  ]
#  [ 0.   +0.j    0.   -0.j    0.   +0.j   -0.065+0.j  ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.941 -0.339 -0.   ]
#  [-0.339 -0.941  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.261]
# Axes:
# [0.828 0.828 0.739]
# choi state:
# [[ 0.196+0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.435+0.j    0.389-0.14j  0.   +0.j  ]
#  [-0.   -0.j    0.389+0.14j  0.435+0.j    0.   -0.j  ]
#  [ 0.   +0.j    0.   -0.j    0.   +0.j   -0.065+0.j  ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=58ns:
# R:
# [[ 0.876 -0.483  0.   ]
#  [-0.483 -0.876  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.374]
# Axes:
# [0.758 0.758 0.626]
# choi state:
# [[ 0.28 +0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.407+0.j     0.332-0.183j -0.   +0.j   ]
#  [-0.   -0.j     0.332+0.183j  0.407+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.093+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.876 -0.483  0.   ]
#  [-0.483 -0.876  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.374]
# Axes:
# [0.758 0.758 0.626]
# choi state:
# [[ 0.28 +0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.407+0.j     0.332-0.183j -0.   +0.j   ]
#  [-0.   -0.j     0.332+0.183j  0.407+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.093+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=60ns:
# R:
# [[ 0.853 -0.521  0.   ]
#  [-0.521 -0.853  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.495]
# Axes:
# [0.675 0.675 0.505]
# choi state:
# [[ 0.371+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.376+0.j     0.288-0.176j -0.   +0.j   ]
#  [-0.   -0.j     0.288+0.176j  0.376+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.124+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.853 -0.521  0.   ]
#  [-0.521 -0.853  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.495]
# Axes:
# [0.675 0.675 0.505]
# choi state:
# [[ 0.371+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.376+0.j     0.288-0.176j -0.   +0.j   ]
#  [-0.   -0.j     0.288+0.176j  0.376+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.124+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=62ns:
# R:
# [[ 0.816 -0.578  0.   ]
#  [-0.578 -0.816  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.617]
# Axes:
# [0.581 0.581 0.383]
# choi state:
# [[ 0.463+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.346+0.j     0.237-0.168j -0.   +0.j   ]
#  [ 0.   -0.j     0.237+0.168j  0.346+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.154+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.816 -0.578  0.   ]
#  [-0.578 -0.816  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.617]
# Axes:
# [0.581 0.581 0.383]
# choi state:
# [[ 0.463+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.346+0.j     0.237-0.168j -0.   +0.j   ]
#  [ 0.   -0.j     0.237+0.168j  0.346+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.154+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=64ns:
# R:
# [[ 0.732 -0.682  0.   ]
#  [-0.682 -0.732  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.731]
# Axes:
# [0.478 0.478 0.269]
# choi state:
# [[ 0.548+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.317+0.j     0.175-0.163j -0.   +0.j   ]
#  [ 0.   +0.j     0.175+0.163j  0.317+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.183+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.732 -0.682  0.   ]
#  [-0.682 -0.732  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.731]
# Axes:
# [0.478 0.478 0.269]
# choi state:
# [[ 0.548+0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.317+0.j     0.175-0.163j -0.   +0.j   ]
#  [ 0.   +0.j     0.175+0.163j  0.317+0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j    -0.183+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=66ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.732  0.682 -0.   ]
#  [ 0.682  0.732 -0.   ]]
# Center:
# [-0.    0.    0.83]
# Axes:
# [0.17  0.366 0.366]
# choi state:
# [[ 0.665+0.j    -0.031-0.034j -0.031+0.034j  0.062+0.j   ]
#  [-0.031+0.034j  0.25 +0.j    -0.062-0.031j  0.031-0.034j]
#  [-0.031-0.034j -0.062+0.031j  0.25 +0.j     0.031+0.034j]
#  [ 0.062+0.j     0.031+0.034j  0.031-0.034j -0.165+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.732  0.682 -0.   ]
#  [ 0.682  0.732 -0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.    0.    0.83]
# Axes:
# [0.366 0.366 0.17 ]
# choi state:
# [[ 0.623+0.j    -0.   +0.j    -0.   -0.j    -0.   +0.j   ]
#  [-0.   -0.j     0.292+0.j    -0.134+0.125j -0.   +0.j   ]
#  [-0.   +0.j    -0.134-0.125j  0.292+0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j    -0.208+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=68ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [ 0.709  0.705  0.   ]
#  [ 0.705 -0.709  0.   ]]
# Center:
# [-0.     0.     0.907]
# Axes:
# [0.093 0.249 0.249]
# choi state:
# [[ 0.704+0.j    -0.023+0.022j -0.023-0.022j  0.044+0.j   ]
#  [-0.023-0.022j  0.25 +0.j    -0.044+0.016j  0.023+0.022j]
#  [-0.023+0.022j -0.044-0.016j  0.25 +0.j     0.023-0.022j]
#  [ 0.044+0.j     0.023-0.022j  0.023+0.022j -0.204+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.709  0.705  0.   ]
#  [ 0.705 -0.709  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.907]
# Axes:
# [0.249 0.249 0.093]
# choi state:
# [[ 0.68 +0.j    -0.   +0.j    -0.   -0.j    -0.   +0.j   ]
#  [-0.   -0.j     0.273+0.j     0.088+0.088j -0.   +0.j   ]
#  [-0.   +0.j     0.088-0.088j  0.273+0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j    -0.227+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=70ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [ 0.735  0.678  0.   ]
#  [ 0.678 -0.735  0.   ]]
# Center:
# [-0.     0.     0.957]
# Axes:
# [0.043 0.129 0.129]
# choi state:
# [[ 0.729+0.j    -0.012+0.012j -0.012-0.012j  0.022+0.j   ]
#  [-0.012-0.012j  0.25 +0.j    -0.022+0.008j  0.012+0.012j]
#  [-0.012+0.012j -0.022-0.008j  0.25 +0.j     0.012-0.012j]
#  [ 0.022+0.j     0.012-0.012j  0.012+0.012j -0.229+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.735  0.678  0.   ]
#  [ 0.678 -0.735  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.957]
# Axes:
# [0.129 0.129 0.043]
# choi state:
# [[ 0.718+0.j    -0.   +0.j    -0.   -0.j    -0.   +0.j   ]
#  [-0.   -0.j     0.261+0.j     0.047+0.044j -0.   +0.j   ]
#  [-0.   +0.j     0.047-0.044j  0.261+0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j    -0.239+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=72ns:
# R:
# [[-0.844 -0.536  0.   ]
#  [-0.536  0.844  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.977]
# Axes:
# [0.006 0.006 0.023]
# choi state:
# [[ 0.733+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.256+0.j    -0.003-0.002j -0.   -0.j   ]
#  [-0.   -0.j    -0.003+0.002j  0.256+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.244+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.844 -0.536  0.   ]
#  [-0.536  0.844  0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [-0.    -0.     0.977]
# Axes:
# [0.006 0.006 0.023]
# choi state:
# [[ 0.733+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.256+0.j    -0.003-0.002j -0.   -0.j   ]
#  [-0.   -0.j    -0.003+0.002j  0.256+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.244+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=74ns:
# R:
# [[ 0.     0.     1.   ]
#  [ 0.816  0.578 -0.   ]
#  [-0.578  0.816  0.   ]]
# Center:
# [0.    0.    0.965]
# Axes:
# [0.035 0.116 0.116]
# choi state:
# [[ 0.733+0.j     0.012-0.012j  0.012+0.012j  0.017+0.j   ]
#  [ 0.012+0.012j  0.25 +0.j    -0.017+0.007j -0.012-0.012j]
#  [ 0.012-0.012j -0.017-0.007j  0.25 +0.j    -0.012+0.012j]
#  [ 0.017+0.j    -0.012+0.012j -0.012-0.012j -0.233+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.816  0.578 -0.   ]
#  [-0.578  0.816  0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [0.    0.    0.965]
# Axes:
# [0.116 0.116 0.035]
# choi state:
# [[ 0.741+0.j  0.   -0.j  0.   +0.j  0.047+0.j]
#  [ 0.   +0.j  0.241+0.j -0.   +0.j  0.   +0.j]
#  [ 0.   -0.j -0.   -0.j  0.241+0.j  0.   -0.j]
#  [ 0.047+0.j  0.   -0.j  0.   +0.j -0.224+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=76ns:
# R:
# [[ 0.     0.     1.   ]
#  [ 0.957  0.291 -0.   ]
#  [-0.291  0.957 -0.   ]]
# Center:
# [0.    0.    0.923]
# Axes:
# [0.077 0.236 0.236]
# choi state:
# [[ 0.711+0.j     0.027-0.028j  0.027+0.028j  0.017+0.j   ]
#  [ 0.027+0.028j  0.25 +0.j    -0.017+0.018j -0.027-0.028j]
#  [ 0.027-0.028j -0.017-0.018j  0.25 +0.j    -0.027+0.028j]
#  [ 0.017+0.j    -0.027+0.028j -0.027-0.028j -0.211+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.957  0.291 -0.   ]
#  [-0.291  0.957 -0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [0.    0.    0.923]
# Axes:
# [0.236 0.236 0.077]
# choi state:
# [[ 0.731+0.j  0.   -0.j  0.   +0.j  0.113+0.j]
#  [ 0.   +0.j  0.231+0.j -0.   +0.j  0.   +0.j]
#  [ 0.   -0.j -0.   -0.j  0.231+0.j  0.   -0.j]
#  [ 0.113+0.j  0.   -0.j  0.   +0.j -0.192+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=78ns:
# R:
# [[ 0.     0.     1.   ]
#  [-0.841  0.541  0.   ]
#  [-0.541 -0.841  0.   ]]
# Center:
# [0.    0.    0.853]
# Axes:
# [0.147 0.352 0.352]
# choi state:
# [[ 0.677+0.j     0.034+0.037j  0.034-0.037j  0.048+0.j   ]
#  [ 0.034-0.037j  0.25 +0.j    -0.048-0.031j -0.034+0.037j]
#  [ 0.034+0.037j -0.048+0.031j  0.25 +0.j    -0.034-0.037j]
#  [ 0.048+0.j    -0.034-0.037j -0.034+0.037j -0.177+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.841  0.541  0.   ]
#  [-0.541 -0.841  0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [0.    0.    0.853]
# Axes:
# [0.352 0.352 0.147]
# choi state:
# [[ 0.713+0.j  0.   -0.j  0.   +0.j -0.148+0.j]
#  [ 0.   +0.j  0.213+0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.213+0.j -0.   +0.j]
#  [-0.148+0.j -0.   +0.j -0.   -0.j -0.14 +0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=80ns:
# R:
# [[ 0.     0.     1.   ]
#  [-0.77   0.638 -0.   ]
#  [-0.638 -0.77   0.   ]]
# Center:
# [-0.     0.     0.761]
# Axes:
# [0.239 0.461 0.461]
# choi state:
# [[ 0.63 +0.j     0.039+0.044j  0.039-0.044j  0.073+0.j   ]
#  [ 0.039-0.044j  0.25 +0.j    -0.073-0.046j -0.039+0.044j]
#  [ 0.039+0.044j -0.073+0.046j  0.25 +0.j    -0.039-0.044j]
#  [ 0.073+0.j    -0.039-0.044j -0.039+0.044j -0.13 +0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.77   0.638 -0.   ]
#  [-0.638 -0.77   0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [-0.     0.     0.761]
# Axes:
# [0.461 0.461 0.239]
# choi state:
# [[ 0.69 +0.j  0.   -0.j  0.   +0.j -0.177+0.j]
#  [ 0.   +0.j  0.19 +0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.19 +0.j -0.   +0.j]
#  [-0.177+0.j -0.   +0.j -0.   -0.j -0.07 +0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=82ns:
# R:
# [[ 0.     0.     1.   ]
#  [-0.776  0.631 -0.   ]
#  [-0.631 -0.776  0.   ]]
# Center:
# [-0.     0.     0.652]
# Axes:
# [0.348 0.562 0.562]
# choi state:
# [[ 0.576+0.j     0.043+0.054j  0.043-0.054j  0.089+0.j   ]
#  [ 0.043-0.054j  0.25 +0.j    -0.089-0.068j -0.043+0.054j]
#  [ 0.043+0.054j -0.089+0.068j  0.25 +0.j    -0.043-0.054j]
#  [ 0.089+0.j    -0.043-0.054j -0.043+0.054j -0.076+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.776  0.631 -0.   ]
#  [-0.631 -0.776  0.   ]
#  [ 0.     0.     1.   ]]
# Center:
# [-0.     0.     0.652]
# Axes:
# [0.562 0.562 0.348]
# choi state:
# [[ 0.663+0.j  0.   -0.j  0.   +0.j -0.218+0.j]
#  [ 0.   +0.j  0.163+0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.163+0.j -0.   +0.j]
#  [-0.218+0.j -0.   +0.j -0.   -0.j  0.011+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=84ns:
# R:
# [[ 0.709  0.705 -0.   ]
#  [ 0.705 -0.709  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.    -0.     0.534]
# Axes:
# [0.653 0.653 0.466]
# choi state:
# [[ 0.401+0.j   -0.   +0.j   -0.   -0.j    0.   +0.j  ]
#  [-0.   -0.j    0.366+0.j    0.232+0.23j  0.   +0.j  ]
#  [-0.   +0.j    0.232-0.23j  0.366+0.j    0.   -0.j  ]
#  [ 0.   +0.j    0.   -0.j    0.   +0.j   -0.134+0.j  ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.709  0.705 -0.   ]
#  [ 0.705 -0.709  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.    -0.     0.534]
# Axes:
# [0.653 0.653 0.466]
# choi state:
# [[ 0.401+0.j   -0.   +0.j   -0.   -0.j    0.   +0.j  ]
#  [-0.   -0.j    0.366+0.j    0.232+0.23j  0.   +0.j  ]
#  [-0.   +0.j    0.232-0.23j  0.366+0.j    0.   -0.j  ]
#  [ 0.   +0.j    0.   -0.j    0.   +0.j   -0.134+0.j  ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=86ns:
# R:
# [[-0.741  0.672 -0.   ]
#  [ 0.672  0.741 -0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.416]
# Axes:
# [0.733 0.733 0.584]
# choi state:
# [[ 0.312+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.396+0.j    -0.271+0.246j  0.   +0.j   ]
#  [-0.   +0.j    -0.271-0.246j  0.396+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j    -0.104+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.741  0.672 -0.   ]
#  [ 0.672  0.741 -0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.416]
# Axes:
# [0.733 0.733 0.584]
# choi state:
# [[ 0.312+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.396+0.j    -0.271+0.246j  0.   +0.j   ]
#  [-0.   +0.j    -0.271-0.246j  0.396+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j    -0.104+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=88ns:
# R:
# [[ 0.708  0.707 -0.   ]
#  [ 0.707 -0.708  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.304]
# Axes:
# [0.8   0.8   0.696]
# choi state:
# [[ 0.228+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.424+0.j     0.283+0.283j  0.   +0.j   ]
#  [-0.   +0.j     0.283-0.283j  0.424+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j    -0.076+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.708  0.707 -0.   ]
#  [ 0.707 -0.708  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.304]
# Axes:
# [0.8   0.8   0.696]
# choi state:
# [[ 0.228+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.424+0.j     0.283+0.283j  0.   +0.j   ]
#  [-0.   +0.j     0.283-0.283j  0.424+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j    -0.076+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=90ns:
# R:
# [[ 0.722  0.692 -0.   ]
#  [ 0.692 -0.722  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.207]
# Axes:
# [0.853 0.853 0.793]
# choi state:
# [[ 0.155+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.448+0.j     0.308+0.295j  0.   +0.j   ]
#  [-0.   +0.j     0.308-0.295j  0.448+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j    -0.052+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.722  0.692 -0.   ]
#  [ 0.692 -0.722  0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.207]
# Axes:
# [0.853 0.853 0.793]
# choi state:
# [[ 0.155+0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]
#  [-0.   -0.j     0.448+0.j     0.308+0.295j  0.   +0.j   ]
#  [-0.   +0.j     0.308-0.295j  0.448+0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j    -0.052+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=92ns:
# R:
# [[-0.71  -0.704  0.   ]
#  [-0.704  0.71  -0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.132]
# Axes:
# [0.892 0.892 0.868]
# choi state:
# [[ 0.099+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.467+0.j    -0.317-0.314j -0.   +0.j   ]
#  [ 0.   +0.j    -0.317+0.314j  0.467+0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j    -0.033+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.71  -0.704  0.   ]
#  [-0.704  0.71  -0.   ]
#  [-0.    -0.    -1.   ]]
# Center:
# [-0.     0.     0.132]
# Axes:
# [0.892 0.892 0.868]
# choi state:
# [[ 0.099+0.j     0.   +0.j     0.   -0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.467+0.j    -0.317-0.314j -0.   +0.j   ]
#  [ 0.   +0.j    -0.317+0.314j  0.467+0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j    -0.033+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=94ns:
# R:
# [[ 0.783  0.622  0.   ]
#  [ 0.622 -0.783 -0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.     0.     0.082]
# Axes:
# [0.915 0.915 0.918]
# choi state:
# [[ 0.062+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.479+0.j     0.358+0.285j -0.   -0.j   ]
#  [ 0.   -0.j     0.358-0.285j  0.479+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.021+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.783  0.622  0.   ]
#  [ 0.622 -0.783 -0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [-0.     0.     0.082]
# Axes:
# [0.915 0.915 0.918]
# choi state:
# [[ 0.062+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.479+0.j     0.358+0.285j -0.   -0.j   ]
#  [ 0.   -0.j     0.358-0.285j  0.479+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.021+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=96ns:
# R:
# [[ 0.912  0.409  0.   ]
#  [ 0.409 -0.912 -0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [-0.     0.     0.062]
# Axes:
# [0.923 0.923 0.938]
# choi state:
# [[ 0.047+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.484+0.j     0.421+0.189j -0.   -0.j   ]
#  [ 0.   -0.j     0.421-0.189j  0.484+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.016+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.912  0.409  0.   ]
#  [ 0.409 -0.912 -0.   ]
#  [-0.     0.    -1.   ]]
# Center:
# [-0.     0.     0.062]
# Axes:
# [0.923 0.923 0.938]
# choi state:
# [[ 0.047+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.484+0.j     0.421+0.189j -0.   -0.j   ]
#  [ 0.   -0.j     0.421-0.189j  0.484+0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j    -0.016+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=98ns:
# R:
# [[ 0.    -0.     1.   ]
#  [ 0.869 -0.495 -0.   ]
#  [ 0.495  0.869  0.   ]]
# Center:
# [-0.     0.     0.073]
# Axes:
# [0.927 0.915 0.915]
# choi state:
# [[ 0.286+0.j     0.172-0.099j  0.172+0.099j -0.113+0.j   ]
#  [ 0.172+0.099j  0.25 +0.j     0.113+0.201j -0.172-0.099j]
#  [ 0.172-0.099j  0.113-0.201j  0.25 +0.j    -0.172+0.099j]
#  [-0.113+0.j    -0.172+0.099j -0.172-0.099j  0.214+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.869 -0.495 -0.   ]
#  [ 0.495  0.869  0.   ]
#  [ 0.    -0.     1.   ]]
# Center:
# [-0.     0.     0.073]
# Axes:
# [0.915 0.915 0.927]
# choi state:
# [[ 0.518+0.j -0.   +0.j -0.   -0.j  0.398+0.j]
#  [-0.   -0.j  0.018+0.j  0.   +0.j  0.   +0.j]
#  [-0.   +0.j  0.   -0.j  0.018+0.j  0.   -0.j]
#  [ 0.398+0.j  0.   -0.j  0.   +0.j  0.445+0.j]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=100ns:
# R:
# [[ 0.    -0.    -1.   ]
#  [-0.811  0.586 -0.   ]
#  [ 0.586  0.811  0.   ]]
# Center:
# [-0.    -0.     0.113]
# Axes:
# [0.887 0.892 0.892]
# choi state:
# [[ 0.307+0.j   -0.047-0.09j -0.047+0.09j  0.131+0.j  ]
#  [-0.047+0.09j  0.25 +0.j   -0.131-0.18j  0.047-0.09j]
#  [-0.047-0.09j -0.131+0.18j  0.25 +0.j    0.047+0.09j]
#  [ 0.131+0.j    0.047+0.09j  0.047-0.09j  0.193+0.j  ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.811  0.586 -0.   ]
#  [ 0.586  0.811  0.   ]
#  [ 0.    -0.    -1.   ]]
# Center:
# [-0.    -0.     0.113]
# Axes:
# [0.892 0.892 0.887]
# choi state:
# [[ 0.085+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.472+0.j    -0.361+0.261j -0.   -0.j   ]
#  [ 0.   -0.j    -0.361-0.261j  0.472+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j    -0.028+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=102ns:
# R:
# [[ 0.     0.    -1.   ]
#  [-0.745  0.667 -0.   ]
#  [ 0.667  0.745  0.   ]]
# Center:
# [ 0.    -0.     0.181]
# Axes:
# [0.819 0.854 0.854]
# choi state:
# [[ 0.34 +0.j    -0.038-0.079j -0.038+0.079j  0.142+0.j   ]
#  [-0.038+0.079j  0.25 +0.j    -0.142-0.153j  0.038-0.079j]
#  [-0.038-0.079j -0.142+0.153j  0.25 +0.j     0.038+0.079j]
#  [ 0.142+0.j     0.038+0.079j  0.038-0.079j  0.16 +0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[-0.745  0.667 -0.   ]
#  [ 0.667  0.745  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.181]
# Axes:
# [0.854 0.854 0.819]
# choi state:
# [[ 0.136+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.455+0.j    -0.318+0.285j -0.   -0.j   ]
#  [ 0.   -0.j    -0.318-0.285j  0.455+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j    -0.045+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=104ns:
# R:
# [[ 0.     0.    -1.   ]
#  [ 0.728  0.686  0.   ]
#  [ 0.686 -0.728  0.   ]]
# Center:
# [ 0.    -0.     0.271]
# Axes:
# [0.729 0.801 0.801]
# choi state:
# [[ 0.385+0.j    -0.038+0.073j -0.038-0.073j  0.137+0.j   ]
#  [-0.038-0.073j  0.25 +0.j    -0.137+0.133j  0.038+0.073j]
#  [-0.038+0.073j -0.137-0.133j  0.25 +0.j     0.038-0.073j]
#  [ 0.137+0.j     0.038-0.073j  0.038+0.073j  0.115+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.728  0.686  0.   ]
#  [ 0.686 -0.728  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.271]
# Axes:
# [0.801 0.801 0.729]
# choi state:
# [[ 0.203+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.432+0.j     0.292+0.275j -0.   -0.j   ]
#  [ 0.   -0.j     0.292-0.275j  0.432+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j    -0.068+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=106ns:
# R:
# [[ 0.     0.    -1.   ]
#  [ 0.729  0.685  0.   ]
#  [ 0.685 -0.729  0.   ]]
# Center:
# [ 0.    -0.     0.377]
# Axes:
# [0.623 0.735 0.735]
# choi state:
# [[ 0.438+0.j    -0.039+0.067j -0.039-0.067j  0.126+0.j   ]
#  [-0.039-0.067j  0.25 +0.j    -0.126+0.114j  0.039+0.067j]
#  [-0.039+0.067j -0.126-0.114j  0.25 +0.j     0.039-0.067j]
#  [ 0.126+0.j     0.039-0.067j  0.039+0.067j  0.062+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.729  0.685  0.   ]
#  [ 0.685 -0.729  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.377]
# Axes:
# [0.735 0.735 0.623]
# choi state:
# [[ 0.283+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.406+0.j     0.268+0.252j -0.   -0.j   ]
#  [ 0.   -0.j     0.268-0.252j  0.406+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j    -0.094+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=108ns:
# R:
# [[ 0.     0.    -1.   ]
#  [ 0.828  0.56   0.   ]
#  [ 0.56  -0.828  0.   ]]
# Center:
# [ 0.    -0.     0.492]
# Axes:
# [0.508 0.657 0.657]
# choi state:
# [[ 0.496+0.j    -0.047+0.068j -0.047-0.068j  0.092+0.j   ]
#  [-0.047-0.068j  0.25 +0.j    -0.092+0.105j  0.047+0.068j]
#  [-0.047+0.068j -0.092-0.105j  0.25 +0.j     0.047-0.068j]
#  [ 0.092+0.j     0.047-0.068j  0.047+0.068j  0.004+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.828  0.56   0.   ]
#  [ 0.56  -0.828  0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.492]
# Axes:
# [0.657 0.657 0.508]
# choi state:
# [[ 0.369+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.377+0.j     0.272+0.184j -0.   -0.j   ]
#  [ 0.   -0.j     0.272-0.184j  0.377+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j    -0.123+0.j   ]]
# ----------------------------------------------------------------------------------------------------
# Results for swap=110ns:
# R:
# [[ 0.     0.    -1.   ]
#  [ 0.886  0.463  0.   ]
#  [ 0.463 -0.886 -0.   ]]
# Center:
# [ 0.    -0.     0.609]
# Axes:
# [0.391 0.567 0.567]
# choi state:
# [[ 0.554+0.j    -0.048+0.063j -0.048-0.063j  0.066+0.j   ]
#  [-0.048-0.063j  0.25 +0.j    -0.066+0.087j  0.048+0.063j]
#  [-0.048+0.063j -0.066-0.087j  0.25 +0.j     0.048-0.063j]
#  [ 0.066+0.j     0.048-0.063j  0.048+0.063j -0.054+0.j   ]]
# ---------------------------------------------------------------------------
# After swapping the axes, center and R
# R:
# [[ 0.886  0.463  0.   ]
#  [ 0.463 -0.886 -0.   ]
#  [ 0.     0.    -1.   ]]
# Center:
# [ 0.    -0.     0.609]
# Axes:
# [0.567 0.567 0.391]
# choi state:
# [[ 0.457+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.348+0.j     0.251+0.131j -0.   -0.j   ]
#  [ 0.   -0.j     0.251-0.131j  0.348+0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j    -0.152+0.j   ]]
# ----------------------------------------------------------------------------------------------------

# %%
from quam_libs.quantum_memory.legacy.marcos import diagnose_choi_states
tol = 1e-6
swap_choi_list = [swap_result_dict[key]["choi state"] for key in swap_result_dict.keys()]
keys = list(swap_result_dict.keys())
df = diagnose_choi_states(swap_choi_list,keys,tol_pos=tol, tol_tp=tol)

# %%
from quam_libs.quantum_memory.legacy.NoiseAnalyze import Checker
np.set_printoptions(precision=3, suppress=True)
for i,key in enumerate(swap_result_dict.keys()):
    checker = Checker(swap_choi_list[i])
    choi, count = checker.choi_checker(index=[1], repeat=100, tol=tol, print_reason=False)
    print(f"After {count} iterations, the Choi state is:\n{choi}")
    print('-'*100)
    swap_result_dict[key]["choi state"] = choi
# Out:
# After 4 iterations, the Choi state is valid.
# After 4 iterations, the Choi state is:
# [[ 0.   +0.j    -0.   +0.012j -0.   -0.012j -0.   +0.j   ]
#  [-0.   -0.012j  0.5  +0.j    -0.499-0.j     0.   +0.012j]
#  [-0.   +0.012j -0.499+0.j     0.5  +0.j     0.   -0.012j]
#  [-0.   -0.j     0.   -0.012j  0.   +0.012j  0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j  0.   +0.j  0.   -0.j -0.442+0.j]
#  [ 0.   -0.j  0.   +0.j -0.   +0.j -0.   +0.j]
#  [ 0.   +0.j -0.   -0.j  0.009+0.j -0.   -0.j]
#  [-0.442-0.j -0.   -0.j -0.   +0.j  0.491+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.034+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.466+0.j     0.391+0.278j -0.   -0.j   ]
#  [ 0.   -0.j     0.391-0.278j  0.5  +0.j    -0.   +0.j   ]
#  [ 0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.074+0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.426+0.j   -0.354-0.29j  0.   -0.j  ]
#  [-0.   -0.j   -0.354+0.29j  0.5  +0.j    0.   +0.j  ]
#  [ 0.   -0.j    0.   +0.j    0.   -0.j    0.   +0.j  ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.126+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.374+0.j    -0.355-0.238j  0.   -0.j   ]
#  [-0.   -0.j    -0.355+0.238j  0.5  +0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.186+0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.314+0.j   -0.308-0.24j  0.   -0.j  ]
#  [-0.   -0.j   -0.308+0.24j  0.5  +0.j    0.   +0.j  ]
#  [ 0.   -0.j    0.   +0.j    0.   -0.j    0.   +0.j  ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.249+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.251+0.j     0.266-0.222j  0.   -0.j   ]
#  [-0.   -0.j     0.266+0.222j  0.5  +0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.313+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.187+0.j    -0.236-0.181j  0.   -0.j   ]
#  [-0.   -0.j    -0.236+0.181j  0.5  +0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.373+0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.127+0.j    -0.223-0.097j  0.   -0.j   ]
#  [-0.   -0.j    -0.223+0.097j  0.5  +0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.423+0.j    -0.   -0.j    -0.   +0.j    -0.   +0.j   ]
#  [-0.   +0.j     0.077+0.j     0.173+0.066j  0.   -0.j   ]
#  [-0.   -0.j     0.173-0.066j  0.5  +0.j    -0.   +0.j   ]
#  [-0.   -0.j     0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j -0.   +0.j  0.   -0.j  0.117+0.j]
#  [-0.   -0.j  0.   +0.j -0.   +0.j -0.   +0.j]
#  [ 0.   +0.j -0.   -0.j  0.463+0.j -0.   -0.j]
#  [ 0.117-0.j -0.   -0.j -0.   +0.j  0.037+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j -0.   +0.j  0.   -0.j  0.058+0.j]
#  [-0.   -0.j  0.   +0.j -0.   +0.j -0.   +0.j]
#  [ 0.   +0.j -0.   -0.j  0.487+0.j -0.   -0.j]
#  [ 0.058-0.j -0.   -0.j -0.   +0.j  0.013+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.496+0.j     0.   -0.j    -0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.004+0.j    -0.003-0.001j  0.   -0.j   ]
#  [-0.   -0.j    -0.003+0.001j  0.5  +0.j     0.   +0.j   ]
#  [ 0.   -0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.488+0.j    0.   +0.j    0.   -0.j   -0.   +0.j  ]
#  [ 0.   -0.j    0.012+0.j    0.064+0.02j -0.   +0.j  ]
#  [ 0.   +0.j    0.064-0.02j  0.5  +0.j    0.   -0.j  ]
#  [-0.   -0.j   -0.   -0.j    0.   +0.j    0.   +0.j  ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.465+0.j     0.   +0.j     0.   -0.j    -0.   -0.j   ]
#  [ 0.   -0.j     0.035+0.j     0.123+0.037j -0.   +0.j   ]
#  [ 0.   +0.j     0.123-0.037j  0.5  +0.j     0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j     0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.427+0.j     0.   +0.j     0.   -0.j    -0.   -0.j   ]
#  [ 0.   -0.j     0.073+0.j     0.181+0.054j -0.   +0.j   ]
#  [ 0.   +0.j     0.181-0.054j  0.5  +0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.377+0.j     0.   +0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   -0.j     0.123+0.j     0.24 +0.051j -0.   -0.j   ]
#  [ 0.   -0.j     0.24 -0.051j  0.5  +0.j    -0.   +0.j   ]
#  [-0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.32 +0.j     0.   -0.j    -0.   +0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.18 +0.j    -0.297+0.019j  0.   -0.j   ]
#  [-0.   -0.j    -0.297-0.019j  0.5  +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.258+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.242+0.j    -0.289+0.187j -0.   -0.j   ]
#  [ 0.   -0.j    -0.289-0.187j  0.5  +0.j     0.   +0.j   ]
#  [ 0.   -0.j    -0.   +0.j     0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.196+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.304+0.j    -0.273+0.272j -0.   -0.j   ]
#  [ 0.   -0.j    -0.273-0.272j  0.5  +0.j    -0.   +0.j   ]
#  [ 0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.138+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.362+0.j    -0.319+0.272j -0.   -0.j   ]
#  [ 0.   -0.j    -0.319-0.272j  0.5  +0.j    -0.   +0.j   ]
#  [ 0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.088+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.412+0.j    -0.365+0.257j -0.   -0.j   ]
#  [ 0.   -0.j    -0.365-0.257j  0.5  +0.j    -0.   +0.j   ]
#  [ 0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.049+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.451+0.j    -0.373+0.279j -0.   -0.j   ]
#  [ 0.   -0.j    -0.373-0.279j  0.5  +0.j    -0.   +0.j   ]
#  [ 0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.025+0.j    -0.   -0.j    -0.   +0.j    -0.   +0.j   ]
#  [-0.   +0.j     0.475+0.j     0.339-0.336j  0.   -0.j   ]
#  [-0.   -0.j     0.339+0.336j  0.5  +0.j     0.   +0.j   ]
#  [-0.   -0.j     0.   +0.j     0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.016+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.484+0.j     0.378+0.297j -0.   -0.j   ]
#  [ 0.   -0.j     0.378-0.297j  0.5  +0.j    -0.   +0.j   ]
#  [ 0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.023+0.j     0.   +0.j     0.   -0.j    -0.   -0.j   ]
#  [ 0.   -0.j     0.477+0.j    -0.414-0.235j -0.   +0.j   ]
#  [ 0.   +0.j    -0.414+0.235j  0.5  +0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j  0.   -0.j  0.   +0.j  0.446-0.j]
#  [ 0.   +0.j  0.   +0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.046+0.j -0.   +0.j]
#  [ 0.446+0.j -0.   +0.j -0.   -0.j  0.454+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j  0.   -0.j  0.   +0.j -0.44 -0.j]
#  [ 0.   +0.j  0.   +0.j -0.   -0.j -0.   -0.j]
#  [ 0.   -0.j -0.   +0.j  0.082+0.j -0.   +0.j]
#  [-0.44 +0.j -0.   +0.j -0.   -0.j  0.418+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.13 +0.j   -0.   -0.j   -0.   +0.j    0.   +0.j  ]
#  [-0.   +0.j    0.37 +0.j    0.389-0.14j  0.   -0.j  ]
#  [-0.   -0.j    0.389+0.14j  0.5  +0.j    0.   -0.j  ]
#  [ 0.   -0.j    0.   +0.j    0.   +0.j    0.   +0.j  ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.187+0.j    -0.   -0.j     0.   -0.j     0.   +0.j   ]
#  [-0.   +0.j     0.313+0.j     0.332-0.183j -0.   +0.j   ]
#  [ 0.   +0.j     0.332+0.183j  0.5  +0.j    -0.   -0.j   ]
#  [ 0.   -0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.248+0.j    -0.   -0.j     0.   -0.j     0.   +0.j   ]
#  [-0.   +0.j     0.252+0.j     0.288-0.176j -0.   +0.j   ]
#  [ 0.   +0.j     0.288+0.176j  0.5  +0.j    -0.   -0.j   ]
#  [ 0.   -0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.309+0.j     0.   -0.j     0.   -0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.191+0.j     0.237-0.168j -0.   +0.j   ]
#  [ 0.   +0.j     0.237+0.168j  0.5  +0.j    -0.   -0.j   ]
#  [ 0.   -0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.366+0.j     0.   +0.j     0.   -0.j     0.   -0.j   ]
#  [ 0.   -0.j     0.134+0.j     0.175-0.163j -0.   +0.j   ]
#  [ 0.   +0.j     0.175+0.163j  0.5  +0.j    -0.   -0.j   ]
#  [ 0.   +0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.415+0.j    -0.   +0.j     0.   -0.j    -0.   -0.j   ]
#  [-0.   -0.j     0.085+0.j    -0.134+0.125j -0.   +0.j   ]
#  [ 0.   +0.j    -0.134-0.125j  0.5  +0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.454+0.j    -0.   +0.j     0.   -0.j    -0.   -0.j   ]
#  [-0.   -0.j     0.046+0.j     0.088+0.088j -0.   +0.j   ]
#  [ 0.   +0.j     0.088-0.088j  0.5  +0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.479+0.j    -0.   +0.j     0.   -0.j    -0.   -0.j   ]
#  [-0.   -0.j     0.021+0.j     0.047+0.044j -0.   +0.j   ]
#  [ 0.   +0.j     0.047-0.044j  0.5  +0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.488+0.j    -0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [-0.   +0.j     0.012+0.j    -0.003-0.002j -0.   -0.j   ]
#  [ 0.   -0.j    -0.003+0.002j  0.5  +0.j    -0.   +0.j   ]
#  [ 0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j  0.   -0.j  0.   +0.j  0.047-0.j]
#  [ 0.   +0.j  0.   +0.j -0.   +0.j -0.   -0.j]
#  [ 0.   -0.j -0.   -0.j  0.483+0.j  0.   -0.j]
#  [ 0.047+0.j -0.   +0.j  0.   +0.j  0.017+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j  0.   -0.j  0.   +0.j  0.113-0.j]
#  [ 0.   +0.j  0.   +0.j -0.   +0.j -0.   -0.j]
#  [ 0.   -0.j -0.   -0.j  0.461+0.j  0.   -0.j]
#  [ 0.113+0.j -0.   +0.j  0.   +0.j  0.039+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j  0.   -0.j  0.   +0.j -0.148-0.j]
#  [ 0.   +0.j  0.   +0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.427+0.j -0.   +0.j]
#  [-0.148+0.j -0.   +0.j -0.   -0.j  0.073+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j  0.   -0.j  0.   +0.j -0.177+0.j]
#  [ 0.   +0.j  0.   +0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.38 +0.j -0.   +0.j]
#  [-0.177-0.j -0.   +0.j -0.   -0.j  0.12 +0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j  0.   -0.j  0.   +0.j -0.218-0.j]
#  [ 0.   +0.j  0.   +0.j  0.   +0.j -0.   -0.j]
#  [ 0.   -0.j  0.   -0.j  0.326+0.j -0.   +0.j]
#  [-0.218+0.j -0.   +0.j -0.   -0.j  0.174+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.267+0.j   -0.   +0.j   -0.   -0.j    0.   -0.j  ]
#  [-0.   -0.j    0.233+0.j    0.232+0.23j  0.   +0.j  ]
#  [-0.   +0.j    0.232-0.23j  0.5  +0.j    0.   -0.j  ]
#  [ 0.   +0.j    0.   -0.j    0.   +0.j    0.   +0.j  ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.208+0.j    -0.   +0.j    -0.   -0.j     0.   -0.j   ]
#  [-0.   -0.j     0.292+0.j    -0.271+0.246j  0.   +0.j   ]
#  [-0.   +0.j    -0.271-0.246j  0.5  +0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.152+0.j    -0.   +0.j    -0.   -0.j     0.   -0.j   ]
#  [-0.   -0.j     0.348+0.j     0.283+0.283j  0.   +0.j   ]
#  [-0.   +0.j     0.283-0.283j  0.5  +0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.104+0.j    -0.   +0.j    -0.   -0.j     0.   -0.j   ]
#  [-0.   -0.j     0.396+0.j     0.308+0.295j  0.   +0.j   ]
#  [-0.   +0.j     0.308-0.295j  0.5  +0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.066+0.j     0.   +0.j     0.   -0.j    -0.   -0.j   ]
#  [ 0.   -0.j     0.434+0.j    -0.317-0.314j -0.   +0.j   ]
#  [ 0.   +0.j    -0.317+0.314j  0.5  +0.j    -0.   -0.j   ]
#  [-0.   +0.j    -0.   -0.j    -0.   +0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.041+0.j     0.   -0.j     0.   +0.j     0.   +0.j   ]
#  [ 0.   +0.j     0.459+0.j     0.358+0.285j -0.   -0.j   ]
#  [ 0.   -0.j     0.358-0.285j  0.5  +0.j    -0.   +0.j   ]
#  [ 0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.031+0.j     0.   -0.j     0.   +0.j     0.   -0.j   ]
#  [ 0.   +0.j     0.469+0.j     0.421+0.189j -0.   -0.j   ]
#  [ 0.   -0.j     0.421-0.189j  0.5  +0.j    -0.   +0.j   ]
#  [ 0.   +0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.5  +0.j -0.   +0.j -0.   -0.j  0.398+0.j]
#  [-0.   -0.j  0.   +0.j  0.   +0.j  0.   +0.j]
#  [-0.   +0.j  0.   -0.j  0.036+0.j  0.   -0.j]
#  [ 0.398-0.j  0.   -0.j  0.   +0.j  0.464+0.j]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.057+0.j     0.   -0.j     0.   +0.j    -0.   -0.j   ]
#  [ 0.   +0.j     0.443+0.j    -0.361+0.261j -0.   -0.j   ]
#  [ 0.   -0.j    -0.361-0.261j  0.5  +0.j    -0.   +0.j   ]
#  [-0.   +0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.09 +0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.41 +0.j    -0.318+0.285j -0.   -0.j   ]
#  [ 0.   -0.j    -0.318-0.285j  0.5  +0.j    -0.   +0.j   ]
#  [-0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.135+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.365+0.j     0.292+0.275j -0.   -0.j   ]
#  [ 0.   -0.j     0.292-0.275j  0.5  +0.j    -0.   +0.j   ]
#  [-0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.188+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.312+0.j     0.268+0.252j -0.   -0.j   ]
#  [ 0.   -0.j     0.268-0.252j  0.5  +0.j    -0.   +0.j   ]
#  [-0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.246+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.254+0.j     0.272+0.184j -0.   -0.j   ]
#  [ 0.   -0.j     0.272-0.184j  0.5  +0.j    -0.   +0.j   ]
#  [-0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is:
# [[ 0.304+0.j     0.   -0.j     0.   +0.j    -0.   +0.j   ]
#  [ 0.   +0.j     0.196+0.j     0.251+0.131j -0.   -0.j   ]
#  [ 0.   -0.j     0.251-0.131j  0.5  +0.j    -0.   +0.j   ]
#  [-0.   -0.j    -0.   +0.j    -0.   -0.j     0.   +0.j   ]]
# ----------------------------------------------------------------------------------------------------

# %%
swap_choi_list = [swap_result_dict[key]["choi state"] for key in swap_result_dict.keys()]
keys = list(swap_result_dict.keys())
df = diagnose_choi_states(swap_choi_list,keys,tol_pos=tol, tol_tp=tol)

# %%
from quam_libs.quantum_memory.entanglement_robustness import entanglementRobustness
for i,key in enumerate(swap_result_dict.keys()):
    swap_result_dict[key]['memory robustness'] = entanglementRobustness(swap_result_dict[key]["choi state"])

# %%
axes_list = np.array([swap_result_dict[key]['axes'] for key in sim_swap_analyze.keys()])
volume_list = np.array([swap_result_dict[key]['volume'] for key in sim_swap_analyze.keys()])
center_list = np.array([swap_result_dict[key]['center'] for key in sim_swap_analyze.keys()])
robustness_list = np.array([swap_result_dict[key]['memory robustness'] for key in sim_swap_analyze.keys()])

fig = plt.figure(figsize=(6, 10))
ax_name = ['axes', 'volume', 'QM']
ax_axes = fig.add_subplot(len(ax_name), 1, 1)
ax_volume = fig.add_subplot(len(ax_name), 1, 2)
ax_QM = fig.add_subplot(len(ax_name), 1, 3)
ax_axes.set_title('MLE simulation')
ax_axes.plot(swap_time,axes_list[:, 0]-0.01,'k' ,label='x-axis')
ax_axes.plot(swap_time,axes_list[:, 1],'r',label='y-axis')
ax_axes.plot(swap_time,axes_list[:, 2],'b', label='z-axis')
#ax_axes.set_ylim(0.9, 1.1)  # Adjust the y-axis limits to focus on the axes values
ax_axes.legend()
ax_axes.set_ylabel('Axes')
ax_volume.plot(swap_time,volume_list,'k', label='volume')
ax_volume.plot(swap_time,volume_list,'.r', label='volume')
#ax_volume.set_ylim(3.5,4.5)
ax_volume.set_ylabel('Volume')
ax_QM.plot(swap_time,robustness_list,'.g',label='memory robustness')
ax_QM.set_ylabel('Robustness')
ax_QM.set_xlabel('swap time(s)')
# Out:
# Text(0.5, 0, 'swap time(s)')

# %%
non_Markovian_data['sim_mle'] = {key:{
    'data':sim_swap_data[key],
    'ellipsoid':{
        'axes': swap_result_dict[key]['axes'],
        'center': swap_result_dict[key]['center'],
        'R': swap_result_dict[key]['R'],
        'volume': swap_result_dict[key]['volume'],
        'param': swap_result_dict[key]['param']},
    'quantum_information':{
        'choi': swap_result_dict[key]['choi state'],
        'robustness': swap_result_dict[key]['memory robustness']
    }
} for key in sim_swap_data.keys()}

# %% [markdown]
# ### Plot togather

# %%
raw_robustness_list = [non_Markovian_data['mle'][key]['quantum_information']['robustness'] for key in non_Markovian_data['mle'].keys()]
sim_robustness_list = [non_Markovian_data['sim_mle'][key]['quantum_information']['robustness']  for key in non_Markovian_data['sim_mle'].keys()]

plt.plot(interaction_time*1e-9,raw_robustness_list,label = 'mle')
plt.plot(swap_time,sim_robustness_list,label='sim')
plt.ylabel('Quantum robustness')
plt.legend()
plt.show()

# %%
raw_center_list = np.array( [non_Markovian_data['mle'][key]['ellipsoid']['center'] for key in non_Markovian_data['mle'].keys()])
sim_center_list = np.array( [non_Markovian_data['sim_mle'][key]['ellipsoid']['center'] for key in non_Markovian_data['sim_mle'].keys()])

plt.plot(interaction_time*1e-9,raw_center_list[:,2],'.',label = 'mle')
plt.plot(swap_time,sim_center_list[:,2],label='sim')
plt.ylim(0,1)
plt.ylabel('Center z')
plt.legend()
plt.show()

# %% [markdown]
# # QPT

# %%
node  = QualibrationNode(name="quantum_memory_qpt")
experiment_index = np.arange(5203,5324,1)

qpt = {
    f'iswap_time={int(i)}ns': {
        'superoperator': node.load_from_id(experiment_index[i]).results['results']['q0']['superoperator'],
        'mitigated superoperator': node.load_from_id(experiment_index[i]).results['results']['q0']['mitigated superoperator'],
    }
    for i in range(len(experiment_index))
}
# Out:
# 2026-03-02 21:46:15,684 - qualibrate - INFO - Creating node quantum_memory_qpt

# %%
def pauli_matrices():
    I = np.array([[1,0],[0,1]], dtype=complex)
    X = np.array([[0,1],[1,0]], dtype=complex)
    Y = np.array([[0,-1j],[1j,0]], dtype=complex)
    Z = np.array([[1,0],[0,-1]], dtype=complex)
    return [I,X,Y,Z]

def vec_col(A): return A.reshape(-1, order='F')


def build_N_M(n=1):
    pals = pauli_matrices()
    N = np.column_stack([vec_col(P) for P in pals])
    M = np.vstack([vec_col(P).conj().T for P in pals])
    return N,M

def ptm_to_superop(R, n=1):
    N,M = build_N_M(n)
    return N @ R @ (M / (2**n))

def superop_to_choi(S, din, dout):
    S4 = S.reshape(dout,dout,din,din)
    L4 = np.transpose(S4, (0,2,1,3))
    return L4.reshape(din*dout, din*dout)

# %%
for i, key in enumerate(qpt.keys()):
    # Convert PTM to Choi state
    ptm = qpt[key]['superoperator']
    superop = ptm_to_superop(ptm)
    choi = superop_to_choi(superop, 2, 2) / 2
    
    # Apply Checker correction
    checker = Checker(choi)
    choi_corrected, count = checker.choi_checker(index=[1], repeat=100, tol=1e-8, print_reason=False)
    
    # Calculate robustness
    robustness_value = QuantumMemoryAnalyze.memory_robustness(choi_corrected)
    
    # Convert MLE PTM to Choi state
    mle_ptm = qpt[key]['mitigated superoperator']
    mle_superop = ptm_to_superop(mle_ptm)
    mle_choi = superop_to_choi(mle_superop, 2, 2) / 2
    
    # Apply Checker correction to MLE Choi
    checker = Checker(mle_choi)
    mle_choi_corrected, count = checker.choi_checker(index=[1], repeat=100, tol=1e-8, print_reason=False)
    
    # Calculate MLE robustness
    mle_robustness_value = QuantumMemoryAnalyze.memory_robustness(mle_choi_corrected)
    
    # Store results in qpt dictionary
    qpt[key]['choi'] = choi_corrected
    qpt[key]['robustness'] = robustness_value
    qpt[key]['mle choi'] = mle_choi_corrected
    qpt[key]['mle robustness'] = mle_robustness_value
# Out:
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 7 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 8 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 11 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 10 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.011  0.132  0.857]
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.022  0.137  0.841]
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.017  0.145  0.838]
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.053  0.135  0.812]
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.062  0.14   0.798]
# After 3 iterations, the Choi state is valid.
# Choi state is invalid:
# ❌ Choi state is not positive semi-definite. Eigenvalues: [-0.     0.043  0.151  0.806]
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.
# After 2 iterations, the Choi state is valid.
# After 3 iterations, the Choi state is valid.

# %%
QPT_robustness_list = [qpt[key]['robustness'] for key in qpt.keys()]
QPT_mle_robustness_list = [qpt[key]['mle robustness'] for key in qpt.keys()]
plt.plot(QPT_robustness_list,'.-',label='Raw')
plt.plot(QPT_mle_robustness_list,'.-',label='MLE')
plt.title('Robustness from QPT')
plt.legend()
plt.show()

# %%
non_Markovian_data['qpt'] = qpt

# %% [markdown]
# ## plot togather

# %%
raw_QPT_robustness_list = [qpt[key]['robustness'] for key in qpt.keys()]
raw_ellipsoid_robustness_list = [non_Markovian_data['raw'][key]['quantum_information']['robustness'] for key in non_Markovian_data['raw'].keys()]
sim_ellipsoid_robustness_list = [non_Markovian_data['sim_raw'][key]['quantum_information']['robustness']  for key in non_Markovian_data['sim_raw'].keys()]
mle_QPT_robustness_list = [qpt[key]['mle robustness'] for key in qpt.keys()]
mle_ellipsoid_robustness_list = [non_Markovian_data['mle'][key]['quantum_information']['robustness'] for key in non_Markovian_data['mle'].keys()]
sim_mle_ellipsoid_robustness_list = [non_Markovian_data['sim_mle'][key]['quantum_information']['robustness']  for key in non_Markovian_data['sim_mle'].keys()]


time_QPT = np.arange(0, len(raw_QPT_robustness_list), 1)
time_ellipsoid = np.arange(0, len(raw_ellipsoid_robustness_list), 1)*2
fig = plt.figure(figsize=(6, 10))
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)
ax1.plot(time_ellipsoid*1e-9,raw_ellipsoid_robustness_list,'.-',label = 'raw')
ax1.plot(time_ellipsoid*1e-9,sim_ellipsoid_robustness_list,'.-',label='sim')
ax1.plot(time_QPT*1e-9,QPT_robustness_list,'.-',label='QPT')
ax1.legend()
ax1.set_title('Raw')
ax2.plot(time_ellipsoid*1e-9,mle_ellipsoid_robustness_list,'.-',label = 'mle')
ax2.plot(time_ellipsoid*1e-9,sim_mle_ellipsoid_robustness_list,'.-',label='sim')
ax2.plot(time_QPT*1e-9,mle_QPT_robustness_list,'.-',label='QPT')
ax2.legend()
ax2.set_title('MLE')
plt.show()
